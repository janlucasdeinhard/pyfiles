# %%
import pandas as pd

import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import warnings,os,datetime

import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense,Dropout,Conv2D,LSTM

warnings.filterwarnings('ignore')

# %%
# 110-by-110 images

trainIMA = pd.read_csv('..\\..\\VenusVolcanos\\Volcanoes_train\\train_images.csv',header=None)
trainLAB = pd.read_csv('..\\..\\VenusVolcanos\\Volcanoes_train\\train_labels.csv',header=None)

testIMA = pd.read_csv('..\\..\\VenusVolcanos\\Volcanoes_test\\test_images.csv',header=None)
testLAB = pd.read_csv('..\\..\\VenusVolcanos\\Volcanoes_test\\test_labels.csv',header=None)

# %%
plt.imshow(trainIMA.loc[10].values.reshape([110,110]))

# %%
trainLAB
# Out:
#              0     1       2                 3
# 0     Volcano?  Type  Radius  Number Volcanoes
# 1            1     3   17.46                 1
# 2            0   NaN     NaN               NaN
# 3            0   NaN     NaN               NaN
# 4            0   NaN     NaN               NaN
# 5            0   NaN     NaN               NaN
# 6            0   NaN     NaN               NaN
# 7            0   NaN     NaN               NaN
# 8            0   NaN     NaN               NaN
# 9            0   NaN     NaN               NaN
# 10           1     1   22.02                 1
# 11           0   NaN     NaN               NaN
# 12           0   NaN     NaN               NaN
# 13           0   NaN     NaN               NaN
# 14           0   NaN     NaN               NaN
# 15           0   NaN     NaN               NaN
# 16           1     1   14.76                 1
# 17           0   NaN     NaN               NaN
# 18           0   NaN     NaN               NaN
# ...
