# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings,os,datetime

import pandas as pd
import tensorflow as tf

from sklearn import preprocessing as pp

from keras.models import Sequential,Model
from keras.layers import Dense,Conv2D,LSTM,Dropout,Input

warnings.filterwarnings('ignore')
sns.set()

# %%
df = pd.read_excel('gandata\\REAL.xlsx')

df = df.drop('Unnamed: 3',axis=1)
df = df.drop(0,axis=0)
df = df.drop('Background flow: 3 ml/min',axis=1)

df = df.rename(columns={'Unnamed: 1':'t','Channel length: 20 cm':'M'})

# %%
# 1.5 secs are 13 timesteps and is the pulse interval

plt.plot(df['t'].values,df['M'].values)

# %%
slots = []

for k in range(0,len(df['M'].values)+1,13):
    slots.append(df['M'].values[k:k+13])
    
slots.pop()
# Out:
# array([3.3254e-06, 1.3144e-06, -3.3029e-06], dtype=object)

# %%
slots = np.vstack(slots)

# %%
rslots = slots[rnd.randint(0,slots.shape[0],5)]
