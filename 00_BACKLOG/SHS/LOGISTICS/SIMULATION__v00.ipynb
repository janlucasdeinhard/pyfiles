# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import warnings,os,time,datetime,math,itertools

import torch
import pandas as pd

from keras.models import Model
from keras.layers import Dense,Input,Activation,LSTM,Conv1D,Conv2D,Dropout,BatchNormalization,concatenate

# %%
sbar_mean = 2

Ts = 2

# %%
date_range_list = pd.date_range('2018-01-01','2020-05-01',freq='MS').strftime("%Y-%b").tolist()

df = pd.DataFrame(
    index=date_range_list,
    columns=['N','Stock','Purchased']
)

# %%
df.at[date_range_list[0],'Stock'] = 10

# %%
plt.hist)
# Out:
# (array([1.376e+03, 2.731e+03, 2.683e+03, 1.798e+03, 8.650e+02, 3.690e+02,
#         1.330e+02, 3.500e+01, 9.000e+00, 1.000e+00]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <a list of 10 Patch objects>)

# %%
df['N'] = rnd.poisson(lam=sbar_mean,size=df.shape[0])

# %%
df['Purchased'] = 0

# %%
for k in range(1,df.shape[0]):
    print(df.iloc[k-1].Stock)
# Out:
# 10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
df
# Out:
#           N Stock  Purchased
# 2018-Jan  3    10          0
# 2018-Feb  1   NaN          0
# 2018-Mar  1   NaN          0
# 2018-Apr  3   NaN          0
# 2018-May  3   NaN          0
# 2018-Jun  4   NaN          0
# 2018-Jul  2   NaN          0
# 2018-Aug  5   NaN          0
# 2018-Sep  2   NaN          0
# 2018-Oct  3   NaN          0
# 2018-Nov  1   NaN          0
# 2018-Dec  1   NaN          0
# 2019-Jan  3   NaN          0
# 2019-Feb  3   NaN          0
# 2019-Mar  3   NaN          0
# 2019-Apr  1   NaN          0
# 2019-May  4   NaN          0
# 2019-Jun  2   NaN          0
# 2019-Jul  1   NaN          0
# 2019-Aug  1   NaN          0
# 2019-Sep  3   NaN          0
# 2019-Oct  2   NaN          0
# 2019-Nov  4   NaN          0
# 2019-Dec  4   NaN          0
# 2020-Jan  3   NaN          0
# 2020-Feb  2   NaN          0
# 2020-Mar  1   NaN          0
# 2020-Apr  3   NaN          0
# 2020-May  4   NaN          0
