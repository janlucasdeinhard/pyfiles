# %%
# General Imports

import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import os,sys,datetime,time,math, warnings,itertools

import pandas as pd
from contextlib import contextmanager

# Snowpark imports
from snowflake.snowpark.session import Session
import snowflake.snowpark.functions as F
import snowflake.snowpark.types as T
from snowflake.snowpark.window import Window
# Out:
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\snowflake\connector\options.py:96: UserWarning: You have an incompatible version of 'pyarrow' installed (12.0.1), please install a version that adheres to: 'pyarrow<8.1.0,>=8.0.0; extra == "pandas"'
#   warn_incompatible_dep(

# %%
def read_single_lineage_extract(excel_path):
    """
    Read and process an Informatica Lineage Excel extract for a single lineage.

    This function reads an Informatica Lineage Excel extract file, performs post-processing
    specific to this file type, and returns a DataFrame containing relevant lineage information.

    Args:
        excel_path (str): The file path to the Informatica Lineage Excel extract.

    Returns:
        pandas.DataFrame: A DataFrame containing lineage information with the following columns:
            - 'Accounts'
            - 'Martlayer.CRMCLOUD_OSC.Accounts'
            - 'SF_CRM_DataMarts/MARTLAYER/CRMCLOUD_OSC/Accounts/'
            - 'Source File'

    Note:
        The function expects the input Excel file to have a specific structure as defined by Informatica Lineage.
        The function will skip the first two rows and use the third row as the header row for reading the DataFrame.
        Post-processing is applied to filter the DataFrame based on the 'SF_CRM_DataMarts' column and select specific
        columns related to the 'Accounts' lineage. The 'Source File' column will be added to the DataFrame with the value
        of the 'excel_path' argument.

    Example:
        excel_path = 'path/to/lineage_extract.xlsx'
        lineage_df = read_single_lineage_extract(excel_path)
    """
    # Expects file structure as defined by Informatica Lineage output
    df = pd.read_excel(excel_path,skiprows=2,header=1)
    # Postprocessing defined for this specific file type
    df = df[df['Resource Name']=='SF_CRM_DataMarts'].filter(items=[
        'Asset Name',
        'Business_Terms',
        'Path'
    ],axis=1)
    df['DP Table'] = excel_path.replace('.xls','').replace('.xlsx','')
    return df

# %%
@contextmanager
def cwd(path):
    """
    Context manager to temporarily change the current working directory.

    This context manager changes the current working directory to the specified 'path'
    while the context is active. After the context exits, the original working directory
    is restored.

    Args:
        path (str): The path to the directory to which the current working directory should be changed.

    Usage:
        with cwd('/path/to/new/directory'):
            # Code executed within this block will have the current working directory changed.
            # After the block exits, the original working directory is restored.

    Example:
        with cwd('/home/user/documents'):
            file_list = os.listdir()  # List files in the '/home/user/documents' directory
        # 
    """
    oldpwd = os.getcwd()
    os.chdir(path)
    try: yield
    finally: os.chdir(oldpwd)

# %%
def read_single_lineage_extract(excel_path):
    """
    Read and process an Informatica Lineage Excel extract for a single lineage.

    This function reads an Informatica Lineage Excel extract file, performs post-processing
    specific to this file type, and returns a DataFrame containing relevant lineage information.

    Args:
        excel_path (str): The file path to the Informatica Lineage Excel extract.

    Returns:
        pandas.DataFrame: A DataFrame containing lineage information with the following columns:
            - 'Accounts'
            - 'Martlayer.CRMCLOUD_OSC.Accounts'
            - 'SF_CRM_DataMarts/MARTLAYER/CRMCLOUD_OSC/Accounts/'
            - 'Source File'

    Note:
        The function expects the input Excel file to have a specific structure as defined by Informatica Lineage.
        The function will skip the first two rows and use the third row as the header row for reading the DataFrame.
        Post-processing is applied to filter the DataFrame based on the 'SF_CRM_DataMarts' column and select specific
        columns related to the 'Accounts' lineage. The 'Source File' column will be added to the DataFrame with the value
        of the 'excel_path' argument.

    Example:
        excel_path = 'path/to/lineage_extract.xlsx'
        lineage_df = read_single_lineage_extract(excel_path)
    """
    # Expects file structure as defined by Informatica Lineage output
    df = pd.read_excel(excel_path,skiprows=2,header=1)
    # Postprocessing defined for this specific file type
    df = df[df['Resource Name']=='SF_CRM_DataMarts'].filter(items=[
        'Asset Name',
        'Business_Terms',
        'Path'
    ],axis=1)
    df['DP Table'] = excel_path.replace('.xls','').replace('.xlsx','')
    return df

# %%
# Path settings
if sys.platform.startswith('win'):
    excel_input_directory = r'../../TF_Data/Dropbox/PhD Prep/DQ Framework - Clustering/Data Products/Informatica Lineage Status Funnel Management 11.08.2023/'
    excel_output_directory = r'../../TF_Data/Dropbox/PhD Prep/DQ Framework - Clustering/Data Products/'
    shsdq_directory = r'../../TF_Data/Dropbox/PhD Prep/SHS DQ/'

# %%
# Load Data Products and associated customer tables
with cwd(excel_output_directory):
    products_file = pd.read_excel('Preliminary List of Data Products.xlsx',sheet_name='Data Products')
    products_file = products_file.merge(
        pd.read_excel('Preliminary List of Data Products.xlsx',sheet_name='DP Layer Tables'),
        on='Data Product Name',how='inner'
    )

# %%
# Read in individual Excel files to construct columns in data product
with cwd(excel_input_directory):
    lineage_file = pd.DataFrame()
    # Iterate tables in Data Product
    for dp_member in os.listdir():
        lineage_file = pd.concat([lineage_file,read_single_lineage_extract(dp_member)],axis=0)
    lineage_file = lineage_file.reset_index(drop=True)

# Post-processing of lineage extract
lineage_file['Path_tmp'] = lineage_file['Path'].str.split('/')
lineage_file[['TABLE_CATALOG','TABLE_SCHEMA','TABLE_NAME']] = pd.DataFrame(lineage_file.Path_tmp.tolist(),index=lineage_file.index).drop(columns=[0,4])
lineage_file = lineage_file.drop(columns=['Path_tmp','Path'])

# %%
# Determine composition of Data products on source table level
dp_composition = products_file.add_prefix('Customer Tables.').merge(
    lineage_file[['TABLE_CATALOG','TABLE_SCHEMA','TABLE_NAME','DP Table']].add_prefix('Source Table.'),
    left_on='Customer Tables.Relevant Data Table in Products Layer',right_on='Source Table.DP Table',how='left'
).drop(columns=['Customer Tables.Technical Location','Source Table.DP Table']).drop_duplicates().reset_index(drop=True)

# %%
# Connection Parameters
connection_parameters = {
    'account':'shsitdl.west-europe.azure',
    'user':'jan-lucas.deinhard@siemens-healthineers.com',
    'authenticator':'externalbrowser',
    'role':'FR_CRMCLOUD_DEV',
    'database':'MARTLAYER',
    'schema':'INFORMATION_SCHEMA',
    'warehouse':'W_CRMCLOUD_P'
}

# Establish Connection
session = Session.builder.configs(connection_parameters).create()

# Fetch column table from Snowflake
cC = session.table("COLUMNS")
C = pd.DataFrame(cC.collect())

session.close()
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...

# %%
# Read file with DQ Checks
with cwd(shsdq_directory):
    dqf_flag = pd.read_excel('DQ Flags in CDC.xlsx',sheet_name='DQ Checks')

# %%
# Contract columns file to relevant DQ flags
C_contracted = C[['TABLE_CATALOG','TABLE_SCHEMA','TABLE_NAME','COLUMN_NAME']].merge(
    dqf_flag[['Name','Dimension']],
    left_on='COLUMN_NAME',right_on='Name',
    how='inner'
).drop_duplicates()

# %%
# Data Quality Flags per data product
dp_dqfs = dp_composition.merge(
    C_contracted,
    left_on=['Source Table.TABLE_CATALOG','Source Table.TABLE_SCHEMA','Source Table.TABLE_NAME'],right_on=['TABLE_CATALOG','TABLE_SCHEMA','TABLE_NAME'],
    how='inner'
).drop(columns=['TABLE_CATALOG','TABLE_SCHEMA','TABLE_NAME'])

# %%
# Create the SQL Select Statement
dp_dqfs['SQL Select'] = dp_dqfs[['Source Table.TABLE_CATALOG','Source Table.TABLE_SCHEMA','Source Table.TABLE_NAME','COLUMN_NAME']].apply(lambda x:
    r'''SELECT "'Y'" AS "Y","'N'" AS "N","NULL" FROM (SELECT "{3}" as "Status",SUM(1) AS "ct" FROM "{0}"."{1}"."{2}" GROUP BY ALL) PIVOT(SUM("ct") FOR "Status" IN ('N','Y',NULL))'''.format(x[0],x[1],x[2],x[3])                                                                                                           
,axis=1)

# %%
# Connection Parameters
connection_parameters = {
    'account':'shsitdl.west-europe.azure',
    'user':'jan-lucas.deinhard@siemens-healthineers.com',
    'authenticator':'externalbrowser',
    'role':'FR_CRMCLOUD_DEV',
    'warehouse':'W_CRMCLOUD_P'
}

# Establish Connection
session = Session.builder.configs(connection_parameters).create()

# %%
results = []

ctr = 1
totalrows = dp_dqfs.shape[0]
for idx,k in dp_dqfs.iterrows():
    print('({1}/{2}) Working on {0}...'.format(k['Name'],ctr,totalrows))
    ctr += 1
    query_result = session.sql(k['SQL Select'])
    results.append(pd.DataFrame(query_result.collect()).iloc[0].tolist())
# Out:
# (1/302) Working on Opportunity Expired (Flag)...
# (2/302) Working on Data Quality Issue (Flag)...
# (3/302) Working on Data Quality Issue (Flag)...
# (4/302) Working on Implausible Revenue (Flag)...
# (5/302) Working on Possible Test Quote (Flag)...
# (6/302) Working on Implausible Cost (Flag)...
# (7/302) Working on Opportunity Expired (Flag)...
# (8/302) Working on Data Quality Issue (Flag)...
# (9/302) Working on Data Quality Issue (Flag)...
# (10/302) Working on Implausible Revenue (Flag)...
# (11/302) Working on Possible Test Quote (Flag)...
# (12/302) Working on Implausible Cost (Flag)...
# (13/302) Working on Expiration Date Missing (Flag)...
# (14/302) Working on Expiration Date Missing (Flag)...
# (15/302) Working on Potential Test Account (Flag)...
# (16/302) Working on Potential Test Account (Flag)...
# (17/302) Working on Potential Test Account (Flag)...
# (18/302) Working on Potential Test Account (Flag)...
# (19/302) Working on Potential Test Account (Flag)...
# (20/302) Working on Potential Test Account (Flag)...
# (21/302) Working on Potential Test Account (Flag)...
# (22/302) Working on Potential Test Account (Flag)...
# (23/302) Working on Potential Test Account (Flag)...
# (24/302) Working on Potential Test Account (Flag)...
# (25/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (26/302) Working on Decision Date Wrong (Flag)...
# (27/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (28/302) Working on Shipment Date Wrong (Flag)...
# (29/302) Working on Sale Type Inconsistency (Flag)...
# (30/302) Working on Multiple Quotes attached (Flag)...
# (31/302) Working on Turnover Date Wrong (Flag)...
# (32/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (33/302) Working on DQ Issue Service Opportunity related (Flag)...
# (34/302) Working on Lost w FC (Flag)...
# (35/302) Working on Booked w/o FC (Flag)...
# (36/302) Working on Quote Number Reference not found (Flag)...
# (37/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (38/302) Working on Expired (Flag)...
# (39/302) Working on Installation Date Wrong (Flag)...
# (40/302) Working on FC Inconsistency (Flag)...
# (41/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (42/302) Working on DQ Issue Quote-related (Flag)...
# (43/302) Working on Delivery Date Wrong (Flag)...
# (44/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (45/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (46/302) Working on DQ Issue Date-related (Flag)...
# (47/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (48/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (49/302) Working on Ghost (Flag)...
# (50/302) Working on Primary Winning Vendor Unknown (Flag)...
# (51/302) Working on Quote Item Reference not found (Flag)...
# (52/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (53/302) Working on Decision Date Wrong (Flag)...
# (54/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (55/302) Working on Shipment Date Wrong (Flag)...
# (56/302) Working on Sale Type Inconsistency (Flag)...
# (57/302) Working on Multiple Quotes attached (Flag)...
# (58/302) Working on Turnover Date Wrong (Flag)...
# (59/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (60/302) Working on DQ Issue Service Opportunity related (Flag)...
# (61/302) Working on Lost w FC (Flag)...
# (62/302) Working on Booked w/o FC (Flag)...
# (63/302) Working on Quote Number Reference not found (Flag)...
# (64/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (65/302) Working on Expired (Flag)...
# (66/302) Working on Installation Date Wrong (Flag)...
# (67/302) Working on FC Inconsistency (Flag)...
# (68/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (69/302) Working on DQ Issue Quote-related (Flag)...
# (70/302) Working on Delivery Date Wrong (Flag)...
# (71/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (72/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (73/302) Working on DQ Issue Date-related (Flag)...
# (74/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (75/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (76/302) Working on Ghost (Flag)...
# (77/302) Working on Primary Winning Vendor Unknown (Flag)...
# (78/302) Working on Quote Item Reference not found (Flag)...
# (79/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (80/302) Working on Decision Date Wrong (Flag)...
# (81/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (82/302) Working on Shipment Date Wrong (Flag)...
# (83/302) Working on Sale Type Inconsistency (Flag)...
# (84/302) Working on Multiple Quotes attached (Flag)...
# (85/302) Working on Turnover Date Wrong (Flag)...
# (86/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (87/302) Working on DQ Issue Service Opportunity related (Flag)...
# (88/302) Working on Lost w FC (Flag)...
# (89/302) Working on Booked w/o FC (Flag)...
# (90/302) Working on Quote Number Reference not found (Flag)...
# (91/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (92/302) Working on Expired (Flag)...
# (93/302) Working on Installation Date Wrong (Flag)...
# (94/302) Working on FC Inconsistency (Flag)...
# (95/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (96/302) Working on DQ Issue Quote-related (Flag)...
# (97/302) Working on Delivery Date Wrong (Flag)...
# (98/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (99/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (100/302) Working on DQ Issue Date-related (Flag)...
# (101/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (102/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (103/302) Working on Ghost (Flag)...
# (104/302) Working on Primary Winning Vendor Unknown (Flag)...
# (105/302) Working on Quote Item Reference not found (Flag)...
# (106/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (107/302) Working on Decision Date Wrong (Flag)...
# (108/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (109/302) Working on Shipment Date Wrong (Flag)...
# (110/302) Working on Sale Type Inconsistency (Flag)...
# (111/302) Working on Multiple Quotes attached (Flag)...
# (112/302) Working on Turnover Date Wrong (Flag)...
# (113/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (114/302) Working on DQ Issue Service Opportunity related (Flag)...
# (115/302) Working on Lost w FC (Flag)...
# (116/302) Working on Booked w/o FC (Flag)...
# (117/302) Working on Quote Number Reference not found (Flag)...
# (118/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (119/302) Working on Expired (Flag)...
# (120/302) Working on Installation Date Wrong (Flag)...
# (121/302) Working on FC Inconsistency (Flag)...
# (122/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (123/302) Working on DQ Issue Quote-related (Flag)...
# (124/302) Working on Delivery Date Wrong (Flag)...
# (125/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (126/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (127/302) Working on DQ Issue Date-related (Flag)...
# (128/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (129/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (130/302) Working on Ghost (Flag)...
# (131/302) Working on Primary Winning Vendor Unknown (Flag)...
# (132/302) Working on Quote Item Reference not found (Flag)...
# (133/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (134/302) Working on Decision Date Wrong (Flag)...
# (135/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (136/302) Working on Shipment Date Wrong (Flag)...
# (137/302) Working on Sale Type Inconsistency (Flag)...
# (138/302) Working on Multiple Quotes attached (Flag)...
# (139/302) Working on Turnover Date Wrong (Flag)...
# (140/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (141/302) Working on DQ Issue Service Opportunity related (Flag)...
# (142/302) Working on Lost w FC (Flag)...
# (143/302) Working on Booked w/o FC (Flag)...
# (144/302) Working on Quote Number Reference not found (Flag)...
# (145/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (146/302) Working on Expired (Flag)...
# (147/302) Working on Installation Date Wrong (Flag)...
# (148/302) Working on FC Inconsistency (Flag)...
# (149/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (150/302) Working on DQ Issue Quote-related (Flag)...
# (151/302) Working on Delivery Date Wrong (Flag)...
# (152/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (153/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (154/302) Working on DQ Issue Date-related (Flag)...
# (155/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (156/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (157/302) Working on Ghost (Flag)...
# (158/302) Working on Primary Winning Vendor Unknown (Flag)...
# (159/302) Working on Quote Item Reference not found (Flag)...
# (160/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (161/302) Working on Decision Date Wrong (Flag)...
# (162/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (163/302) Working on Shipment Date Wrong (Flag)...
# (164/302) Working on Sale Type Inconsistency (Flag)...
# (165/302) Working on Multiple Quotes attached (Flag)...
# (166/302) Working on Turnover Date Wrong (Flag)...
# (167/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (168/302) Working on DQ Issue Service Opportunity related (Flag)...
# (169/302) Working on Lost w FC (Flag)...
# (170/302) Working on Booked w/o FC (Flag)...
# (171/302) Working on Quote Number Reference not found (Flag)...
# (172/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (173/302) Working on Expired (Flag)...
# (174/302) Working on Installation Date Wrong (Flag)...
# (175/302) Working on FC Inconsistency (Flag)...
# (176/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (177/302) Working on DQ Issue Quote-related (Flag)...
# (178/302) Working on Delivery Date Wrong (Flag)...
# (179/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (180/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (181/302) Working on DQ Issue Date-related (Flag)...
# (182/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (183/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (184/302) Working on Ghost (Flag)...
# (185/302) Working on Primary Winning Vendor Unknown (Flag)...
# (186/302) Working on Quote Item Reference not found (Flag)...
# (187/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (188/302) Working on Decision Date Wrong (Flag)...
# (189/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (190/302) Working on Shipment Date Wrong (Flag)...
# (191/302) Working on Sale Type Inconsistency (Flag)...
# (192/302) Working on Multiple Quotes attached (Flag)...
# (193/302) Working on Turnover Date Wrong (Flag)...
# (194/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (195/302) Working on DQ Issue Service Opportunity related (Flag)...
# (196/302) Working on Lost w FC (Flag)...
# (197/302) Working on Booked w/o FC (Flag)...
# (198/302) Working on Quote Number Reference not found (Flag)...
# (199/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (200/302) Working on Expired (Flag)...
# (201/302) Working on Installation Date Wrong (Flag)...
# (202/302) Working on FC Inconsistency (Flag)...
# (203/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (204/302) Working on DQ Issue Quote-related (Flag)...
# (205/302) Working on Delivery Date Wrong (Flag)...
# (206/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (207/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (208/302) Working on DQ Issue Date-related (Flag)...
# (209/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (210/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (211/302) Working on Ghost (Flag)...
# (212/302) Working on Primary Winning Vendor Unknown (Flag)...
# (213/302) Working on Quote Item Reference not found (Flag)...
# (214/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (215/302) Working on Decision Date Wrong (Flag)...
# (216/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (217/302) Working on Shipment Date Wrong (Flag)...
# (218/302) Working on Sale Type Inconsistency (Flag)...
# (219/302) Working on Multiple Quotes attached (Flag)...
# (220/302) Working on Turnover Date Wrong (Flag)...
# (221/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (222/302) Working on DQ Issue Service Opportunity related (Flag)...
# (223/302) Working on Lost w FC (Flag)...
# (224/302) Working on Booked w/o FC (Flag)...
# (225/302) Working on Quote Number Reference not found (Flag)...
# (226/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (227/302) Working on Expired (Flag)...
# (228/302) Working on Installation Date Wrong (Flag)...
# (229/302) Working on FC Inconsistency (Flag)...
# (230/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (231/302) Working on DQ Issue Quote-related (Flag)...
# (232/302) Working on Delivery Date Wrong (Flag)...
# (233/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (234/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (235/302) Working on DQ Issue Date-related (Flag)...
# (236/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (237/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (238/302) Working on Ghost (Flag)...
# (239/302) Working on Primary Winning Vendor Unknown (Flag)...
# (240/302) Working on Quote Item Reference not found (Flag)...
# (241/302) Working on DQ Issue Funnel Inconsistencies (Flag)...
# (242/302) Working on Decision Date Wrong (Flag)...
# (243/302) Working on Primary Incumbent Vendor Product Missing (Flag)...
# (244/302) Working on Shipment Date Wrong (Flag)...
# (245/302) Working on Sale Type Inconsistency (Flag)...
# (246/302) Working on Multiple Quotes attached (Flag)...
# (247/302) Working on Turnover Date Wrong (Flag)...
# (248/302) Working on Non CS-POS w/o inc. vendor (Flag)...
# (249/302) Working on DQ Issue Service Opportunity related (Flag)...
# (250/302) Working on Lost w FC (Flag)...
# (251/302) Working on Booked w/o FC (Flag)...
# (252/302) Working on Quote Number Reference not found (Flag)...
# (253/302) Working on Prior Year Revenue  Run Rate Wrong (Flag)...
# (254/302) Working on Expired (Flag)...
# (255/302) Working on Installation Date Wrong (Flag)...
# (256/302) Working on FC Inconsistency (Flag)...
# (257/302) Working on DQ Issue In-Vitro Opportunity related (Flag)...
# (258/302) Working on DQ Issue Quote-related (Flag)...
# (259/302) Working on Delivery Date Wrong (Flag)...
# (260/302) Working on DQ Issue In-Vivo Funnel relevant (Flag)...
# (261/302) Working on DQ Issue In-Vivo Opportunity related (Flag)...
# (262/302) Working on DQ Issue Date-related (Flag)...
# (263/302) Working on DQ Issue In-Vitro Funnel relevant (Flag)...
# (264/302) Working on DQ Issue Opportunity Vendor related (Flag)...
# (265/302) Working on Ghost (Flag)...
# (266/302) Working on Primary Winning Vendor Unknown (Flag)...
# (267/302) Working on Quote Item Reference not found (Flag)...
# (268/302) Working on Opportunity Expired (Flag)...
# (269/302) Working on Opportunity Expired (Flag)...
# (270/302) Working on Opportunity Expired (Flag)...
# (271/302) Working on Opportunity Expired (Flag)...
# (272/302) Working on Opportunity Expired (Flag)...
# (273/302) Working on Opportunity Expired (Flag)...
# (274/302) Working on Opportunity Expired (Flag)...
# (275/302) Working on Opportunity Expired (Flag)...
# (276/302) Working on Opportunity Expired (Flag)...
# (277/302) Working on Project.Signature Date in the past (Flag)...
# (278/302) Working on Project.PM20 achieved and no Contract Value (Flag)...
# (279/302) Working on Project.PM40 not achieved and Signature Date in <40 days (Flag)...
# (280/302) Working on Project.First Rev. Recogn. before Signature Date (Flag)...
# (281/302) Working on Project.No Signature Date (Flag)...
# (282/302) Working on Project.ISM Milestone Progress (Flag)...
# (283/302) Working on Project.Next Milestone in the past (Flag)...
# (284/302) Working on Project.ES DQ Issue (Flag)...
# (285/302) Working on Project.Signature Date in the past (Flag)...
# (286/302) Working on Project.PM20 achieved and no Contract Value (Flag)...
# (287/302) Working on Project.PM40 not achieved and Signature Date in <40 days (Flag)...
# (288/302) Working on Project.First Rev. Recogn. before Signature Date (Flag)...
# (289/302) Working on Project.No Signature Date (Flag)...
# (290/302) Working on Project.ISM Milestone Progress (Flag)...
# (291/302) Working on Project.Next Milestone in the past (Flag)...
# (292/302) Working on Project.ES DQ Issue (Flag)...
# (293/302) Working on Project.Signature Date in the past (Flag)...
# (294/302) Working on Project.PM20 achieved and no Contract Value (Flag)...
# (295/302) Working on Project.PM40 not achieved and Signature Date in <40 days (Flag)...
# (296/302) Working on Project.First Rev. Recogn. before Signature Date (Flag)...
# (297/302) Working on Project.No Signature Date (Flag)...
# (298/302) Working on Project.ISM Milestone Progress (Flag)...
# (299/302) Working on Project.Next Milestone in the past (Flag)...
# (300/302) Working on Project.ES DQ Issue (Flag)...
# (301/302) Working on Implausible Revenue (Flag)...
# (302/302) Working on Implausible Cost (Flag)...

# %%
session.close()

# %%
dp_dqfs = pd.concat(
    [dp_dqfs,pd.DataFrame(results).rename(columns={0:'Y Count',1:'N Count',2:'NULL Count'})]
,axis=1)

dp_dqfs[['Y Count','N Count','NULL Count']] = dp_dqfs[['Y Count','N Count','NULL Count']].fillna(0)

# %%
source_dqfs = dp_dqfs.groupby(['Source Table.TABLE_CATALOG','Source Table.TABLE_SCHEMA','Source Table.TABLE_NAME','Dimension'])['COLUMN_NAME'].apply(list).reset_index(name='Flags')

# %%
source_dqfs[['Source Table.TABLE_CATALOG','Source Table.TABLE_SCHEMA','Source Table.TABLE_NAME','Flags']]
# Out:
#    Source Table.TABLE_CATALOG Source Table.TABLE_SCHEMA  \
# 0                   MARTLAYER              CRMCLOUD_CPQ
# 1                   MARTLAYER              CRMCLOUD_CPQ
# 2                   MARTLAYER              CRMCLOUD_CPQ
# 3                   MARTLAYER              CRMCLOUD_CPQ
# 4                   MARTLAYER              CRMCLOUD_CPQ
# 5                   MARTLAYER              CRMCLOUD_CPQ
# 6                   MARTLAYER              CRMCLOUD_OSC
# 7                   MARTLAYER              CRMCLOUD_OSC
# 8                   MARTLAYER              CRMCLOUD_OSC
# 9                   MARTLAYER              CRMCLOUD_OSC
# 10                  MARTLAYER              CRMCLOUD_OSC
# 11                  MARTLAYER              CRMCLOUD_OSC
# 12                  MARTLAYER              CRMCLOUD_OSC
# 13                  MARTLAYER              CRMCLOUD_OSC
#
#    Source Table.TABLE_NAME                                              Flags
# 0     ACTIVE_QUOTES_HEADER  [Opportunity Expired (Flag), Opportunity Expir...
# 1     ACTIVE_QUOTES_HEADER  [Data Quality Issue (Flag), Implausible Revenu...
# 2     ACTIVE_QUOTES_HEADER  [Data Quality Issue (Flag), Data Quality Issue...
# 3     ACTIVE_QUOTES_HEADER  [Possible Test Quote (Flag), Possible Test Quo...
# 4   IN_VITRO_Contract_KPIs  [Implausible Revenue (Flag), Implausible Cost ...
# 5                Proposals  [Expiration Date Missing (Flag), Expiration Da...
# 6                 Accounts  [Potential Test Account (Flag), Potential Test...
# 7                     OLIs  [Primary Incumbent Vendor Product Missing (Fla...
# 8                     OLIs  [DQ Issue Funnel Inconsistencies (Flag), Sale ...
# 9                     OLIs  [Decision Date Wrong (Flag), Shipment Date Wro...
# 10           Opportunities  [Opportunity Expired (Flag), Opportunity Expir...
# 11                Projects  [Project.No Signature Date (Flag), Project.No ...
# 12                Projects  [Project.Signature Date in the past (Flag), Pr...
# 13                Projects  [Project.ES DQ Issue (Flag), Project.ES DQ Iss...
