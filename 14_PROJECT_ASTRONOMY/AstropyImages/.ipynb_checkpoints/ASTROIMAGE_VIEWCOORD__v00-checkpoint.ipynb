# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import datetime,os,warnings,csv

import torch
from torch import functional as F
from torch import optim
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor

import astropy.units as u
from astropy import coordinates as coord

from astroquery import vizier as V
from astroquery import skyview as sv

# %%
view = sv.SkyView()

# %%
c = coord.SkyCoord(10,50,unit=('deg','deg'),frame='icrs')

paths = view.get_images(position=c,survey=['Fermi 5','Planck 217 Q'])

plt.imshow(paths[0][0].data)

# %%
surveys = dict(view.list_surveys())
# Out:
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
# ...
