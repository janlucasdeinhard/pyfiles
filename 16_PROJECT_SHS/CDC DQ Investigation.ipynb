# %% [markdown]
# # Snowflake CDC DQ Investigation
#
# The goal of this notebook is to understand on a very high level simple KPIs which gauge data quality  issues added inside the CRM Data Cloud.

# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import warnings,datetime,time,math,itertools,os,sys

import torch
import torch.nn as nn
from torch.nn import functional as F

import pandas as pd
import plotly.express as px

from sklearn.preprocessing import LabelEncoder

import networkx as nx

import snowflake.connector
# Out:
# C:\Users\z003mxpm\Anaconda3\lib\site-packages\snowflake\connector\options.py:94: UserWarning: You have an incompatible version of 'pyarrow' installed (4.0.0), please install a version that adheres to: 'pyarrow<3.1.0,>=3.0.0; extra == "pandas"'
#   warn_incompatible_dep(

# %%
sys.path.append('./../7_HELPERFUNCTIONS/')
from WorldSimulators.CRMDatabase import CRMDB

# %% [markdown]
# ## Connect to CDC and fetch Metadata
#
# Build connection framework and fetch Metadata Information.

# %%
conn = snowflake.connector.connect(
    user='jan-lucas.deinhard@siemens-healthineers.com',
    account='shsitdl.west-europe.azure',
    authenticator='externalbrowser'
)
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...

# %%
# CRM Data Cloud Metadata
info = pd.read_sql("SHOW COLUMNS",con=conn)

# %%
conn.close()

# %% [markdown]
# # Metadata Preprocessing
#
# Metadata added information, includes
# * Flagging of test columns
# * Full Name Creation
# * In-database Name Creation
# * Database hierarchy mapping
# * First Occurence of table in Cloud

# %%
info['Test Schema'] = info['schema_name'].apply(lambda x: 'Y' if '_TEST' in x else 'N')

# %%
info['Full Tablename'] = info.apply(lambda x: x['database_name']+'.'+x['schema_name']+'.'+x['table_name'],axis=1)

# %%
info['In-Database Name'] = info.apply(lambda x: x['schema_name']+'.'+x['table_name'],axis=1)

# %%
database_hierarchy = {
    'ACCESSLAYER':0, 
    'CRMCL_CHECKIN':1,
    'CRMCL_SCREENING':2,
    'CRMCL_BOARDING':3,
    'CRMCL_TOPICAREA':4,
    'MARTLAYER':5
}

info['database_hierarchy'] = info['database_name'].apply(lambda x: database_hierarchy.get(x,-1))

# %%
info = info.merge(
    info[[
        'schema_name',
        'table_name',
        'database_hierarchy',
        'database_name'
    ]].drop_duplicates().sort_values(by=[
        'schema_name',
        'table_name',
        'database_hierarchy',
    ],ascending=True).drop(columns=['database_hierarchy']).groupby(['schema_name','table_name'],as_index=False).first(),
    on=['schema_name','table_name'],how='left'
).rename(columns={
    'database_name_x':'database_name',
    'database_name_y':'Table First Occurrence'
})

info['Full Tablename First Occurrence'] = info[['In-Database Name','Table First Occurrence']].apply(lambda x: x[1]+'.'+x[0],axis=1)

# %% [markdown]
# # Analysis part
#
# Define tables to be checked for comparison, compare metadata for this set and set thresholds.

# %%
df0 = info[(info['database_name'].isin(['CRMCL_TOPICAREA']))&(info['Test Schema']=='N')].copy()

df0 = df0[['Full Tablename','Full Tablename First Occurrence']].drop_duplicates()

df0 = df0.merge(
    info[['Full Tablename','column_name']].groupby(['Full Tablename'],as_index=False).nunique(),
    on='Full Tablename',how='left'
).rename(columns={'column_name':'TopicArea Column Count'})

df0 = df0.merge(
    info[['Full Tablename','column_name']].groupby(['Full Tablename'],as_index=False).nunique(),
    left_on='Full Tablename First Occurrence',right_on='Full Tablename',how='left'
).drop(columns=['Full Tablename_y']).rename(columns={
    'column_name':'First Occurrence Column Count',
    'Full Tablename_x':'Full Tablename'
})

# %%
df0['Column Count Delta'] = df0[['TopicArea Column Count','First Occurrence Column Count']].apply(lambda x: x[0]/x[1]-1,axis=1)

# %%
df0.sort_values(by=['Column Count Delta'],ascending=False)
# Out:
#                                         Full Tablename  \
# 42              CRMCL_TOPICAREA.AUXFILES.Shipment_Test
# 154                  CRMCL_TOPICAREA.OSC.Opportunities
# 62       CRMCL_TOPICAREA.CPQ.IN_VITRO_Additional_Items
# 157                       CRMCL_TOPICAREA.OSC.Projects
# 152                           CRMCL_TOPICAREA.OSC.OLIs
# ..                                                 ...
# 19         CRMCL_TOPICAREA.AUXFILES.Manual Adjustments
# 18              CRMCL_TOPICAREA.AUXFILES.LC_Currencies
# 0    CRMCL_TOPICAREA.ADOBE_ANALYTICS.ADOBE_WEB_ANAL...
# 90              CRMCL_TOPICAREA.GCR.Revenue_New_Orders
# 245                      CRMCL_TOPICAREA.SDTB.SDTB_IBD
#
#                        Full Tablename First Occurrence  \
# 42                CRMCL_CHECKIN.AUXFILES.Shipment_Test
# 154                    CRMCL_CHECKIN.OSC.Opportunities
# 62         CRMCL_CHECKIN.CPQ.IN_VITRO_Additional_Items
# 157                         CRMCL_CHECKIN.OSC.Projects
# 152                             CRMCL_CHECKIN.OSC.OLIs
# ..                                                 ...
# 19           CRMCL_CHECKIN.AUXFILES.Manual Adjustments
# 18              CRMCL_SCREENING.AUXFILES.LC_Currencies
# 0    CRMCL_CHECKIN.ADOBE_ANALYTICS.ADOBE_WEB_ANALYTICS
# 90                CRMCL_CHECKIN.GCR.Revenue_New_Orders
# 245                        CRMCL_CHECKIN.SDTB.SDTB_IBD
#
#      TopicArea Column Count  First Occurrence Column Count  Column Count Delta
# 42                        4                              1            3.000000
# 154                      93                             37            1.513514
# 62                       51                             21            1.428571
# 157                     115                             51            1.254902
# 152                     133                             63            1.111111
# ..                      ...                            ...                 ...
# 19                       14                             14            0.000000
# 18                        6                              6            0.000000
# 0                         7                              7            0.000000
# 90                       49                             50           -0.020000
# 245                      43                            216           -0.800926
#
# [253 rows x 5 columns]

# %%
df0
# Out:
#                                         Full Tablename  \
# 0    CRMCL_TOPICAREA.ADOBE_ANALYTICS.ADOBE_WEB_ANAL...
# 1    CRMCL_TOPICAREA.AUXFILES.Account_Address_Geolo...
# 2    CRMCL_TOPICAREA.AUXFILES.Account_DefaultPerCou...
# 3    CRMCL_TOPICAREA.AUXFILES.Account_FreseniusSett...
# 4          CRMCL_TOPICAREA.AUXFILES.Account_IB Factors
# ..                                                 ...
# 248  CRMCL_TOPICAREA.VARIAN.VarianAccountTerritorie...
# 249              CRMCL_TOPICAREA.VARIAN.VarianAccounts
# 250                CRMCL_TOPICAREA.VARIAN.VarianAssets
# 251         CRMCL_TOPICAREA.VARIAN.VarianOpportunities
# 252           CRMCL_TOPICAREA.VARIAN.VarianTerritories
#
#                        Full Tablename First Occurrence  \
# 0    CRMCL_CHECKIN.ADOBE_ANALYTICS.ADOBE_WEB_ANALYTICS
# 1    CRMCL_CHECKIN.AUXFILES.Account_Address_Geoloca...
# 2     CRMCL_CHECKIN.AUXFILES.Account_DefaultPerCountry
# 3     CRMCL_CHECKIN.AUXFILES.Account_FreseniusSettings
# 4            CRMCL_CHECKIN.AUXFILES.Account_IB Factors
# ..                                                 ...
# 248  CRMCL_BOARDING.VARIAN.VarianAccountTerritoriesMap
# 249                CRMCL_CHECKIN.VARIAN.VarianAccounts
# 250                  CRMCL_CHECKIN.VARIAN.VarianAssets
# 251           CRMCL_CHECKIN.VARIAN.VarianOpportunities
# 252             CRMCL_CHECKIN.VARIAN.VarianTerritories
#
#      TopicArea Column Count  First Occurrence Column Count  Column Count Delta
# 0                         7                              7            0.000000
# 1                        19                             19            0.000000
# 2                         2                              2            0.000000
# 3                         5                              5            0.000000
# 4                         6                              6            0.000000
# ..                      ...                            ...                 ...
# 248                       5                              4            0.250000
# 249                      37                             34            0.088235
# 250                      39                             31            0.258065
# 251                      81                             67            0.208955
# 252                      14                             13            0.076923
#
# [253 rows x 5 columns]

# %%
conn = snowflake.connector.connect(
    user='jan-lucas.deinhard@siemens-healthineers.com',
    account='shsitdl.west-europe.azure',
    authenticator='externalbrowser'
)
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...

# %%
size_query = '''
SELECT count(*) as ROWNUM FROM {0}
'''
L = []
for cindex,k in df0.iterrows():
    query_last = size_query.format('\"'+k['Full Tablename'].replace('.','\".\"')+'\"')
    query_first = size_query.format('\"'+k['Full Tablename First Occurrence'].replace('.','\".\"')+'\"')
    try:
        l = [pd.read_sql(query_last,con=conn).values[0][0],pd.read_sql(query_first,con=conn).values[0][0]]
    except:
        l = [np.nan,np.nan]
    L.append(l)

# %%
conn.close()

# %%
df0 = pd.concat([df0,pd.DataFrame(L)],axis=1)

# %%
df0 = df0.rename(columns={
    0:'TopicArea Row Count',
    1:'First Occurrence Row Count'
})

# %%
df0
# Out:
#                                         Full Tablename  \
# 0    CRMCL_TOPICAREA.ADOBE_ANALYTICS.ADOBE_WEB_ANAL...
# 1    CRMCL_TOPICAREA.AUXFILES.Account_Address_Geolo...
# 2    CRMCL_TOPICAREA.AUXFILES.Account_DefaultPerCou...
# 3    CRMCL_TOPICAREA.AUXFILES.Account_FreseniusSett...
# 4          CRMCL_TOPICAREA.AUXFILES.Account_IB Factors
# ..                                                 ...
# 248  CRMCL_TOPICAREA.VARIAN.VarianAccountTerritorie...
# 249              CRMCL_TOPICAREA.VARIAN.VarianAccounts
# 250                CRMCL_TOPICAREA.VARIAN.VarianAssets
# 251         CRMCL_TOPICAREA.VARIAN.VarianOpportunities
# 252           CRMCL_TOPICAREA.VARIAN.VarianTerritories
#
#                        Full Tablename First Occurrence  \
# 0    CRMCL_CHECKIN.ADOBE_ANALYTICS.ADOBE_WEB_ANALYTICS
# 1    CRMCL_CHECKIN.AUXFILES.Account_Address_Geoloca...
# 2     CRMCL_CHECKIN.AUXFILES.Account_DefaultPerCountry
# 3     CRMCL_CHECKIN.AUXFILES.Account_FreseniusSettings
# 4            CRMCL_CHECKIN.AUXFILES.Account_IB Factors
# ..                                                 ...
# 248  CRMCL_BOARDING.VARIAN.VarianAccountTerritoriesMap
# 249                CRMCL_CHECKIN.VARIAN.VarianAccounts
# 250                  CRMCL_CHECKIN.VARIAN.VarianAssets
# 251           CRMCL_CHECKIN.VARIAN.VarianOpportunities
# 252             CRMCL_CHECKIN.VARIAN.VarianTerritories
#
#      TopicArea Column Count  First Occurrence Column Count  \
# 0                         7                              7
# 1                        19                             19
# 2                         2                              2
# 3                         5                              5
# 4                         6                              6
# ..                      ...                            ...
# 248                       5                              4
# 249                      37                             34
# 250                      39                             31
# 251                      81                             67
# 252                      14                             13
#
#      Column Count Delta  TopicArea Row Count  First Occurrence Row Count
# 0              0.000000            4274906.0                   4289639.0
# 1              0.000000             419844.0                    419844.0
# 2              0.000000                286.0                       286.0
# 3              0.000000                206.0                       206.0
# 4              0.000000                647.0                       647.0
# ..                  ...                  ...                         ...
# 248            0.250000            3270171.0                   3270171.0
# 249            0.088235              21365.0                     21365.0
# 250            0.258065             211422.0                    211176.0
# 251            0.208955             235231.0                    235231.0
# 252            0.076923              41792.0                     41792.0
#
# [253 rows x 7 columns]

# %%
df0['Row Count Delta'] = df0[['TopicArea Row Count','First Occurrence Row Count']].apply(lambda x: x[0]/x[1]-1,axis=1)

# %%
df0['Row Count Delta'].replace([np.inf,-np.inf],np.nan,inplace=True)

# %%
df0[~df0['Row Count Delta'].isna()].sort_values(by=['Row Count Delta'],ascending=False).head(25)
# Out:
#                                         Full Tablename  \
# 98     CRMCL_TOPICAREA.INFORMATION_SCHEMA.FILE_FORMATS
# 107        CRMCL_TOPICAREA.INFORMATION_SCHEMA.SCHEMATA
# 109          CRMCL_TOPICAREA.INFORMATION_SCHEMA.STAGES
# 115           CRMCL_TOPICAREA.INFORMATION_SCHEMA.VIEWS
# 127                       CRMCL_TOPICAREA.OSC.Accounts
# 250                CRMCL_TOPICAREA.VARIAN.VarianAssets
# 136        CRMCL_TOPICAREA.OSC.Business_Plan_Objective
# 129             CRMCL_TOPICAREA.OSC.Activity_Assignees
# 130              CRMCL_TOPICAREA.OSC.Activity_Contacts
# 131            CRMCL_TOPICAREA.OSC.Activity_Objectives
# 132             CRMCL_TOPICAREA.OSC.Asset_All_Contacts
# 133      CRMCL_TOPICAREA.OSC.Asset_All_Oppty_Relations
# 134            CRMCL_TOPICAREA.OSC.Asset_All_Resources
# 135                         CRMCL_TOPICAREA.OSC.Assets
# 91   CRMCL_TOPICAREA.GCR.Revenue_New_Orders_Aggregated
# 137  CRMCL_TOPICAREA.OSC.Business_Plan_Objective_Split
# 138                 CRMCL_TOPICAREA.OSC.Business_Plans
# 139   CRMCL_TOPICAREA.OSC.Contact_Marketing_Attributes
# 140                       CRMCL_TOPICAREA.OSC.Contacts
# 141              CRMCL_TOPICAREA.OSC.DQ_Check_Overview
# 143                     CRMCL_TOPICAREA.OSC.DQ_Results
# 144  CRMCL_TOPICAREA.OSC.Employee_Territory_Visibil...
# 145                      CRMCL_TOPICAREA.OSC.Employees
# 128                     CRMCL_TOPICAREA.OSC.Activities
# 124         CRMCL_TOPICAREA.OSC.Account_ID2Country_Map
#
#                        Full Tablename First Occurrence  \
# 98      ANALYTICSLAYER.INFORMATION_SCHEMA.FILE_FORMATS
# 107         ANALYTICSLAYER.INFORMATION_SCHEMA.SCHEMATA
# 109           ANALYTICSLAYER.INFORMATION_SCHEMA.STAGES
# 115            ANALYTICSLAYER.INFORMATION_SCHEMA.VIEWS
# 127                         CRMCL_CHECKIN.OSC.Accounts
# 250                  CRMCL_CHECKIN.VARIAN.VarianAssets
# 136          CRMCL_CHECKIN.OSC.Business_Plan_Objective
# 129               CRMCL_CHECKIN.OSC.Activity_Assignees
# 130                CRMCL_CHECKIN.OSC.Activity_Contacts
# 131              CRMCL_CHECKIN.OSC.Activity_Objectives
# 132               CRMCL_CHECKIN.OSC.Asset_All_Contacts
# 133        CRMCL_CHECKIN.OSC.Asset_All_Oppty_Relations
# 134              CRMCL_CHECKIN.OSC.Asset_All_Resources
# 135                           CRMCL_CHECKIN.OSC.Assets
# 91    CRMCL_BOARDING.GCR.Revenue_New_Orders_Aggregated
# 137    CRMCL_CHECKIN.OSC.Business_Plan_Objective_Split
# 138                   CRMCL_CHECKIN.OSC.Business_Plans
# 139     CRMCL_CHECKIN.OSC.Contact_Marketing_Attributes
# 140                         CRMCL_CHECKIN.OSC.Contacts
# 141              CRMCL_TOPICAREA.OSC.DQ_Check_Overview
# 143                     CRMCL_TOPICAREA.OSC.DQ_Results
# 144  CRMCL_BOARDING.OSC.Employee_Territory_Visibili...
# 145                        CRMCL_CHECKIN.OSC.Employees
# 128                       CRMCL_CHECKIN.OSC.Activities
# 124         CRMCL_TOPICAREA.OSC.Account_ID2Country_Map
#
#      TopicArea Column Count  First Occurrence Column Count  \
# 98                       22                             22
# 107                      13                             13
# 109                      10                             10
# 115                      12                             12
# 127                     107                             93
# 250                      39                             31
# 136                      10                             10
# 129                      10                             10
# 130                       9                              9
# 131                       8                              8
# 132                       6                              6
# 133                       7                              7
# 134                       6                              6
# 135                     106                             67
# 91                       34                             33
# 137                      59                             59
# 138                      26                             26
# 139                      12                             12
# 140                      63                             63
# 141                       8                              8
# 143                      15                             15
# 144                       2                              2
# 145                      14                             14
# 128                      51                             47
# 124                       2                              2
#
#      Column Count Delta  TopicArea Row Count  First Occurrence Row Count  \
# 98             0.000000                 26.0                         1.0
# 107            0.000000                 36.0                         2.0
# 109            0.000000                 13.0                         1.0
# 115            0.000000                 74.0                        23.0
# 127            0.150538             589467.0                    588225.0
# 250            0.258065             211422.0                    211176.0
# 136            0.000000              47082.0                     47082.0
# 129            0.000000            2218625.0                   2218625.0
# 130            0.000000             738909.0                    738909.0
# 131            0.000000                 71.0                        71.0
# 132            0.000000               4577.0                      4577.0
# 133            0.000000             656698.0                    656698.0
# 134            0.000000                 42.0                        42.0
# 135            0.582090            1626617.0                   1626617.0
# 91             0.030303           16411294.0                  16411294.0
# 137            0.000000             118703.0                    118703.0
# 138            0.000000               5111.0                      5111.0
# 139            0.000000             140229.0                    140229.0
# 140            0.000000             393052.0                    393052.0
# 141            0.000000                 16.0                        16.0
# 143            0.000000             598049.0                    598049.0
# 144            0.000000             819839.0                    819839.0
# 145            0.000000              15575.0                     15575.0
# 128            0.085106            2133424.0                   2133424.0
# 124            0.000000             589467.0                    589467.0
#
#      Row Count Delta
# 98         25.000000
# 107        17.000000
# 109        12.000000
# 115         2.217391
# 127         0.002111
# 250         0.001165
# 136         0.000000
# 129         0.000000
# 130         0.000000
# 131         0.000000
# 132         0.000000
# 133         0.000000
# 134         0.000000
# 135         0.000000
# 91          0.000000
# 137         0.000000
# 138         0.000000
# 139         0.000000
# 140         0.000000
# 141         0.000000
# 143         0.000000
# 144         0.000000
# 145         0.000000
# 128         0.000000
# 124         0.000000
