# %%
# Default imports.
import numpy as np 
from numpy import random as rnd 
from matplotlib import pyplot as plt 
import os,sys,datetime,time,warnings,itertools,math 

# Always need pandas.
import pandas as pd 

# Lanchain OpenAI imports.
from langchain.llms import OpenAI
from langchain import ConversationChain
from langchain import PromptTemplate

# SPARQL Wrapper
from SPARQLWrapper import SPARQLWrapper,JSON

# %%
# Load platform-dependent API key file.
if sys.platform=='win32':
    api_key_file_target = r'C:\\Users\\z003mxpm\\Desktop\\Library_SHS\\keys\\langchain.txt'
else:
    api_key_file_target = r'/Users/janlucasdeinhard/Local Keystore/langchain.txt'
# Load API key file on system.
api_keys = {}
with open(api_key_file_target,'r') as f:
    text = f.readline()
    while len(text)>0:
        linelist = [k.strip() for k in text.split(':')]
        assert len(linelist)==2,'Target file corrupted!'
        api_keys[linelist[0]] = linelist[1]
        text = f.readline()
# Add API key to path.
os.environ['OPENAI_API_KEY'] = api_keys['CITY_EVOLUTION_KEY']

# %%
# Configure LLM with GPT4 architecture.
#llm = OpenAI(model_name='gpt-4-1106-preview')
llm = OpenAI(model_name='gpt-4')
conv = ConversationChain(
    llm=llm,
    verbose = False
)
# Out:
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\openai.py:216: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\openai.py:811: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(

# %%
# Instruct the model for desired output. Further instructions go here.
print(conv.predict(input='''
    This is a fine-tuning instruction. You will now act as a question-answer machine and restrict your answers to one-word responses whereever possible. Specifically I want you
    to return the closest integer year if I ask you a date. If the city was founded BCE, you give me the negative integer. Please be extra careful about this! 
    Along with the founding date in this format, I want you
    output the confidence you have in this date, on a scale from 0 to 1, all right? Please use forward slash as a separator.
'''))
# Out:
# Understood.

# %%
# Prepare prompt template.
prompt = PromptTemplate(
    input_variables=['City'],
    template='''
        When was the city of {City} first mentioned in historical records?
    '''
)

# %%
# Prepare prompt template.
prompt = PromptTemplate(
    input_variables=['City1','City2','City3','City4','City5','City6','City7','City8','City9','City10'],
    template='''
        When were the following cities first mentioned in historical records? {City1},{City2},{City3},{City4},{City5},{City6},{City7},{City8},{City9},{City10}
    '''
)

# %%
resp = conv.predict(input=prompt.format(
     City1='Tokyo'
    ,City2='Jakarta'
    ,City3='Delhi'
    ,City4='Mumbai'
    ,City5='Manila'
    ,City6='Seoul'
    ,City7='Cairo'
    ,City8='Dhaka'
    ,City9='Bangkok'
    ,City10='Moscow'
))

print(resp)
# Out:
# Tokyo/1603/0.9, Jakarta/397/0.75, Delhi/-2800/0.6, Mumbai/-1500/0.8, Manila/1571/0.95, Seoul/-18/0.8, Cairo/969/0.9, Dhaka/1608/0.8, Bangkok/1378/0.7, Moscow/1147/0.85

# %%
# Determine path on platform
if sys.platform=='win32':
    file_path = r'..\\..\\..\\TF_Data\\Dropbox\\TF_data\\world_cities\\'
else:
    raise Exception('Please configure a file path for this platform.')
# Load database of cities
df = pd.read_csv(file_path+'worldcities.csv')

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
sparql.setQuery("""
SELECT DISTINCT ?city ?cityLabel ?country ?countryLabel ?continent ?continentLabel
WHERE {
  # ?city wdt:P31/wdt:P279* wd:Q515.
  # ?city wdt:P17 ?country.            
  # ?country wdt:P30 ?continent.       
  # ?city wdt:P1082 ?population.

  FILTER (?population > 10000)  
  FILTER (?continent IN (wd:Q46, wd:Q48))  # Filter for Europe (Q46) or Asia (Q48)

  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "en".
  }
}
ORDER BY ?continentLabel ?countryLabel ?cityLabel
""")
sparql.setReturnFormat(JSON)
sparql_results = sparql.query().convert()
wds_cities = pd.json_normalize(sparql_results['results'],record_path=['bindings'])

# %%
wds_cities = wds_cities.rename(columns={
    'cityLabel.value':'city',
    'continentLabel.value':'continent',
    'countryLabel.value':'country'
})

# %%
rf = df.merge(
    wds_cities,
    on=['city','country'],how='inner'
)

rf = rf.drop(columns=[
    'country.value',
    'countryLabel.xml:lang',
    'countryLabel.type',
    'continent.type',
    'continent.value',
    'continentLabel.xml:lang',
    'continentLabel.type',
    'city.value',
    'cityLabel.xml:lang',
    'cityLabel.type',
    'id',
    'city.type',
    'country.type'	
]).drop_duplicates()

# %%
L = []
MAXCOUNTER = rf.shape[0]

ctr = 0
for k,v in rf.iterrows():
    resp = conv.predict(input=prompt.format(City=v['city']))
    L.append(resp)
    if ctr%100==0: print('{0} / {1} completed'.format(ctr,MAXCOUNTER))
    ctr += 1
    #print('City: {0}  -->  Model Reponse: {1}'.format(v['city'],resp))
# Out:
# 0 / 4845 completed
# 100 / 4845 completed
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-4-1106-preview in organization org-ETO7hv3Zc6cvPXSTScQLVTnL on tokens per day (TPD): Limit 500000, Used 498556, Requested 5172. Please try again in 10m44.198s. Visit https://platform.openai.com/account/rate-limits to learn more..
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-4-1106-preview in organization org-ETO7hv3Zc6cvPXSTScQLVTnL on tokens per day (TPD): Limit 500000, Used 498531, Requested 5172. Please try again in 10m39.878s. Visit https://platform.openai.com/account/rate-limits to learn more..
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-4-1106-preview in organization org-ETO7hv3Zc6cvPXSTScQLVTnL on tokens per day (TPD): Limit 500000, Used 498507, Requested 5172. Please try again in 10m35.731s. Visit https://platform.openai.com/account/rate-limits to learn more..
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for gpt-4-1106-preview in organization org-ETO7hv3Zc6cvPXSTScQLVTnL on tokens per day (TPD): Limit 500000, Used 498483, Requested 5172. Please try again in 10m31.584s. Visit https://platform.openai.com/account/rate-limits to learn more..
# Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 10.0 seconds as it raised RateLimitError: Rate limit reached for gpt-4-1106-preview in organization org-ETO7hv3Zc6cvPXSTScQLVTnL on tokens per day (TPD): Limit 500000, Used 498434, Requested 5172. Please try again in 10m23.116s. Visit https://platform.openai.com/account/rate-limits to learn more..
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-113-ccd0137d5028> in <module>
#       4 ctr = 0
#       5 for k,v in rf.iterrows():
# ----> 6     resp = conv.predict(input=prompt.format(City=v['city']))
#       7     L.append(resp)
#       8     if ctr%100==0: print('{0} / {1} completed'.format(ctr,MAXCOUNTER))
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\chains\llm.py in predict(self, callbacks, **kwargs)
#     255                 completion = llm.predict(adjective="funny")
#     256         """
# --> 257         return self(kwargs, callbacks=callbacks)[self.output_key]
#     258
#     259     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\chains\base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     306         except BaseException as e:
#     307             run_manager.on_chain_error(e)
# --> 308             raise e
#     309         run_manager.on_chain_end(outputs)
#     310         final_outputs: Dict[str, Any] = self.prep_outputs(
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\chains\base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     300         try:
#     301             outputs = (
# --> 302                 self._call(inputs, run_manager=run_manager)
#     303                 if new_arg_supported
#     304                 else self._call(inputs)
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\chains\llm.py in _call(self, inputs, run_manager)
#      91         run_manager: Optional[CallbackManagerForChainRun] = None,
#      92     ) -> Dict[str, str]:
# ---> 93         response = self.generate([inputs], run_manager=run_manager)
#      94         return self.create_outputs(response)[0]
#      95
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\chains\llm.py in generate(self, input_list, run_manager)
#     101         """Generate LLM result from inputs."""
#     102         prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 103         return self.llm.generate_prompt(
#     104             prompts,
#     105             stop,
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\base.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     495     ) -> LLMResult:
#     496         prompt_strings = [p.to_string() for p in prompts]
# --> 497         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     498
#     499     async def agenerate_prompt(
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\base.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     644                 )
#     645             ]
# --> 646             output = self._generate_helper(
#     647                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     648             )
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     532             for run_manager in run_managers:
#     533                 run_manager.on_llm_error(e)
# --> 534             raise e
#     535         flattened_outputs = output.flatten()
#     536         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     519         try:
#     520             output = (
# --> 521                 self._generate(
#     522                     prompts,
#     523                     stop=stop,
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\openai.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     894         messages, params = self._get_chat_params(prompts, stop)
#     895         params = {**params, **kwargs}
# --> 896         full_response = completion_with_retry(
#     897             self, messages=messages, run_manager=run_manager, **params
#     898         )
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\openai.py in completion_with_retry(llm, run_manager, **kwargs)
#     113         return llm.client.create(**kwargs)
#     114
# --> 115     return _completion_with_retry(**kwargs)
#     116
#     117
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     323             retry_exc = self.retry_error_cls(fut)
#     324             if self.reraise:
# --> 325                 raise retry_exc.reraise()
#     326             raise retry_exc from fut.exception()
#     327
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\tenacity\__init__.py in reraise(self)
#     156     def reraise(self) -> t.NoReturn:
#     157         if self.last_attempt.failed:
# --> 158             raise self.last_attempt.result()
#     159         raise self
#     160
#
# c:\Users\z003mxpm\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# c:\Users\z003mxpm\Anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#     384                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\langchain\llms\openai.py in _completion_with_retry(**kwargs)
#     111     @retry_decorator
#     112     def _completion_with_retry(**kwargs: Any) -> Any:
# --> 113         return llm.client.create(**kwargs)
#     114
#     115     return _completion_with_retry(**kwargs)
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\openai\api_resources\chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     153         )
#     154
# --> 155         response, _, api_key = requestor.request(
#     156             "post",
#     157             url,
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\openai\api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     297             request_timeout=request_timeout,
#     298         )
# --> 299         resp, got_stream = self._interpret_response(result, stream)
#     300         return resp, got_stream, self.api_key
#     301
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\openai\api_requestor.py in _interpret_response(self, result, stream)
#     708         else:
#     709             return (
# --> 710                 self._interpret_response_line(
#     711                     result.content.decode("utf-8"),
#     712                     result.status_code,
#
# c:\Users\z003mxpm\Anaconda3\lib\site-packages\openai\api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     773         stream_error = stream and "error" in resp.data
#     774         if stream_error or not 200 <= rcode < 300:
# --> 775             raise self.handle_error_response(
#     776                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777             )
#
# RateLimitError: Rate limit reached for gpt-4-1106-preview in organization org-ETO7hv3Zc6cvPXSTScQLVTnL on tokens per day (TPD): Limit 500000, Used 498375, Requested 5172. Please try again in 10m12.921s. Visit https://platform.openai.com/account/rate-limits to learn more.

# %%
for chunk_idx in range(0,rf.shape[0],10):
    try:
        print(rf[chunk_idx:chunk_idx+10]['city'].values.tolist())
    except:
        print(rf[chunk_idx:]['city'].values.tolist())
# Out:
# ['Tokyo', 'Jakarta', 'Delhi', 'Mumbai', 'Manila', 'Seoul', 'Cairo', 'Dhaka', 'Bangkok', 'Moscow']
# ['Moscow', 'Istanbul', 'Istanbul', 'Karachi', 'Bangalore', 'Ho Chi Minh City', 'Tehran', 'Chennai', 'Lahore', 'London']
# ['Paris', 'Nagoya', 'Taipei', 'Kuala Lumpur', 'Hanoi', 'Pune', 'Ahmedabad', 'Riyadh', 'Madrid', 'Baghdad']
# ['Singapore', 'Prayagraj', 'Giza', 'Ankara', 'Ankara', 'Saint Petersburg', 'Saint Petersburg', 'Alexandria', 'Barcelona', 'Berlin']
# ['İzmir', 'İzmir', 'Kabul', 'Amman', 'Jeddah', 'Yokohama', 'Busan', 'Lucknow', 'Mashhad', 'Dubai']
# ['Faisalabad', 'Jaipur', 'Jaipur', 'Athens', 'Taichung', 'Kuwait City', 'Budapest', 'Quezon City', 'Kyiv', 'Sanaa']
# ['Incheon', 'Birmingham', 'Bursa', 'Bursa', 'Rome', 'Pyongyang', 'Stuttgart', 'Kaohsiung', 'Lisbon', 'Manchester']
# ['Munich', 'Tashkent', 'Hamburg', 'Daegu', 'Antalya', 'Antalya', 'Colombo', 'Baku', 'Baku', 'Fukuoka']
# ['Konya', 'Konya', 'Phnom Penh', 'Haiphong', 'Rawalpindi', 'Vadodara', 'Gujranwala', 'Gaziantep', 'Gaziantep', 'Minsk']
# ['Indore', 'Şanlıurfa', 'Şanlıurfa', 'Vienna', 'Karaj', 'Peshawar', 'Sapporo', 'Aleppo', 'Almaty', 'Almaty']
# ['Bucharest', 'Multan', 'Tainan', 'Warsaw', 'Mersin', 'Mersin', 'Adana', 'Adana', 'Damascus', 'Diyarbakır']
# ['Diyarbakır', 'Mosul', 'Patna', 'Mecca', 'Novosibirsk', 'Novosibirsk', 'Stockholm', 'Madurai', 'Jamshedpur', 'Sofia']
# ['Kawasaki', 'Kawasaki', 'Gwangju', 'Gwangju', 'Abu Dhabi', 'Daejeon', 'Yekaterinburg', 'Yekaterinburg', 'Amsterdam', 'Kharkiv']
# ['Khulna', 'Muscat', 'Ulaanbaatar', 'Kayseri', 'Kayseri', 'Belgrade', 'Milan', 'Copenhagen', 'Samsun', 'Samsun']
# ['Saitama', 'Mandalay', 'Meerut', 'Porto', 'Helsinki', 'Jabalpur', 'Sharjah', 'Kazan', 'Kazan', 'Suwon']
# ['Cần Thơ', 'Chelyabinsk', 'Chelyabinsk', 'Qom', 'Hiroshima', 'Chiang Mai', 'Doha', 'Medina', 'Omsk', 'Omsk']
# ['Bandar Lampung', 'Samara', 'Samara', 'Ulsan', 'Amritsar', 'Tbilisi', 'Ufa', 'Ufa', 'Biên Hòa', 'Krasnoyarsk']
# ['Krasnoyarsk', 'Cologne', 'Bishkek', 'Yerevan', 'Gwalior', 'Goyang', 'Oslo', 'Sendai', 'Voronezh', 'Voronezh']
# ['Perm', 'Perm', 'Changwon', 'Jodhpur', 'Shymkent', 'Shymkent', 'Denizli', 'Denizli', 'Volgograd', 'Volgograd']
# ['Islamabad', 'Raipur', 'Raipur', 'Kota', 'Kota', 'Quetta', 'Kathmandu', 'Jerusalem', 'Riga', 'Dushanbe']
# ['Ashgabat', 'Zagreb', 'Vilnius', 'The Hague', 'Bratislava', 'Manama', 'Tallinn', 'Beirut', 'Tirana', 'Sarajevo']
# ['Nicosia', 'Ljubljana', 'New Delhi', 'Gibraltar', 'Podgorica', 'Bern', 'Reykjavík', 'Luxembourg', 'Thimphu', 'Bandar Seri Begawan']
# ['Saint Helier', 'Andorra la Vella', 'Bareilly', 'Chiba', 'Dnipro', 'Zamboanga City', 'Kirkuk', 'Naples', 'Cebu City', 'Coimbatore']
# ['Krasnodar', 'Krasnodar', 'Antipolo', 'Bucheon', 'Klang', 'Gurgaon', 'Turin', 'Jalandhar', 'Marseille', 'Eskişehir']
# ['Eskişehir', 'Liverpool', 'Ipoh', 'Portsmouth', 'Southampton', 'Saratov', 'Saratov', 'Erbil', 'Cheongju', 'Sakai']
# ['Sakai', 'Sakai', 'Kraków', 'George Town', 'Niigata', 'Leeds', 'Hamamatsu', 'Bilbao', 'Homs', 'Nottingham']
# ['Erzurum', 'Erzurum', 'Frankfurt', 'Bahawalpur', 'Thiruvananthapuram', 'Tyumen', 'Tyumen', 'Zaporizhzhia', 'Kumamoto', 'Valenzuela']
# ['Cagayan de Oro', 'Lviv', 'Sagamihara', 'Okayama', 'Latakia', 'Bhiwandi', 'Dasmariñas', 'Warangal', 'Salem', 'General Santos']
# ['Bacoor', 'Vellore', 'Łódź', 'Shizuoka', 'Kochi', 'Rasht', 'Gorakhpur', 'Wrocław', 'Palermo', 'Sargodha']
# ['San Jose del Monte', 'Ansan', 'Huế', 'Düsseldorf', 'Izhevsk', 'Izhevsk', 'Petaling Jaya', 'Noida', 'Jeonju', 'Barnaul']
# ['Barnaul', 'Rotterdam', 'Kryvyi Rih', 'Bhilai', 'Bhilai', 'Glasgow', 'Namangan', 'Ulyanovsk', 'Ulyanovsk', 'Irkutsk']
# ['Irkutsk', 'Khabarovsk', 'Khabarovsk', 'Leipzig', 'Gothenburg', 'Yaroslavl', 'Yaroslavl', 'Kuantan', 'Cuttack', 'Haifa']
# ['Bacolod', 'Bacolod', 'Kawaguchi', 'Kagoshima', 'Makhachkala', 'Makhachkala', 'Dortmund', 'Shah Alam', 'Essen', 'Mymensingh']
# ['Anyang', 'Genoa', 'Tomsk', 'Tomsk', 'Bristol', 'Irbid', 'Bremen', 'Orenburg', 'Orenburg', 'Dresden']
# ['Nellore', 'Ajmer', 'Poznań', 'Samarkand', 'Ryazan', 'Ryazan', 'Astrakhan', 'Astrakhan', 'Lyon', 'Antwerp']
# ['Yazd', 'Agartala', 'Himeji', 'Bắc Ninh', 'Penza', 'Penza', 'Port Said', 'Sevastopol', 'Pohang', 'Sheffield']
# ['Utsunomiya', 'Suez', 'Nuremberg', 'Ujjain', 'Hải Dương', 'Leicester', 'Aden', 'Matsuyama', 'Matsudo', 'Ichikawa']
# ['Ichikawa', 'Imus', 'Jammu', 'Kirov', 'Kirov', 'Kirov', 'Kirov', 'Sukkur', 'Johor Bahru', 'Duisburg']
# ['Toulouse', 'Kota Bharu', 'Vinh', 'Larkana', 'Cheboksary', 'Cheboksary', 'Edinburgh', 'Belgaum', 'Tula', 'Tula']
# ['Gdańsk', 'Sylhet', 'Gaya', 'Chiniot', 'Ōita', 'Kaliningrad', 'Kaliningrad', 'Kurashiki', 'Kanazawa', 'Piraeus']
# ['Jalgaon', 'Fukuyama', 'Amagasaki', 'Pyeongtaek', 'Kurnool', 'General Trias', 'Kota Kinabalu', 'Stavropol', 'Stavropol', 'Udaipur']
# ['Udaipur', 'Udaipur', 'Batman', 'Batman', 'Taoyuan District', 'Kahramanmaraş', 'Kahramanmaraş', 'Fujisawa', 'Zürich', 'Machida']
# ['Ulan-Ude', 'Ulan-Ude', 'Kashiwa', 'Jeju', 'Masan', 'Tver', 'Tver', 'Trabzon', 'Trabzon', 'Malatya']
# ['Malatya', 'Uijeongbu', 'Akola', 'Aomori', 'Toyota', 'Santa Rosa', 'Santa Rosa', 'Elazığ', 'Elazığ', 'Hpa-An']
# ['Seremban', 'Magnitogorsk', 'Magnitogorsk', 'Takamatsu', 'Biñan', 'Paju', 'Toyama', 'Sanandaj', 'Toyonaka', 'Türkmenabat']
# ['Bryansk', 'Bryansk', 'Nagasaki', 'Szczecin', 'Hirakata', 'Gifu', 'Dera Ghazi Khan', 'Miyazaki', 'Sandakan', 'Thanh Hóa']
# ['Surgut', 'Surgut', 'Belgorod', 'Belgorod', 'Yokosuka', 'Nha Trang', 'Malabon', 'Bologna', 'Plovdiv', 'Tarlac City']
# ['Okazaki', 'Florence', 'Novi Sad', 'Kaunas', 'Ichinomiya', 'Ichinomiya', 'Taunggyi', 'Sivas', 'Sivas', 'Stoke-on-Trent']
# ['Rohtak', 'Vinnytsia', 'Takasaki', 'Butuan', 'Toyohashi', 'Keelung', 'Bharatpur', 'Az Zubayr', 'Nagano', 'Bochum']
# ['Coventry', 'Cibinong', 'Iligan', 'Cabuyao', 'Nakano', 'Nakano', 'Utrecht', 'Pokhara', 'Hrodna', 'Nam Định']
# ['Vladimir', 'Vladimir', 'Kawagoe', 'Kawagoe', 'Taraz', 'Taraz', 'Ibb', 'Ibb', 'Wuppertal', 'Manisa']
# ['Manisa', 'San Fernando', 'San Fernando', 'San Fernando', 'San Fernando', 'San Fernando', 'San Fernando', 'San Fernando', 'San Pedro', 'Wakayama']
# ['Pavlodar', 'Pavlodar', 'Gimpo', 'Nara', 'Van', 'Van', 'Koshigaya', 'Varna', 'Takatsuki', 'Semey']
# ['Semey', 'Bydgoszcz', 'Chita', 'Chita', 'Nice', 'Tokorozawa', 'Simferopol', 'Vũng Tàu', 'Brest', 'Yeosu']
# ['Yeosu', 'Kaluga', 'Kaluga', 'Muzaffarpur', 'Alwar', 'Lublin', 'Buôn Ma Thuột', 'Alicante', 'Tarsus', 'Tarsus']
# ['Belfast', 'Iwaki', 'Hirosaki', 'Bielefeld', 'Tampere', 'Bonn', 'Asan', 'Asan', 'Maebashi', 'Balıkesir']
# ['Balıkesir', 'Thái Nguyên', 'Asahikawa', 'Smolensk', 'Smolensk', 'Debrecen', 'Kōchi', 'Bielsko-Biała', 'Cluj-Napoca', 'Bari']
# ['Kuching', 'Naha', 'Nantes', 'Osh', 'Aksaray', 'Aksaray', 'Saransk', 'Saransk', 'Nukus', 'Münster']
# ['Münster', 'Cà Mau', 'Kasur', 'Kingston upon Hull', 'Mannheim', 'Alanya', 'Alanya', 'Yakutsk', 'Yakutsk', 'Yokkaichi']
# ['Catania', 'Karlsruhe', 'Kurgan', 'Kurgan', 'Kasugai', 'Hisar', 'Hisar', 'Puerto Princesa', 'Adıyaman', 'Adıyaman']
# ['Kurume', 'Vila Nova de Gaia', 'Akita', 'Iksan', 'Montpellier', 'Phan Thiết', 'Białystok', 'Chakwal', 'Afyonkarahisar', 'Afyonkarahisar']
# ['İskenderun', 'İskenderun', 'Augsburg', 'Navotas', 'Yangsan', 'Bradford', 'Tagum', 'Espoo', 'Rangpur', 'Vigo']
# ['Çorum', 'Çorum', 'Ismailia', 'Strasbourg', 'Mabalacat', 'Tambov', 'Tambov', 'Graz', 'Morioka', 'Ichalkaranji']
# ['Ibaraki', 'Ibaraki', 'Katowice', 'Bolton', 'San Pablo', 'San Pablo', 'San Pablo', 'Aarhus', 'Myeik', 'Fukushima']
# ['Bago', 'Sterlitamak', 'Sterlitamak', 'Lucena', 'Lucena', 'Chuncheon', 'Satna', 'Long Xuyên', 'Petrozavodsk', 'Petrozavodsk']
# ['Wiesbaden', 'Bukhara', 'Việt Trì', 'Sunderland', 'Maastricht', 'Çorlu', 'Çorlu', 'Gyeongsan', 'Mamuju', 'Nizhnevartovsk']
# ['Nizhnevartovsk', 'Qarshi', 'Tsu', 'Novorossiysk', 'Novorossiysk', 'Székesfehérvár', 'Craiova', 'Thái Bình', 'Fuchū', 'Fuchū']
# ['Mito', 'Plymouth', 'Talisay', 'Talisay', 'Talisay', 'Talisay', 'Yoshkar-Ola', 'Yoshkar-Ola', 'Ichihara', 'Zhytomyr']
# ['İnegöl', 'İnegöl', 'Chernivtsi', 'Bergen', 'Kütahya', 'Kütahya', 'Yao', 'Bordeaux', 'Nagaoka', 'Nagaoka']
# ['Suncheon', 'Engels', 'Engels', 'Malolos', 'Osmaniye', 'Osmaniye', 'Nawabshah', 'Gelsenkirchen', 'Mönchengladbach', 'Nonthaburi']
# ['Fukui', 'Venice', 'Quảng Ngãi', 'Olongapo', 'Hiratsuka', 'Kotri', 'Isparta', 'Isparta', 'Derby', 'Verona']
# ['Siverek', 'Siverek', 'Tokushima', 'Kuala Terengganu', 'Wolverhampton', 'Bharatpur', 'Tacloban', 'Turku', 'Rạch Giá', 'Kanggye']
# ['Taganrog', 'Taganrog', 'Kızıltepe', 'Kızıltepe', 'Hakodate', 'Uşak', 'Uşak', 'Begusarai', 'Aachen', 'Yanbu']
# ['Gdynia', 'Chemnitz', 'Chigasaki', 'Sahiwal', 'Kiel', 'Sibu', 'Yamagata', 'Yamagata', 'Syktyvkar', 'Syktyvkar']
# ['Győr', 'Hafizabad', 'Tuy Hòa', 'Fuji', 'Mokpo', 'Sasebo', 'Myitkyina', 'Haeju', 'Lille', 'Düzce']
# ['Düzce', 'Anju', 'Stavanger', 'Limassol', 'Ivano-Frankivsk', 'Halle', 'Halle', 'Szeged', 'Košice', 'Matsumoto']
# ['Nyíregyháza', 'Eindhoven', 'Mirpur Khas', 'Sandnes', 'Pathein', 'Nizhnekamsk', 'Nizhnekamsk', 'Magdeburg', 'Shakhty', 'Shakhty']
# ['Elche', 'Groningen', 'Miri', 'Messina', 'Oral', 'Oral', 'Badalona', 'Okara', 'Freiburg im Breisgau', 'Saga']
# ['Meycauayan', 'Kasukabe', 'Barishal', 'Purwokerto', 'Ormoc', 'Orsk', 'Orsk', 'Vizianagaram', 'Ordu', 'Ordu']
# ['Krefeld', 'Kolpino', 'Kolpino', 'Daşoguz', 'Takarazuka', 'Rennes', 'Ashdod', 'Częstochowa', 'Tilburg', 'Hachinohe']
# ['Swindon', 'Lutsk', 'Sambhal', 'Sabadell', 'Radom', 'Santo Tomas', 'Santo Tomas', 'Santo Tomas', 'Santo Tomas', 'Santo Tomas']
# ['Damietta', 'Mainz', 'Konibodom', 'Pleiku', 'Osan', 'Netanya', 'Oviedo', 'Alor Setar', 'Lübeck', 'Zielona Góra']
# ['Valencia', 'Valencia', 'Valencia', 'Norwich', 'Petropavl', 'Petropavl', 'Gangneung', 'Almere', 'Vantaa', 'Geneva']
# ['Shimla', 'Babruysk', 'Erfurt', 'Móstoles', 'Jerez de la Frontera', 'Puri', 'Kure', 'Linz', 'Oberhausen', 'Mytishchi']
# ['Mytishchi', 'Pskov', 'Pskov', 'Isesaki', 'Burgas', 'Chungju', 'Pagadian', 'Bukit Mertajam', 'Sidon', 'Rostock']
# ['Panabo', 'Solihull', 'Milton Keynes', 'Beersheba', 'Oulu', 'Mary', 'Toledo', 'Kharagpur', 'Kharagpur', 'Monywa']
# ['Dindigul', 'Trieste', 'Kodaira', 'Itami', 'Loures', 'Nagareyama', 'Ongole', 'Bolu', 'Bolu', 'Sejong']
# ['Yachiyo', 'Yachiyo', 'Vĩnh Long', 'Tekirdağ', 'Tekirdağ', 'Holon', 'Biysk', 'Biysk', 'Charleroi', 'Aberdeen']
# ['Deoghar', 'Toruń', 'Kassel', 'Haldia', 'Luxor', 'Matsue', 'Jacobabad', 'Tokat', 'Tokat', 'Kabankalan']
# ['Lahad Datu', 'Liège', 'Banja Luka', 'Taranto', 'Martapura', 'Chakradharpur', 'Oradea', 'Madhyamgram', 'Rzeszów', 'Hino']
# ['Hino', 'Fuenlabrada', 'Brescia', 'Parma', 'Suzuka', 'Koronadal', 'Koronadal', 'Viranşehir', 'Viranşehir', 'Karaköprü']
# ['Karaköprü', 'Sosnowiec', 'Tanauan', 'Tanauan', 'Trondheim', 'Prato', 'Anseong', 'Yuzhno-Sakhalinsk', 'Yuzhno-Sakhalinsk', 'Narsingdi']
# ['Peterborough', 'Kumagaya', 'Rijeka', 'Karaman', 'Karaman', 'Yamaguchi', 'Muş', 'Muş', 'Hyesan', 'Kielce']
# ['Kırıkkale', 'Kırıkkale', 'Bago', 'Bournemouth', 'Armavir', 'Armavir', 'Balakovo', 'Balakovo', 'Aydın', 'Aydın']
# ['Malaybalay', 'Odawara', 'Kishiwada', 'Shahr-e Kord', 'Rybinsk', 'Rybinsk', 'Hagen', 'Pak Kret', 'Braga', 'Digos']
# ['Numazu', 'Tachikawa', 'Kecskemét', 'Tottori', 'Reims', 'Breda', 'Modena', 'Guri', 'Basel', 'Toyokawa']
# ['Chūō-ku', 'Potsdam', 'Niš', 'Narashino', 'Odense', 'Toulon', 'Amadora', 'Brăila', 'Uji', 'York']
# ['Sittwe', 'Jaunpur', 'Çanakkale', 'Çanakkale', 'Nijmegen', 'Saarbrücken', 'Edirne', 'Edirne', 'Purwakarta', 'Split']
# ['Hamm', 'Almada', 'Urayasu', 'Matosinhos', 'Baranavichy', 'Saint-Étienne', 'Ereğli', 'Ereğli', 'Ereğli', 'Ereğli']
# ['Chandannagar', 'Cuddalore', 'Olsztyn', 'Gliwice', 'Cianjur', 'Tyre', 'Menemen', 'Menemen', 'Ludwigshafen', 'Deo']
# ['Hitachi', 'Le Havre', 'Banyuwangi', 'Reggio Emilia', 'Izumo', 'Oldenburg', 'Niiza', 'Batumi', 'Ramat Gan', 'Kohat']
# ['Sakura', 'Sakura', 'Uppsala', 'Uppsala', 'Tomakomai', 'Novocherkassk', 'Novocherkassk', 'Nishio', 'Warrington', 'Gondomar']
# ['Oyama', 'Oyama', 'Zlatoust', 'Zlatoust', 'Haarlem', 'Tuguegarao', 'Grenoble', 'Iwata', 'Takaoka', 'Siirt']
# ['Siirt', 'Osnabrück', 'Körfez', 'Körfez', 'Perugia', 'Obihiro', 'Leverkusen', 'Klaipėda', 'Hadano', 'Kushiro']
# ['Kushiro', 'Idlib', 'Arnhem', 'Kandy', 'Saqqez', 'Huddersfield', 'Muridke', 'Turgutlu', 'Turgutlu', 'Pocheon']
# ['Ube', 'Gölcük', 'Gölcük', 'Muzaffargarh', 'Godhra', 'Villeurbanne', 'Zemun', 'Musashino', 'Andong', 'Dijon']
# ['Chittoor', 'Salihli', 'Salihli', 'Apeldoorn', 'Đồng Hới', 'Krishnanagar', 'Kidapawan', 'Solingen', 'Darmstadt', 'Enschede']
# ['Heidelberg', 'Ceyhan', 'Ceyhan', 'Newport', 'Newport', 'Newport', 'Arad', 'Zabrze', 'Bingöl', 'Bingöl']
# ['Miyakonojō', 'Seixal', 'Livorno', 'Ekibastuz', 'Ekibastuz', 'Hat Yai', 'Herne', 'Chirchiq', 'Angers', 'Ravenna']
# ['Higashimurayama', 'Cadiz', 'Châu Đốc', 'Guimarães', 'Tigaraksa', 'Ilagan', 'Gojra', 'Fethiye', 'Fethiye', 'Saharsa']
# ['Danao', 'Danao', 'Erzincan', 'Erzincan', 'Salzburg', 'Mandi Bahauddin', 'Nazilli', 'Nazilli', 'Hanam', 'Vidisha']
# ['Cẩm Phả', 'Kariya', 'Kariya', 'Almetyevsk', 'Almetyevsk', 'Bytom', 'Regensburg', 'Oxford', 'Neuss', 'Bartın']
# ['Bartın', 'San Juan', 'San Juan', 'San Juan', 'San Juan', 'San Juan', 'San Juan', 'San Juan', 'Dibrugarh', 'Edremit']
# ['Edremit', 'Bandırma', 'Bandırma', 'Salavat', 'Salavat', 'Tama', 'Tama', 'Seogwipo', 'Tochigi', 'Noda']
# ['San Jose', 'San Jose', 'San Jose', 'San Jose', 'San Jose', 'San Jose', 'San Jose', 'San Jose', 'San Jose', 'Kırşehir']
# ['Kırşehir', 'Sinpo', 'Paderborn', 'Nevşehir', 'Nevşehir', 'Ueda', 'Moriguchi', 'Siem Reap', 'Erode', 'Gwangyang']
# ['Marbella', 'Asaka', 'Foggia', 'Sayama', 'Jaranwala', 'Miskolc', 'Clermont-Ferrand', 'Kerch', 'Kragujevac', 'Nîmes']
# ['Rimini', 'Komaki', 'Toda', 'Kutaisi', 'Odivelas', 'Saumlaki', 'Gloucester', 'Imabari', 'Abbottabad', 'West Bromwich']
# ['Sagay', 'Sagay', 'Ağrı', 'Ağrı', 'Amasya', 'Amasya', 'Santiago', 'Santiago', 'Santiago', 'Iruma']
# ['Kastamonu', 'Kastamonu', 'Szombathely', 'Sibiu', 'Yonago', 'Dundee', 'Kopeysk', 'Kopeysk', 'Lüleburgaz', 'Lüleburgaz']
# ['Mati', 'Bacău', 'Rubtsovsk', 'Rubtsovsk', 'Negombo', 'Cam Ranh', 'Cam Ranh', 'Dadu', 'Misato', 'Misato']
# ['Misato', 'Le Mans', 'Etah', 'Calapan', 'Urdaneta', 'Aalborg', 'Aix-en-Provence', 'Yalova', 'Yalova', 'Berezniki']
# ['Berezniki', 'Shillong', 'Kusatsu', 'Kakamigahara', 'Okinawa', 'Khasavyurt', 'Khasavyurt', 'Ruse', 'Coimbra', 'Birkenhead']
# ['Ashikaga', 'Cizre', 'Cizre', 'Telford', 'Preston', 'Brest', 'Nizip', 'Nizip', 'Lausanne', 'Bahawalnagar']
# ['Maykop', 'Maykop', 'Tabaco', 'Mandsaur', 'Boulogne-Billancourt', 'Rybnik', 'Rize', 'Rize', 'Vlorë', 'Jahrom']
# ['Jyväskylä', 'Middlesbrough', 'Khuzdar', 'Pécs', 'Tours', 'Kokubunji', 'Ebina', 'Dawei', 'Kuwana', 'Pakpattan']
# ['Minō', 'Koga', 'Koga', 'Ingolstadt', 'Bat Yam', 'Tsuchiura', 'Dipolog', 'Koganei', 'Zama', 'Shūnan']
# ['Mandya', 'Iğdır', 'Iğdır', 'Carcar', 'Amiens', 'Vila Franca de Xira', 'Kisarazu', 'Gingoog', 'Maia', 'Yaizu']
# ['Inazawa', 'Stara Zagora', 'Tiraspol', 'Giresun', 'Giresun', 'Salerno', 'Brighton', 'Ruda Śląska', 'Zafarwal', 'Silopi']
# ['Silopi', 'Nakhon Ratchasima', 'Mörön', 'Naga', 'Naga', 'Veszprém', 'Navoiy', 'Tando Allahyar', 'Isahaya', 'Innsbruck']
# ['Hassan', 'Abiko', 'Limoges', 'San Carlos', 'Lincoln', 'Annecy', 'Mogaung', 'Ödemiş', 'Ödemiş', 'Kamëz']
# ['Ferrara', 'Karabük', 'Karabük', 'Surat Thani', 'Narita', 'Fürth', 'Fürth', 'Lashio', 'Silay', 'Zwolle']
# ['Tychy', 'Rustavi', 'Rustavi', 'Onomichi', 'Kozan', 'Kozan', 'Udon Thani', 'Battambang', 'Leiden', 'Ergani']
# ['Ergani', 'Çayırova', 'Çayırova', 'Västerås', 'Würzburg', 'Opole', 'Novocheboksarsk', 'Novocheboksarsk', 'Örebro', 'Zoetermeer']
# ['Iwakuni', 'Seto', 'Bataysk', 'Bataysk', 'Pinsk', 'Nefteyugansk', 'Nefteyugansk', 'Ulm', 'Kadoma', 'Kaspiysk']
# ['Kaspiysk', 'Heilbronn', 'Anderlecht', 'Neftekamsk', 'Neftekamsk', 'Bam', 'High Wycombe', 'Monza', 'Pforzheim', 'Rosetta']
# ['Angren', 'Leiria', 'Latina', 'Cambridge', 'Ünye', 'Ünye', 'Exeter', 'Iizuka', 'Rishra', 'Panevėžys']
# ['Kampong Cham', 'Novomoskovsk', 'Novomoskovsk', 'Giugliano in Campania', 'Indramayu', 'Colchester', 'Polatlı', 'Polatlı', 'Leeuwarden', 'Wolfsburg']
# ['Savannakhet', 'Gorzów Wielkopolski', 'Gyumri', 'Pervouralsk', 'Pervouralsk', 'Montreuil', 'Algeciras', 'Hội An', 'Setúbal', 'Matsubara']
# ['Baia Mare', 'Kadirli', 'Kadirli', 'Cherkessk', 'Cherkessk', 'Bergamo', 'Kirishima', 'Gapan', 'Uruma', 'Derbent']
# ['Derbent', 'Ise', 'Patnos', 'Patnos', 'Bayawan', 'Kâhta', 'Kâhta', 'Slough', 'Pescara', 'Fier']
# ['Kamalia', 'Saint-Denis', 'Kashiwara', 'Kashiwara', 'Urasoe', 'Hòa Bình', 'Kuopio', 'Samandağ', 'Samandağ', 'Tsuruoka']
# ['Soreang', 'Metz', 'Płock', 'Tabuk', 'Tabuk', 'Perpignan', 'Kot Addu', 'Zonguldak', 'Zonguldak', 'Göttingen']
# ['Barcelos', 'Darjeeling', 'Orléans', 'Ebetsu', 'Fujimino', 'Dordrecht', 'Besançon', 'Handa', 'Chelmsford', 'Yüksekova']
# ['Yüksekova', 'Pleven', 'Elbląg', 'Bruges', 'Kasuga', 'Cheltenham', 'Nevinnomyssk', 'Nevinnomyssk', 'Lahti', 'Dimitrovgrad']
# ['Dimitrovgrad', 'Ikoma', 'Nowshera', 'Akishima', 'Ligao', 'Bottrop', 'Linköping', 'Forlì', 'Niğde', 'Niğde']
# ['Aizuwakamatsu', 'Nobeoka', 'Reutlingen', 'Uzhhorod', 'Obninsk', 'Obninsk', 'Rouen', 'Dąbrowa Górnicza', 'Fujimi', 'Fujimi']
# ['Argenteuil', 'Wałbrzych', 'Samal', 'Samal', 'Manpo', 'Beppu', 'Sassari', 'Buzău', 'Helsingborg', 'Himamaylan']
# ['Swabi', 'Khon Kaen', 'Karatsu', 'Kilis', 'Kilis', 'Sandvika', 'Kars', 'Kars', 'Nasushiobara', 'Durrës']
# ['Berdiansk', 'Niihama', 'Sliven', 'Sano', 'Koblenz', 'Hatsukaichi', 'Bijeljina', 'Erlangen', 'Bremerhaven', 'Kamagaya']
# ['Alphen aan den Rijn', 'Rotherham', 'Kakegawa', 'Kuşadası', 'Kuşadası', 'Kristiansand', 'Recklinghausen', 'Nagahama', 'Tawau', 'Mulhouse']
# ['Hōfu', 'Hikone', 'Midyat', 'Midyat', 'Bergisch Gladbach', 'Remscheid', 'Burdur', 'Burdur', 'Tayabas', 'Vicenza']
# ['Otaru', 'Kaposvár', 'Laoag', 'Champdani', 'Ōshū', 'Zahlé', 'Habikino', 'Kamyshin', 'Kamyshin', 'Doncaster']
# ['Shkodër', 'Jena', 'Trincomalee', 'Olmaliq', 'Baybay', 'Nancy', 'Ichinoseki', 'Funchal', 'Terni', 'Trier']
# ['Namur', 'Murom', 'Murom', 'Kazo', 'Khardah', 'Ōmuta', 'Winterthur', 'Tuzla', 'Tarnów', 'Khushab']
# ['Basingstoke', 'Nikopol', 'Caen', 'Marugame', 'Bangaon', 'Bangaon', 'Bangaon', 'Tacurong', 'Dera Ismail Khan', 'Cavite City']
# ['Yevpatoriia', 'Carmona', 'Bayugan', 'Soma', 'Soma', 'Novoshakhtinsk', 'Novoshakhtinsk', 'Douliu', 'Žilina', 'Ikeda']
# ['Ikeda', 'Ikeda', 'Salford', 'Šiauliai', 'Seversk', 'Seversk', 'Koszalin', 'Tajimi', 'Delft', 'Chaman']
# ['Charsadda', 'Manokwari', 'Bolzano', 'Chorzów', 'Erdenet', 'Noyabrsk', 'Noyabrsk', 'Catbalogan', 'Nakhon Si Thammarat', 'Kemalpaşa']
# ['Kemalpaşa', 'Komatsu', 'Roubaix', 'Achinsk', 'Achinsk', 'Nusaybin', 'Nusaybin', 'Kiryū', 'Ourense', 'Mazyr']
# ['Kandhkot', 'Toride', 'Ōnojō', 'Moers', 'Yozgat', 'Yozgat', 'Novara', 'Tourcoing', 'Balanga', 'Salzgitter']
# ['Berdsk', 'Berdsk', 'Worcester', 'Włocławek', 'Nanterre', 'Sergiyev Posad', 'Sergiyev Posad', 'Inzai', 'Chikushino', 'Ginowan']
# ['Kamianets-Podilskyi', 'Elista', 'Elista', 'Kalyani', 'Saijō', 'Isehara', 'Eastbourne', 'Pazardzhik', 'Wigan', 'Siegen']
# ['Vitry-sur-Seine', 'Sakado', 'Novokuybyshevsk', 'Novokuybyshevsk', 'Bergama', 'Bergama', 'Piacenza', 'Miryang', 'Tanjungpandan', 'Hildesheim']
# ['Satu Mare', 'Sangju', 'Bhadreswar', 'Leuven', 'Klagenfurt', 'Chishtian', 'Gütersloh', 'Boryeong', 'Deventer', 'Zheleznogorsk']
# ['Zheleznogorsk', 'Zheleznogorsk', 'Zheleznogorsk', 'Yên Bái', 'Créteil', 'Kawachinagano', 'Kanoya', 'Ancona', 'Port Blair', 'Kaiserslautern']
# ['Gangtok', 'Ahar', 'Kōnan', 'Kōnan', 'Lamitan', 'Shahrisabz', 'Aubervilliers', 'Nabire', 'Râmnicu Vâlcea', 'Viseu']
# ['Maribor', 'Ashiya', 'Ashiya', 'Sopron', 'Galle', 'Yashio', 'Bath', 'Inagi', 'Vị Thanh', 'Colombes']
# ['Pernik', 'Komae', 'Schwerin', 'Çankırı', 'Çankırı', 'Ludwigsburg', 'Nisshin', 'Prizren', 'Drobeta-Turnu Severin', 'Tartu']
# ['Suceava', 'Şırnak', 'Şırnak', 'Bender', 'Jaffna', 'Queluz', 'Aulnay-sous-Bois', 'Settsu', 'Poitiers', 'Chester']
# ['Ama', 'Kitanagoya', 'Dobrich', 'Higashiyamato', 'Catanzaro', 'Valjevo', 'Jalal-Abad', 'Prešov', 'Warabi', 'Balkanabat']
# ['Mechelen', 'Al Wakrah', 'Viana do Castelo', 'Ayase', 'Maasin', 'Maasin', 'Maasin', 'Mardin', 'Mardin', 'Larnaca']
# ['Nakhon Sawan', 'Loznica', 'Owariasahi', 'Kouvola', 'Karakol', 'Como', 'Shumen', 'Pori', 'Veliko Tarnovo', 'Purmerend']
# ['Nazareth', 'Osijek', 'Lucerne', 'Kunitachi', 'Phuket', 'Champigny-sur-Marne', 'Haskovo', 'Rueil-Malmaison', 'Kirtipur', 'Schiedam']
# ['Târgu Jiu', 'Kiyose', 'Elbasan', 'Bilecik', 'Bilecik', 'Daugavpils', 'Kashiba', 'Rubí', 'Barreiro', 'Cabadbaran']
# ['La Rochelle', 'Izumiōtsu', 'Lelystad', 'Avilés', 'Nakhon Pathom', 'Ubon Ratchathani', 'Carlisle', 'Nitra', 'Banská Bystrica', 'Katano']
# ['Aveiro', 'Pau', 'Bokhtar', 'Cannes', 'Gladbeck', 'Okegawa', 'Zrenjanin', 'Pančevo', 'Vlaardingen', 'Jōyō']
# ['Antibes', 'Ramla', 'Zadar', 'Musashimurayama', 'Joensuu', 'Calais', 'Kiyosu', 'Dazaifu', 'Inowrocław', 'Hekinan']
# ['Yoshikawa', 'Tsurugashima', 'Tulcea', 'Blagoevgrad', 'Thakhèk', 'Lappeenranta', 'Oroquieta', 'Toyoake', 'Ajaccio', 'Borongan']
# ['Matara', 'Čačak', 'Sihanoukville', 'Givatayim', 'Yambol', 'Bitlis', 'Bitlis', 'Phitsanulok', 'Điện Biên Phủ', 'Novi Pazar']
# ['Gardēz', 'Chiang Rai', 'Fujiidera', 'Sagaing', 'Szolnok', 'Assen', 'Castellammare di Stabia', 'Liepāja', 'Ponta Delgada', 'Pruszków']
# ['Kitamoto', 'Karlskrona', 'Tomigusuku', 'Hämeenlinna', 'Vaasa', 'Potenza', 'Siemianowice Śląskie', 'Kraljevo', 'Hereford', 'Bayburt']
# ['Bayburt', 'Trnava', 'Samut Sakhon', 'Tatabánya', 'Magong', 'Nagakute', 'Paphos', 'Songkhla', 'Tagajō', 'Wamena']
# ['Ełk', 'Faro', 'Alba Iulia', 'Yamatotakada', 'Bangor', 'Bangor', 'Seinäjoki', 'Vaslui', 'Hasuda', 'Ōsakasayama']
# ['Tsushima', 'Tsushima', 'Anuradhapura', 'Tandag', 'Rayong', 'Giurgiu', 'Rovaniemi', 'Santarém', 'Fussa', 'Kırklareli']
# ['Kırklareli', 'Vratsa', 'Yala', 'Chambéry', 'Portugalete', 'Nonoichi', 'Leskovac', 'Trang', 'Takaishi', 'Kyustendil']
# ['Tczew', 'Vejle', 'Zushi', 'Świdnica', 'Užice', 'Samut Prakan', 'Hod HaSharon', 'Hamura', 'Rijswijk', 'Kruševac']
# ['Békéscsaba', 'Shijōnawate', 'Legionowo', 'Hilden', 'Gümüşhane', 'Gümüşhane', 'Zalău', 'Muğla', 'Muğla', 'Évora']
# ['Phra Nakhon Si Ayutthaya', 'Trenčín', 'Jelgava', 'Castelo Branco', 'Rio Tinto', 'Vigan', 'Zalaegerszeg', 'Dunfermline', 'Guliston', 'Lancaster']
# ['Lampang', 'Vranje', 'Shiogama', 'Gabrovo', 'Mikkeli', 'Shiraoka', 'Korçë', 'Sakon Nakhon', 'Targovishte', 'Alytus']
# ['Bodø', 'Iwakura', 'Elmshorn', 'Takahama', 'Takahama', 'Vila Real', 'Kardzhali', 'Eger', 'Sombor', 'Jūrmala']
# ['Halle-Neustadt', 'Gori', 'Vidin', 'Świętochłowice', 'Luleå', 'Inverness', 'Salisbury', 'Ramat HaSharon', 'Middelburg', 'Birendranagar']
# ['Ripollet', 'Ząbki', 'Karmiel', 'Kokkola', 'Badulla', 'Nagykanizsa', 'Slobozia', 'Vilvoorde', 'Alexandria', 'Thun']
# ['Pinneberg', 'Bellinzona', 'Dunaújváros', 'Razgrad', 'Zugdidi', 'Xonobod', 'Kalmar', 'Matale', 'Or Yehuda', 'Mińsk Mazowiecki']
# ['Hódmezővásárhely', 'Kampong Chhnang', 'Silistra', 'Dubrovnik', 'Guarda', 'Fribourg', 'Kampot', 'Berat', 'Ardahan', 'Ardahan']
# ['Żyrardów', 'Nakama', 'Viborg', 'Panaji', 'Malbork', 'Famagusta', 'Pärnu', 'Şəmkir', 'Şəmkir', 'Lovech']
# ['Montana', 'Brčko', 'Vernier', 'Celje', 'Tromsø', 'Nyköping', 'Esch-sur-Alzette', 'Tunceli', 'Tunceli', 'Wołomin']
# ['Kranj', 'Kikinda', 'Brzeg', 'Kajaani', 'Schaffhausen', 'Prijepolje', 'Marijampolė', 'Maassluis', 'Hillerød', 'Chur']
# ['Yehud', 'Lichfield', 'Krong Kep', 'Kornwestheim', 'Beja', 'Vršac', 'Luboń', 'Bragança', 'Neuchâtel', 'Artvin']
# ['Artvin', 'Naryn', 'Naryn', 'Chichester', 'Smolyan', 'Merauke', 'Ostróda', 'Bor', 'Ventspils', 'Koh Kong']
# ['Chumphon', 'Birkirkara', 'Kyrenia', 'Mažeikiai', 'Salgótarján', 'Yverdon-les-Bains', 'Kampong Thom', 'Molde', 'Zug', 'Giżycko']
# ['Khorugh', 'Szekszárd', 'Sabirabad', 'Sabirabad', 'Ungheni', 'Bregenz', 'Carouge', 'Salyan', 'Salyan', 'Kętrzyn']
# ['Cahul', 'Dübendorf', 'Subotica', 'Stung Treng', 'Dietikon', 'Hakha', 'Nuwara Eliya', 'Mortsel', 'Samut Songkhram', 'Gedera']
# ['Rēzekne', 'Vevey', 'Hamar', 'Renens', 'Batken', 'Koper', 'San Juan de Aznalfarache', 'Velenje', 'Arar', 'Piastów']
# ['Weingarten', 'Weingarten', 'Jonava', 'Kościan', 'Meyrin', 'Utena', 'Ulaangom', 'Vukovar', 'Szczytno', 'Truro']
# ['Bartoszyce', 'Portalegre', 'Novo Mesto', 'Baalbek', 'Gjirokastër', 'Valmiera', 'Huskvarna', 'Allschwil', 'Kėdainiai', 'Opfikon']
# ['Sacavém', 'Nyon', 'Aarau', 'Ogre', 'Jēkabpils', 'Soroca', 'Telšiai', 'Thalwil', 'Reinach', 'Schlieren']
# ['Tauragė', 'Pully', 'Ukmergė', 'Orhei', 'Adliswil', 'Wolfratshausen', 'Ostermundigen', 'Szigethalom', 'Łomianki', 'Comrat']
# ['Ulcinj', 'Morges', 'Lezhë', 'Telavi', 'Herceg Novi', 'Solothurn', 'Budva', 'Binningen', 'Pljevlja', 'Wallisellen']
# ['Ptuj', 'Tsetserleg', 'Salaspils', 'Eppelheim', 'Prilly', 'Viljandi', 'Mārupe', 'Thônex', 'Kukës', 'Plungė']
# ['Kretinga', 'Marib', 'Arbon', 'Phrae', 'Astara', 'Astara', 'Tukums', 'Qusar', 'Qusar', 'Hall in Tirol']
# ['Chojnów', 'Šilutė', 'Bijelo Polje', 'Asperg', 'Schwyz', 'La Tour-de-Peilz', 'Kamnik', 'Radviliškis', 'Liestal', 'Chêne-Bougeries']
# ['Ecublens', 'Le Grand-Saconnex', 'Cēsis', 'Ozurgeti', 'Eisenstadt', 'Hambantota', 'Sigulda', 'Baruun-Urt', 'Birsfelden', 'Neftçala']
# ['Neftçala', 'Villars-sur-Glâne', 'Cetinje', 'Sjenica', 'Akhaltsikhe', 'Plav', 'Bar', 'Männedorf', 'Sinop', 'Sinop']
# ['Domžale', 'Drochia', 'Delémont', 'Druskininkai', 'Puck', 'Nova Gorica', 'Ialoveni', 'Rokiškis', 'Bulgan', 'Taraclia']
# ['Izola', 'Murska Sobota', 'Elektrėnai', 'Berane', 'Mariehamn', 'Rezina', 'Loikaw', 'Anenii Noi', 'Jurbarkas', 'Sarnen']
# ['Ordubad', 'Ordubad', 'Olaine', 'Vilkaviškis', 'Nisporeni', 'Kuldīga', 'Mojkovac', 'Glarus', 'Jagodina', 'Đà Lạt']
# ['Tanjung Selor', 'Udine', 'Kalisz', 'Izumisano', 'Legnica', 'Wakefield', 'Kani', 'Chikusei', 'Andria', 'Alaminos']
# ['Alaminos', 'Hanau', 'Hasilpur', 'Tsuyama', 'Bislig', 'Arezzo', 'Sakata', 'Cottbus', 'Itoshima', 'Saku']
# ['Dongducheon', 'Chitose', 'Witten', 'Munakata', 'Hadera', 'Lorca', 'Iida', 'Escalante', 'Ōmura', 'Kamisu']
# ['Muzaffarabad', 'Mons', 'Aliağa', 'Aliağa', 'Shimada', 'Lecce', 'Mianwali', 'Barletta', 'Valongo', 'Jaworzno']
# ['Kanuma', 'Gera', 'Grudziądz', 'Gatchina', 'Gatchina', 'Shibata', 'Shibata', 'Alessandria', 'Helmond', 'Azumino']
# ['Menderes', 'Menderes', 'Iserlohn', 'Avignon', 'Düren', 'Tatvan', 'Tatvan', 'Naju', 'Flensburg', 'Tübingen']
# ['Kitakami', 'Satsumasendai', 'Jalalpur Jattan', 'Victorias', 'Pisa', 'Zwickau', 'Mihara', 'El Puerto de Santa María', 'Aalst', 'Bogo']
# ['Lucca', 'Prijedor', 'Passi', 'Bhakkar', 'Ratingen', 'Calaca', 'Słupsk', 'Dipalpur', 'Lünen', 'Fukuroi']
# ['Paredes', 'Mobara', 'Villingen-Schwenningen', 'Kharian', 'Garulia', 'Tagaytay', 'Kameoka', 'Treviso', 'Kaizuka', 'Jastrzębie-Zdrój']
# ['Iga', 'Ushiku', 'Chita', 'Dapitan', 'Takayama', 'Derry', 'Moriyama', 'Marl', 'Worms', 'Bais']
# ['Tire', 'Tire', 'Fredrikstad', 'Bhalwal', 'Velbert', 'Tanjay', 'Nakatsu', 'Bhaktapur', 'Nowy Sącz', 'Minden']
# ['Muroran', 'Shikokuchūō', 'Hengelo', 'Bekobod', 'La Louvière', 'Varese', 'Norderstedt', 'Dessau-Roßlau', 'Kimitsu', 'Kashiwazaki']
# ['Sint-Niklaas', 'Yonezawa', 'Akiruno', 'Echizen', 'Echizen', 'Neumünster', 'Sokcho', 'Jamshoro', 'Balad', 'Vila do Conde']
# ['Torres Vedras', 'Iwamizawa', 'Skarżysko-Kamienna', 'Mooka', 'Béziers', 'Bamberg', 'Jelenia Góra', 'Maizuru', 'Kizugawa', 'Delmenhorst']
# ['Kortrijk', 'Manbij', 'Pattoki', 'Hasselt', 'Viersen', 'Roosendaal', 'Rheine', 'Marburg', 'Fukuchiyama', 'Tsubame']
# ['Siedlce', 'Toyooka', 'Pyapon', 'Kahror Pakka', 'Caserta', 'Aira', 'Asti', 'Nabari', 'Troisdorf', 'Kai']
# ['Daisen', 'Daisen', 'Lod', 'Toba Tek Singh', 'Piotrków Trybunalski', 'Wilhelmshaven', 'Kengtung', 'Bayreuth', 'Tosu', 'Kyōtanabe']
# ['Lüneburg', 'Nakatsugawa', 'Tatebayashi', 'Dorsten', 'Gela', 'Dĩ An', 'Amakusa', 'Samundri', 'Castrop-Rauxel', 'Miki']
# ['Miki', 'Detmold', 'Çınar', 'Çınar', 'Landshut', 'Konin', 'Arnsberg', 'Inuyama', 'Kasama', 'Mysłowice']
# ['Lüdenscheid', 'Ostrowiec Świętokrzyski', 'Shibukawa', 'Ostend', 'Shakargarh', 'Sambrial', 'Esbjerg', 'Türkmenbaşy', 'Ede', 'Sipalay']
# ['Penafiel', 'Aschaffenburg', 'Piła', 'Ostrów Wielkopolski', 'Ishioka', 'Cremona', 'Santo Tirso', 'Yukuhashi', 'Lubin', 'Bocholt']
# ['Katori', 'Lisburn', 'Benidorm', 'Érd', 'Moriya', 'Zenica', 'Loulé', 'Kovel', 'Eniwa', 'Kempten']
# ['Phú Quốc', 'Celle', 'Minami-Alps', 'Tournai', 'Uwajima', 'Suwałki', 'Roxas', 'Roxas', 'Roxas', 'Gniezno']
# ['Anan', 'Sabae', 'Mansehra', 'Ko Samui', 'Fulda', 'Tanabe', 'Dinslaken', 'Sōja', 'Głogów', 'Tangub']
# ['Doboj', 'Lippstadt', 'Zamość', 'Bergen op Zoom', 'Przemyśl', 'Fuefuki', 'Kashima', 'Kashima', 'Hashima', 'Siddipet']
# ['Herford', 'Yachimata', 'La Carlota', 'Fukutsu', 'Pabianice', 'Kerpen', 'Hīt', 'Gwacheon', 'Saiki', 'Urla']
# ['Urla', 'Kalush', 'Shiojiri', 'Kazanlak', 'Sindelfingen', 'Seraing', 'Asenovgrad', 'Lahat', 'Weimar', 'Neuwied']
# ['Ina', 'Villach', 'Roeselare', 'Ferrol', 'Jaisalmer', 'Leszno', 'Dormagen', 'Plauen', 'Sandefjord', 'Chunian']
# ['Rosenheim', 'Bucak', 'Bucak', 'Yanagawa', 'Miyoshi', 'Miyoshi', 'Miyoshi', 'Isabela', 'Neubrandenburg', 'Meulaboh']
# ['Sodegaura', 'Rahat', 'Tamana', 'Grevenbroich', 'Nawalgarh', 'Tenri', 'Crotone', 'Póvoa de Varzim', 'Lugano', 'Asahi']
# ['Asahi', 'Asahi', 'Tsuruga', 'Nankana Sahib', 'Kurihara', 'Randers', 'Herten', 'Carrara', 'Shiroi', 'Nago']
# ['Chełm', 'Bannu', 'Kaga', 'Łomża', 'Çaldıran', 'Çaldıran', 'Fujioka', 'Żory', 'Deva', 'Zelenogorsk']
# ['Zelenogorsk', 'Wels', 'Bergheim', 'Kolding', 'Friedrichshafen', 'Tarnowskie Góry', 'Figueira da Foz', 'Itoman', 'Horsens', 'Mitoyo']
# ['Candon', 'Derik', 'Derik', 'Mielec', 'Schwäbisch Gmünd', 'Hita', 'Aisai', 'Offenburg', 'Garbsen', 'Hürth']
# ['Wesel', 'Tamba', 'Sennan', 'Tomaszów Mazowiecki', 'Stralsund', 'Langenfeld', 'Savona', 'Bełchatów', 'Neu-Ulm', 'Greifswald']
# ['Hashimoto', 'Molfetta', 'Yame', 'Afula', 'Shimotsuke', 'Towada', 'Sanyō-Onoda', 'Pasrur', 'Mouscron', 'Ogōri']
# ['Unna', 'Agrigento', 'Kesennuma', 'Hyūga', 'Hua Hin', 'El Salvador', 'Tahara', 'Chikuma', 'Shirakawa', 'Chichibu']
# ['Euskirchen', 'Canlaon', 'Faenza', 'Göppingen', 'Kitahiroshima', 'Kitahiroshima', 'Felgueiras', 'Tokoname', 'Date', 'Date']
# ['Ishikari', 'Kosai', 'Stalowa Wola', 'Choshi', 'Tønsberg', 'Roermond', 'Mizuho', 'Mizuho', 'Będzin', 'Biała Podlaska']
# ['Minokamo', 'Meerbusch', 'Görlitz', 'Uki', 'Frankfurt (Oder)', 'Kędzierzyn-Koźle', 'Sankt Augustin', 'Stolberg', 'Krymsk', 'Krymsk']
# ['Kudamatsu', 'Paços de Ferreira', 'Eschweiler', 'Langenhagen', 'Verviers', 'Alcobaça', 'Waiblingen', 'Murakami', 'Cuneo', 'Nōgata']
# ['Hassa', 'Hassa', 'Amarante', 'Zgierz', 'Tursunzoda', 'Takizawa', 'Bihać', 'Baden-Baden', 'Portimão', 'Lingen']
# ['Hidaka', 'Hidaka', 'Toki', 'Batac', 'Ovar', 'Martin', 'Canterbury', 'Pulheim', 'Schweinfurt', 'Hattingen']
# ['Pombal', 'Chino', 'Konan', 'Zhushan', 'Minamiuonuma', 'Sakurai', 'Sarpsborg', 'Annaka', 'Kampen', 'Cholet']
# ['Ostrołęka', 'Bad Salzuflen', 'Nihonmatsu', 'Nordhorn', 'Kotka', 'Sado', 'Siena', 'Piekary Śląskie', 'Hashtpar', 'Tokmok']
# ['Dholka', 'Tuni', 'Neustadt', 'Neustadt', 'Neustadt', 'Neustadt', 'Neustadt', 'Salo', 'Passau', 'Hamada']
# ['Elda', 'Wetzlar', 'Frechen', 'Naka', 'Rumia', 'Mutsu', 'Roskilde', 'Ahlen', 'Panjakent', 'Kleve']
# ['Tomiya', 'Usa', 'Wolfenbüttel', 'Poprad', 'Malkara', 'Malkara', 'Ålesund', 'Piaseczno', 'Torrelavega', 'Miyakojima']
# ['Bad Kreuznach', 'Ibbenbüren', 'Izumi', 'Eilat', 'Racibórz', 'Caldas da Rainha', 'Covilhã', 'Tsukubamirai', 'Böblingen', 'Speyer']
# ['Isfara', 'Gummersbach', 'Ravensburg', 'Arao', 'Satte', 'Montijo', 'Willich', 'Tadmur', 'Rastatt', 'Hannan']
# ['Nanao', 'Goslar', 'Kyōtango', 'Miyako', 'Goshogawara', 'Peine', 'Susono', 'Fafe', 'Nakagawa', 'Nakagawa']
# ['Nakagawa', 'Puławy', 'Yasu', 'Herning', 'Nichinan', 'Sittard', 'Silkeborg', 'Lörrach', 'Starogard Gdański', 'Amora']
# ['Emden', 'Kameyama', 'Erftstadt', 'Haripur', 'Porvoo', 'Chikugo', 'Leonberg', 'Frankenthal', 'Bergkamen', 'Tomisato']
# ['Suzaka', 'Ridder', 'Ridder', 'Gronau', 'Bad Oeynhausen', 'Hikari', 'Özgön', 'Asakura', 'Midori', 'Rheda-Wiedenbrück']
# ['Wejherowo', 'Freising', 'Alsdorf', 'Dachau', 'Starachowice', 'Bornheim', 'Yamaga', 'Omitama', 'Suwa', 'Hørsholm']
# ['Cuxhaven', 'Voluntari', 'Straubing', 'Zutphen', 'Sanmu', 'Helsingør', 'Soest', 'Ishigaki', 'Dornbirn', 'Kołobrzeg']
# ['Tarnobrzeg', 'Durham', 'Zawiercie', 'Finike', 'Finike', 'Ena', 'Perth', 'Skierniewice', 'Okaya', 'Tonami']
# ['Stade', 'Higashine', 'Águeda', 'Hennef', 'Ono', 'Ono', 'Herzogenrath', 'Kikugawa', 'Kutno', 'Nanto']
# ['Gosen', 'Tomioka', 'Fellbach', 'Schwerte', 'Dülmen', 'Blois', 'Nysa', 'Neunkirchen', 'Neunkirchen', 'Noboribetsu']
# ['Fujiyoshida', 'Sanuki', 'Filderstadt', 'Melle', 'Lohja', 'Hyvinkää', 'Wodzisław Śląski', 'Taebaek', 'Hioki', 'Oranienburg']
# ['Hof', 'Izunokuni', 'Beringen', 'Rodgau', 'Dendermonde', 'Kurayoshi', 'Kasaoka', 'Gotha', 'Takashima', 'Bünde']
# ['Kaufbeuren', 'Kikuchi', 'Bruchsal', 'Hokota', 'Krosno', 'Shima', 'Shima', 'Albstadt', 'Weinheim', 'Ourém']
# ['Erkrath', 'Hokuto', 'Hokuto', 'Olhão', 'Kitakata', 'Brühl', 'Brühl', 'Otwock', 'Dębica', 'Dunakeszi']
# ['Memmingen', 'Næstved', 'Falkensee', 'Biella', 'Tank', 'Numata', 'Nanjō', 'Wiener Neustadt', 'Radomsko', 'Tateyama']
# ['Tateyama', 'Iwanuma', 'Yatağan', 'Yatağan', 'Turnhout', 'Neustadt am Rübenberge', 'Kaarst', 'Lehrte', 'Deinze', 'Świdnik']
# ['Tiberias', 'Bietigheim-Bissingen', 'Masuda', 'Albufeira', 'Svishtov', 'Dikili', 'Dikili', 'Hagi', 'Kamen', 'Himi']
# ['Yatomi', 'Marki', 'Erkelenz', 'Wismar', 'Shinshiro', 'Çeşme', 'Çeşme', 'Santa Cruz', 'Makinohara', 'Zharkent']
# ['Zharkent', 'Siegburg', 'Gifhorn', 'Shimabara', 'Heinsberg', 'Lokeren', 'Akbarpur', 'Akbarpur', 'Rantepao', 'Germering']
# ['Borken', 'Ciechanów', 'Laatzen', 'Kobayashi', 'Miura', 'Nettetal', 'Sieradz', 'Dreieich', 'Awaji', 'Amberg']
# ['Eisenach', 'Aurich', 'Imperia', 'Köniz', 'Kasai', 'Akaiwa', 'Futtsu', 'Balykchy', 'Homburg', 'Maniwa']
# ['Ansbach', 'Nordhausen', 'Schwabach', 'Minamishimabara', 'Coburg', 'Poti', 'Merano', 'Shimotsuma', 'Beigang', 'Kirchheim unter Teck']
# ['Nürtingen', 'Wunstorf', 'Bragadiru', 'Eberswalde', 'Chojnice', 'Amuntai', 'Mikołów', 'Königswinter', 'Kwidzyn', 'Świnoujście']
# ['Herstal', 'Yuzawa', 'Fredericia', 'Kitaibaraki', 'Schwäbisch Hall', 'Geel', 'Komoro', 'Zduńska Wola', 'Leinfelden-Echterdingen', 'Nowa Sól']
# ['Szigetszentmiklós', 'Antequera', 'Hückelhoven', 'Bensheim', 'Chaves', 'Freiberg', 'Sumoto', 'Järvenpää', 'Unzen', 'Amami']
# ['Ostfildern', 'Lemgo', 'Bolesławiec', 'Pirmasens', 'Sint-Truiden', 'Uozu', 'Katō', 'Wageningen', 'Tomar', 'Weißenfels']
# ['Sivaganga', 'Arys', 'Arys', 'Buxtehude', 'Löhne', 'Agano', 'Maihar', 'Freital', 'Halberstadt', 'Maintal']
# ['Junnar', 'Ōzu', 'Ōzu', 'Schorndorf', 'Oświęcim', 'Itoigawa', 'Kasumigaura', 'Ninove', 'Sagae', 'Ettlingen']
# ['Völklingen', 'Langen', 'Langen', 'Halle', 'Rauma', 'Ahaus', 'Écija', 'Michalovce', 'Würselen', 'Niederkassel']
# ['Steyr', 'Pirna', 'Solan', 'Mettmann', 'Plasencia', 'La Chaux-de-Fonds', 'Takikawa', 'Stirling', 'Stendal', 'Trofa']
# ['Mitsuke', 'Sopot', 'Tamba-Sasayama', 'Higashimatsushima', 'Ilmenau', 'Szczecinek', 'Waregem', 'Baikonur', 'Baikonur', 'Ílhavo']
# ['Wesseling', 'Inashiki', 'Yoshinogawa', 'Hitachiomiya', 'Marinha Grande', 'Sakuragawa', 'Bautzen', 'Ibusuki', 'Fürstenfeldbruck', 'Gujō']
# ['Nishiwaki', 'Königs Wusterhausen', 'Misawa', 'Żary', 'Jarosław', 'Backnang', 'Kamp-Lintfort', 'Venlo', 'Ibara', 'Katsuragi']
# ['Papenburg', 'Uster', 'Haugesund', 'Olot', 'Greven', 'Kehl', 'Knurów', 'Oleśnica', 'Maibara', 'Chrzanów']
# ['Châtelet', 'Warendorf', 'Tudela', 'Lębork', 'Holstebro', 'Suhl', 'Silves', 'Erding', 'Tuttlingen', 'Beckum']
# ['Sōma', 'Mizunami', 'Torres Novas', 'Esik', 'Esik', 'Cloppenburg', 'Cantanhede', 'Zhetisay', 'Zhetisay', 'Coesfeld']
# ['Voerde', 'Águilas', 'Emsdetten', 'Selçuk', 'Selçuk', 'Mühlhausen', 'Mühlhausen', 'Sanok', 'Uto', 'Udhampur']
# ['Sankt Ingbert', 'Kerava', 'Jasło', 'Czechowice-Dziedzice', 'Bad Vilbel', 'Zhmerynka', 'Dietzenbach', 'Porta Westfalica', 'Chortoq', 'Sinsheim']
# ['Winsen', 'Winchester', 'Setouchi', 'Miranda de Ebro', 'Sion', 'Karak', 'Atami', 'Usuki', 'Isumi', 'Burriana']
# ['Sochaczew', 'Cieszyn', 'Câmara de Lobos', 'Kilimli', 'Kilimli', 'Mörfelden-Walldorf', 'Meppen', 'Dimitrovgrad', 'Leer', 'Savonlinna']
# ['Kraśnik', 'Lage', 'Kahoku', 'Kahoku', 'Cegléd', 'Radebeul', 'Unnan', 'Datteln', 'Saarlouis', 'Wermelskirchen']
# ['Crailsheim', 'Ahrensburg', 'Tamra', 'Wedel', 'Tienen', 'Wavre', 'Tamura', 'Iyo', 'Kempen', 'Seelze']
# ['Menen', 'Meppel', 'Balingen', 'Baja', 'Seiyo', 'Steinfurt', 'Deggendorf', 'Goch', 'Năvodari', 'Mosonmagyaróvár']
# ['Iława', 'Dupnitsa', 'Shingū', 'Shingū', 'Awa', 'Dzierżoniów', 'Abashiri', 'Merseburg', 'Zweibrücken', 'IJsselstein']
# ['Ofunato', 'Barsinghausen', 'Esposende', 'Hemer', 'Gotō', 'Oława', 'Inabe', 'Râmnicu Sărat', 'Korschenbroich', 'Lommel']
# ['Vibo Valentia', 'Tōon', 'Úbeda', 'Tobelo', 'Nowy Targ', 'Viernheim', 'Geldern', 'Grodzisk Mazowiecki', 'Shisō', 'Binche']
# ['Uonuma', 'Dimona', 'Sneek', 'Ojiya', 'Xinyuan', 'Uelzen', 'Geraardsbergen', 'Olkusz', 'Bad Nauheim', 'Ronda']
# ['Vechta', 'Sakaiminato', 'Kos', 'Pruszcz Gdański', 'Vác', 'Nokia', 'Shōbara', 'Umaria', 'Police', 'Kaarina']
# ['Oldenzaal', 'Zgorzelec', 'Minamikyūshū', 'Forchheim', 'Asakuchi', 'Kamaishi', 'Lampertheim', 'Bungoōno', 'Sarıkaya', 'Sarıkaya']
# ['Yamanashi', 'Itzehoe', 'Jülich', 'Bernburg', 'Sō', 'Wernigerode', 'Kuji', 'Achim', 'Ylöjärvi', 'Yufu']
# ['Kaizu', 'Motosu', 'Altenburg', 'Bilzen', 'Camaiore', 'Shiroishi', 'Shiroishi', 'Naumburg', 'Minamisatsuma', 'Shimanto']
# ['Shimanto', 'Mioveni', 'Czeladź', 'Espinho', 'Milazzo', 'Geesthacht', 'Delbrück', 'Herrenberg', 'Georgsmarienhütte', 'Foça']
# ['Foça', 'Dhahran', 'Oudenaarde', 'Namerikawa', 'Gödöllő', 'Ribeira Grande', 'Bramsche', 'Nagato', 'Oer-Erkenschwick', 'Rosmalen']
# ['Bizen', 'Września', 'Radolfzell am Bodensee', 'Norak', 'Namegata', 'Komagane', 'Yenice', 'Yenice', 'Yenice', 'Yenice']
# ['Yenice', 'Yenice', 'Hoyerswerda', 'Katagami', 'Louvain-la-Neuve', 'Gevelsberg', 'Weil am Rhein', 'Mława', 'Kuroishi', 'Haan']
# ['Ayabe', 'Kreuztal', 'Mae Sot', 'Kosonsoy', 'Ózd', 'Łowicz', 'Verbania', 'Rheinberg', 'Tongeren', 'Hitoyoshi']
# ['Netivot', 'Trebinje', 'Burgdorf', 'Yaita', 'Bielsk Podlaski', 'Lagos', 'Lushnjë', 'Werl', 'Łuków', 'Chitral']
# ['Tokmak', 'Nantan', 'Neuruppin', 'Schönebeck', 'Bochnia', 'Omaezaki', 'Einbeck', 'Żywiec', 'Lohmar', 'Leh']
# ['Unterschleißheim', 'Ennepetal', 'Myszków', 'Hajdúböszörmény', 'Tekeli', 'Tekeli', 'Emmen', 'Pápa', 'Andernach', 'Yanai']
# ['Taunusstein', 'Bielawa', 'Osterholz-Scharmbeck', 'Motomiya', 'Gorna Oryahovitsa', 'Gaggenau', 'Bad Hersfeld', 'Walsrode', 'Tskhinvali', 'Aarschot']
# ['Friedberg', 'Friedberg', 'Tsuru', 'Bretten', 'Augustów', 'Budaörs', 'Rendsburg', 'Hafnarfjörður', 'Brodnica', 'Meschede']
# ['Waltrop', 'Culemborg', 'Saalfeld', 'Merzig', 'Arlon', 'Izegem', 'Tönisvorst', 'Schwelm', 'Aral', 'Aral']
# ['Kınık', 'Kınık', 'Vaihingen an der Enz', 'Landsberg', 'Landsberg', 'Rietberg', 'Swarzędz', 'Petrich', 'Zaltbommel', 'Santiago do Cacém']
# ['Kitaakita', 'Gotse Delchev', 'Nowy Dwór Mazowiecki', 'Güstrow', 'Oelde', 'Riesa', 'Königsbrunn', 'Winnenden', 'Riihimäki', 'Schwandorf']
# ['Rösrath', 'Kavajë', 'Gyula', 'Kiskunfélegyháza', 'Ath', 'Shibushi', 'Carmona', 'Northeim', 'Anadia', 'Bühl']
# ['Kaminoyama', 'Fundão', 'Reinbek', 'Reda', 'Springe', 'Nirasaki', 'Śrem', 'Emmendingen', 'Tondela', 'Höxter']
# ['Nivelles', 'Krotoszyn', 'Hirado', 'Takahashi', 'Asago', 'Herentals', 'Sønderborg', 'Oyabe', 'Harelbeke', 'Lepe']
# ['Heerenveen', 'Yangiyer', 'Leichlingen', 'Zeitz', 'Idar-Oberstein', 'Griesheim', 'Gyöngyös', 'Saito', 'Olching', 'Aioi']
# ['Geislingen an der Steige', 'Teltow', 'Baunatal', 'Dubăsari', 'Izu', 'Wegberg', 'Kobyłka', 'Mechernich', 'Biłgoraj', 'Higashikagawa']
# ['Gorlice', 'Baesweiler', 'Leimen', 'Grimma', 'Esztergom', 'Kevelaer', 'Svendborg', 'Ajka', 'Obama', 'Bad Neuenahr-Ahrweiler']
# ['Čapljina', 'Kłodzko', 'Rapperswil-Jona', 'Geilenkirchen', 'Mima', 'Szentendre', 'Peniche', 'Tainai', 'Kakuda', 'Kriens']
# ['Imatra', 'Sundern', 'Ludwigsfelde', 'Andenne', 'Soignies', 'Arnstadt', 'Zakopane', 'Havran', 'Havran', 'Kitsuki']
# ['Itako', 'Troyan', 'Ukiha', 'Lohne', 'Gojō', 'Wiesloch', 'Orosháza', 'Niimi', 'Neckarsulm', 'Overath']
# ['Bidur', 'Schloß Holte-Stukenbrock', 'Strausberg', 'Ronse', 'Zirndorf', 'Rheinbach', 'Panauti', 'Takahagi', 'Aytos', 'Aschersleben']
# ['Hennigsdorf', 'Awara', 'Heiligenhaus', 'Ichikikushikino', 'Akitakata', 'Sandanski', 'Estarreja', 'Wągrowiec', 'Wangen im Allgäu', 'Hohen Neuendorf']
# ['Szentes', 'Nayoro', 'Hamminkeln', 'Saumur', 'Turek', 'Pınarbaşı', 'Pınarbaşı', 'Butzbach', 'Heppenheim', 'Lamego']
# ['Zottegem', 'Obertshausen', 'Jarocin', 'Ōtake', 'Montreux', 'Weiterstadt', 'Tubize', 'Kiskunhalas', 'Wieliczka', 'Siófok']
# ['Jászberény', 'Jumilla', 'Mühlacker', 'Wyszków', 'Samokov', 'Schleswig', 'Groß-Gerau', 'Nordenham', 'Hjørring', 'Selm']
# ['Bingen am Rhein', 'Arida', 'Kami', 'Kami', 'Sangerhausen', 'Frauenfeld', 'Kluczbork', 'Lindau', 'Geretsried', 'Friedrichsdorf']
# ['Świecie', 'Köthen', 'Khashuri', 'Tavira', 'Gembloux', 'Yuanchang', 'Kulmbach', 'Lice', 'Lice', 'Achern']
# ['Novopavlovsk', 'Novopavlovsk', 'Helmstedt', 'Sankt Wendel', 'Ligang', 'Lübbecke', 'Nagai', 'Tosa', 'Ōmachi', 'Wetzikon']
# ['Pszczyna', 'Roth', 'Verl', 'Harsewinkel', 'Pfungstadt', 'Rinteln', 'Ditzingen', 'Lennestadt', 'Nesher', 'Rottweil']
# ['Wiehl', 'Horb am Neckar', 'Kazincbarcika', 'Wałcz', 'Plettenberg', 'Delitzsch', 'Rudolstadt', 'Mimasaka', 'Staßfurt', 'Idstein']
# ['Maaseik', 'Brilon', 'Skawina', 'Samtredia', 'Baar', 'Markkleeberg', 'Öhringen', 'Albergaria-a-Velha', 'Meckenheim', 'Bad Oldesloe']
# ['Norden', 'Salzkotten', 'Petershagen', 'Sprockhövel', 'Kościerzyna', 'Sastamala', 'Zittau', 'Tōno', 'Raahe', 'Gyál']
# ['Ninohe', 'Wil', 'Ma‘bar', 'Waldkraiburg', 'Iki', 'Espelkamp', 'Białogard', 'Żagań', 'Lüdinghausen', 'Villarrobledo']
# ['Übach-Palenberg', 'Warstein', 'Ronnenberg', 'Olpe', 'Sandomierz', 'Rishton', 'Meiningen', 'Schmallenberg', 'Omurtag', 'Harstad']
# ['Nemuro', 'Pavlovsk', 'Pavlovsk', 'Aso', 'Bad Soden am Taunus', 'Kulachi', 'Delfzijl', 'Oga', 'Raisio', 'Seia']
# ['Gose', 'Arad', 'Vizela', 'Konstancin-Jeziorna', 'Larvik', 'Cartaxo', 'Attendorn', 'Nasukarasuyama', 'Buzen', 'Herzogenaurach']
# ['Syke', 'Waldshut-Tiengen', 'Limbach-Oberfrohna', 'Spremberg', 'Senftenberg', 'Bad Mergentheim', 'Martos', 'Rathenow', 'Husum', 'Środa Wielkopolska']
# ['Dunaharaszti', 'Hajdúszoboszló', 'Gazojak', 'Lebedyn', 'Haren', 'Diest', 'Varel', 'Velingrad', 'Kaltenkirchen', 'Isa']
# ['Bedburg', 'Bedburg', 'Kamiamakusa', 'Quedlinburg', 'Calw', 'Sonneberg', 'Ibi', 'Döbeln', 'Sehnde', 'Freudenstadt']
# ['Jüchen', 'Lubliniec', 'Jawor', 'Mirandela', 'Starnberg', 'Popovo', 'Horgen', 'Takehara', 'Ostrów Mazowiecka', 'Elburg']
# ['Tata', 'Mosbach', 'Hachimantai', 'Korbach', 'Herdecke', 'Eisenhüttenstadt', 'Gelnhausen', 'Salzwedel', 'Kreuzlingen', 'Płońsk']
# ['Saint-Ghislain', 'Bulle', 'Dillenburg', 'Leutkirch im Allgäu', 'Lubartów', 'Westerstede', 'Neusäß', 'Bad Salzungen', 'Frederikshavn', 'Nagykőrös']
# ['Eschborn', 'Senden', 'Senden', 'Gersthofen', 'Almeirim', 'Calamba', 'Kumano', 'Kumano', 'Riehen', 'Gaoshu']
# ['Laguna de Duero', 'Karben', 'Caniço', 'Netphen', 'Minamata', 'Oliveira do Bairro', 'Mine', 'Puchheim', 'Gobō', 'Lagoa']
# ['Lagoa', 'Warburg', 'Koło', 'Fleurus', 'Komló', 'Nikaho', 'Überlingen', 'Grajewo', 'Vale de Cambra', 'Büdingen']
# ['Nagold', 'Wädenswil', 'Laupheim', 'Świebodzice', 'Wertheim', 'Bad Kissingen', 'Vreden', 'Eckernförde', 'Thebes', 'Kitzingen']
# ['Kalat', 'Lengerich', 'Glauchau', 'Działdowo', 'Wettingen', 'Mrągowo', 'Łęczna', 'Petrila', 'Moguer', 'Byala Slatina']
# ['Donaueschingen', 'Metzingen', 'Apolda', 'Friesoythe', 'Pushkar', 'Uenohara', 'Goleniów', 'Stadthagen', 'Burg', 'Makó']
# ['Isperih', 'Braine-le-Comte', 'Buftea', 'Pogradec', 'Heide', 'Sevlievo', 'Radevormwald', 'Karnobat', 'Zambrów', 'Gardelegen']
# ['Aleksandrów Łódzki', 'Otopeni', 'Schwetzingen', 'Hockenheim', 'Dudelange', 'Cisnădie', 'Waldkirch', 'Sulejówek', 'Murayama', 'Bad Harzburg']
# ['Eppingen', 'Nova Zagora', 'Bad Rappenau', 'Lom', 'Machico', 'Karlovo', 'Vecsés', 'Palafrugell', 'Versmold', 'Elsdorf']
# ['Sonthofen', 'Seligenstadt', 'Bungotakada', 'Xanten', 'Kemi', 'Polkowice', 'Iisalmi', 'Opoczno', 'Tornio', 'Józefów']
# ['Orzesze', 'Yabu', 'Nowa Ruda', 'Chełmno', 'Etajima', 'Mezdra', 'Kurikka', 'Aichach', 'Huy', 'Germersheim']
# ['Göd', 'Stadtallendorf', 'Zerbst', 'Łaziska Górne', 'Wülfrath', 'Büren', 'Entroncamento', 'Waghäusel', 'Kant', 'Senaki']
# ['Geseke', 'Hoogstraten', 'Leerdam', 'Bad Krozingen', 'Sondershausen', 'Günzburg', 'Kara-Suu', 'Eeklo', 'Jämsä', 'Hajnówka']
# ['Wieluń', 'Blankenberge', 'Panagyurishte', 'Schramberg', 'Prudnik', 'Traunreut', 'Cugir', 'Matsuura', 'Soltau', 'Groß-Umstadt']
# ['Teteven', 'Bad Schwartau', 'Skive', 'Gryfino', 'Coswig', 'Coswig', 'Schenefeld', 'Lubań', 'Traunstein', 'Bruchköbel']
# ['Bülach', 'Alfena', 'Rio Maior', 'Los Llanos de Aridane', 'Varkaus', 'Wipperfürth', 'Schifferstadt', 'Fröndenberg', 'Fót', 'Werdau']
# ['Furano', 'Luckenwalde', 'Torhout', 'Enger', 'Mössingen', 'Nördlingen', 'Nidderau', 'Veresegyház', 'Oliveira do Hospital', 'Herborn']
# ['Gerlingen', 'Wildeshausen', 'Kremenets', 'Schortens', 'Horten', 'Valkeakoski', 'Skanderborg', 'Blieskastel', 'Zülpich', 'Tielt']
# ['Gyömrő', 'Elvas', 'Stadtlohn', 'Meinerzhagen', 'Hörstel', 'Botevgrad', 'Duderstadt', 'Dingolfing', 'Korntal-Münchingen', 'Mealhada']
# ['Ely', 'Gjøvik', 'Harmanli', 'Bibai', 'Gioia Tauro', 'Susaki', 'Baden', 'Rawicz', 'Pleszew', 'Wittmund']
# ['Chodzież', 'Gostyń', 'Bad Waldsee', 'Annaberg-Buchholz', 'Vianen', 'Medina del Campo', 'Złotów', 'Kloten', 'Oberkirch', 'Greiz']
# ['Donauwörth', 'Rumoi', 'Hatvan', 'Marneuli', 'Lichtenfels', 'Neustrelitz', 'Hakui', 'Requena', 'Torgau', 'Edam']
# ['Zossen', 'Holzminden', 'Schopfheim', 'Kęty', 'Telgte', 'Qorasuv', 'Giengen an der Brenz', 'Heusenstamm', 'Weesp', 'Saint-Dié-des-Vosges']
# ['Fukagawa', 'Uetersen', 'Mölln', 'Peshtera', 'Makurazaki', 'Ochtrup', 'Glinde', 'Nykøbing Falster', 'Törökszentmiklós', 'Tettnang']
# ['Ennigerloh', 'Mangualde', 'Tomaszów Lubelski', 'Olten', 'Neviges', 'Poperinge', 'Blankenburg', 'Äänekoski', 'Volketswil', 'Komárom']
# ['Ozorków', 'Waldbröl', 'Schmalkalden', 'Eschwege', 'Dęblin', 'Hamina', 'Sarstedt', 'Burghausen', 'Bieruń', 'Sulzbach-Rosenberg']
# ['Sélestat', 'Karcag', 'Enkhuizen', 'Marsberg', 'Trzebinia', 'Borna', 'Várpalota', 'Wittlich', 'Oschersleben', 'Taketa']
# ['Eupen', 'Lieto', 'Nakło nad Notecią', 'Bad Tölz', 'Jakobstad', 'Mayen', 'Konstantynów Łódzki', 'Andrychów', 'Weil der Stadt', 'Keszthely']
# ['Alzey', 'Bückeburg', 'Hechingen', 'Adria', 'Kolbermoor', 'Heinola', 'Bad Pyrmont', 'Bad Aibling', 'Hemmingen', 'Sokołów Podlaski']
# ['Rhede', 'Haiger', 'Seesen', 'Radeberg', 'Müllheim', 'Bad Berleburg', 'Pułtusk', 'Regensdorf', 'Łańcut', 'Vila Real de Santo António']
# ['Vellmar', 'Wervik', 'Dalanzadgad', 'Mino', 'Izra', 'Krasnystaw', 'Wassenberg', 'San Vito dei Normanni', 'Iiyama', 'Pfullingen']
# ['Haldensleben', 'Burscheid', 'Bergneustadt', 'Schkeuditz', 'Lebach', 'Püttlingen', 'Sömmerda', 'Hochheim am Main', 'Oberasbach', 'Naantali']
# ['Sukumo', 'Bad Driburg', 'Akune', 'Gostynin', 'Akureyri', 'Schneverdingen', 'Martigny', 'Renningen', 'Kamienna Góra', 'Prenzlau']
# ['Rawa Mazowiecka', 'Marktoberdorf', 'Nauen', 'Paks', 'Bad Reichenhall', 'Alfeld', 'Muttenz', 'Fushë-Krujë', 'Százhalombatta', 'Monor']
# ['Berkovitsa', 'Crimmitschau', 'Gossau', 'Gossau', 'Lukovit', 'Kegalle', 'Szamotuły', 'Lessines', 'Bremervörde', 'Konz']
# ['Bad Dürkheim', 'Vlotho', 'Jiadong', 'Freilassing', 'Myślenice', 'Tatsuno', 'Lahnstein', 'Międzyrzecz', 'Walcourt', 'Kostrzyn nad Odrą']
# ['Békés', 'Bad Segeberg', 'Zielonka', 'Gheorgheni', 'Heidenau', 'Wörth am Rhein', 'Schwalmstadt', 'Schwarzenbek', 'Taku', 'Visé']
# ['Monthey', 'Garwolin', 'Hessisch Oldendorf', 'Großenhain', 'Końskie', 'Illertissen', 'Braniewo', 'Garching bei München', 'Naarden', 'Pisz']
# ['Svilengrad', 'Werdohl', 'Auerbach', 'Auerbach', 'Wadowice', 'Bad Säckingen', 'Sierpc', 'Băicoi', 'Pieksämäki', 'Łask']
# ['Dombóvár', 'Vordingborg', 'Parchim', 'Pratteln', 'Bexbach', 'Kelsterbach', 'Bobingen', 'Freudenberg', 'Sinzig', 'Oroszlány']
# ['Pomáz', 'Ginsheim-Gustavsburg', 'Rypin', 'Oborniki', 'Remagen', 'Frankenberg', 'Frankenberg', 'Pyskowice', 'Herve', 'Międzyrzec Podlaski']
# ['Oerlinghausen', 'Trossingen', 'Grenchen', 'Laç', 'Złotoryja', 'Linbian', 'Schrobenhausen', 'Milanówek', 'Alcochete', 'Sokółka']
# ['Pionki', 'Bendorf', 'Strzelce Opolskie', 'Dabas', 'Bad Münder am Deister', 'Marche-en-Famenne', 'Wendlingen am Neckar', 'Toba', 'Bad Langensalza', 'Freienbach']
# ['Ebino', 'Thale', 'Raunheim', 'Marktredwitz', 'Wittenberge', 'Damme', 'Forssa', 'Burgdorf', 'Sigmaringen', 'Nidda']
# ['Montemor-o-Novo', 'Gescher', 'Bad Münstereifel', 'Péruwelz', 'Eutin', 'Heilbad Heiligenstadt', 'Kamenz', 'Bad Wildungen', 'Horn-Bad Meinberg', 'G‘uzor']
# ['Wohlen', 'Stockach', 'Freiberg am Neckar', 'Diepholz', 'Hrubieszów', 'Pécel', 'Przasnysz', 'Peso da Régua', 'Königstein im Taunus', 'Braunau am Inn']
# ['Aubange', 'Altena', 'Grójec', 'Mohács', 'Cham', 'Penzberg', 'Ustka', 'Aabenraa', 'Kozienice', 'Marienberg']
# ['Balmazújváros', 'Brzesko', 'Babenhausen', 'Gubin', 'Kronach', 'Bargteheide', 'Preetz', 'Łęczyca', 'Schwarzenberg', 'Gunzenhausen']
# ['Cernavodă', 'Guben', 'Namysłów', 'Bytów', 'Kelheim', 'Steffisburg', 'Reinheim', 'Ripon', 'Mátészalka', 'Krapkowice']
# ['Bad Wörishofen', 'Bogatynia', 'Bürstadt', 'Katsuura', 'Trzcianka', 'Hajdúnánás', 'Hünfeld', 'Marbach am Neckar', 'Boysun', 'Diksmuide']
# ['Locarno', 'Libiąż', 'Strzegom', 'Wurzen', 'Kushima', 'Kauhava', 'Aue', 'Ceadîr-Lunga', 'Bad Lippspringe', 'Sunagawa']
# ['Miyazu', 'Hannut', 'Gryfice', 'Peer', 'Chełmża', 'Słubice', 'Corabia', 'Keflavík', 'Bree', 'Brackenheim']
# ['Hønefoss', 'Quarteira', 'Yaypan', 'Langenthal', 'Ciney', 'Garðabær', 'Differdange', 'Kisvárda', 'Loimaa', 'Kirchhain']
# ['Pocking', 'Olecko', 'Straelen', 'Erlensee', 'Herisau', 'Markranstädt', 'Ustroń', 'Przeworsk', 'Bassum', 'Eilenburg']
# ['Brakel', 'Kierspe', 'Dieburg', 'Orimattila', 'Michelstadt', 'Halver', 'Lyss', 'Walldorf', 'Niepołomice', 'Erwitte']
# ['Mezőkövesd', 'Landen', 'Clausthal-Zellerfeld', 'Breaza', 'Ikast', 'Taucha', 'Sulechów', 'Nowogard', 'Finsterwalde', 'Füssen']
# ['Owase', 'Ropczyce', 'Aki', 'Mezőtúr', 'Ebersbach an der Fils', 'Weener', 'Csongrád', 'Alsfeld', 'Bad Bentheim', 'Schlüchtern']
# ['Stäfa', 'Neustadt in Holstein', 'Bitburg', 'Świdwin', 'Bastogne', 'Gargždai', 'Lidzbark Warmiński', 'Chitila', 'Königslutter am Elm', 'Budakeszi']
# ['Casalpusterlengo', 'Wadern', 'Kavarna', 'Rakovski', 'Künzelsau', 'Patos', 'Macedo de Cavaleiros', 'Plochingen', 'Uusikaupunki', 'Bad Bramstedt']
# ['Kalocsa', 'Drensteinfurt', 'Langenau', 'Kanding', 'Einsiedeln', 'Kuusamo', 'Templin', 'Szarvas', 'Waremme', 'Serpa']
# ['Mindelheim', 'Rahden', 'Jędrzejów', 'Boppard', 'Khamir', 'Ribnitz-Damgarten', 'Radzyń Podlaski', 'Solec Kujawski', 'Schriesheim', 'Küsnacht']
# ['Siemiatycze', 'Gehrden', 'Jelcz-Laskowice', 'Genappe', 'Limanowa', 'Vicovu de Sus', 'Neustadt bei Coburg', 'Ober-Ramstadt', 'Mainburg', 'Hofgeismar']
# ['Mian Sahib', 'Głuchołazy', 'Neutraubling', 'Mendrisio', 'Markgröningen', 'Hohenstein-Ernstthal', 'Brake', 'Hückeswagen', 'Horw', 'Alta']
# ['Loviisa', 'Blomberg', 'Sárvár', 'Tapolca', 'Selb', 'Langelsheim', 'Witzenhausen', 'Grodzisk Wielkopolski', 'Choszczno', 'Boguszów-Gorce']
# ['Richterswil', 'Moura', 'Meilen', 'Busko-Zdrój', 'Gardabani', 'Chirpan', 'Dorfen', 'Kochkor-Ata', 'Ratzeburg', 'Nisko']
# ['Pilisvörösvár', 'Hilchenbach', 'Biatorbágy', 'Zollikon', 'Ylivieska', 'Uhingen', 'Cherrapunji', 'Neu-Anspach', 'Lipno', 'Usingen']
# ['Langenselbold', 'Tiszaújváros', 'Łapy', 'Serhetabat', 'Fritzlar', 'Człuchów', 'Radzymin', 'Meerane', 'Bad Wurzach', 'Jever']
# ['Wąbrzeźno', 'Gafanha da Nazaré', 'Balassagyarmat', 'Oftringen', 'Thuin', 'Pattensen', 'Rotenburg an der Fulda', 'Spenge', 'Brwinów', 'Montabaur']
# ['Schwabmünchen', 'Tornesch', 'Obanazawa', 'Berettyóújfalu', 'Nishinoomote', 'Çiçekdağı', 'Çiçekdağı', 'Törökbálint', 'Ząbkowice Śląskie', 'Wilsdruff']
# ['Măgurele', 'Wschowa', 'Ottweiler', 'Mittweida', 'Mosina', 'Versoix', 'Lauda-Königshofen', 'Isny im Allgäu', 'Gland', 'Ożarów Mazowiecki']
# ['Neustadt an der Donau', 'Słupca', 'Eberbach', 'Markdorf', 'Rønne', 'Urbino', 'Priverno', 'Olsberg', 'Cadaval', 'Oschatz']
# ['Grünstadt', 'Darłowo', 'Mocha', 'Pucioasa', 'Löbau', 'Bad Camberg', 'Abensberg', 'Abony', 'Schneeberg', 'Pomorie']
# ['Mizil', 'Gernsbach', 'Holzgerlingen', 'Sassenberg', 'Angermünde', 'Hettstedt', 'Vöhringen', 'Kartuzy', 'Quakenbrück', 'Uslar']
# ['Estremoz', 'Raydah', 'Ortahisar', 'Ortahisar', 'Dippoldiswalde', 'Sines', 'Lubsko', 'Staszów', 'Jodoigne', 'Nowy Tomyśl']
# ['Valença', 'Amriswil', 'Eppstein', 'Burglengenfeld', 'Murrhardt', 'Püspökladány', 'Lauchhammer', 'Głowno', 'Kerben', 'Ostrzeszów']
# ['Eggenfelden', 'Narvik', 'Kępno', 'Zimnicea', 'Nesebar', 'Ovidiu', 'Spaichingen', 'Leuna', 'Tamm', 'Bebra']
# ['Lich', 'Kalkar', 'Golub-Dobrzyń', 'Gouveia', 'Enghien', 'Schmölln', 'Mór', 'Buchloe', 'Genthin', 'Aßlar']
# ['Erbach', 'Erbach', 'Skoczów', 'Landau an der Isar', 'Zeven', 'Hilpoltstein', 'Weißenhorn', 'Lauterbach', 'Philippsburg', 'Aleksandrów Kujawski']
# ['Kiskőrös', 'Lorsch', 'Krumbach', 'Bergen', 'Bergen', 'Melsungen', 'Kauhajoki', 'Gura Humorului', 'Ettenheim', 'Haßfurt']
# ['Couvin', 'Grünberg', 'Aberystwyth', 'Höchstadt an der Aisch', 'Leżajsk', 'Eichstätt', 'Neckargemünd', 'Münchenstein', 'Gołdap', 'Uzwil']
# ['Tarumizu', 'Bad Soden-Salmünster', 'Biedenkopf', 'Włodawa', 'Trzebnica', 'Sátoraljaújhely', 'Jimbolia', 'Löningen', 'Ihtiman', 'Dinant']
# ['Bad Laasphe', 'Pfullendorf', 'Głubczyce', 'Żnin', 'Bad Dürrheim', 'Wolsztyn', 'Nidzica', 'Hajdúsámson', 'Schüttorf', 'Spiez']
# ['Wiesmoor', 'Besigheim', 'Zehdenick', 'Tuchola', 'Wasserburg am Inn', 'Dinklage', 'Kaspi', 'Albertirsa', 'Wehr', 'Bad Salzdetfurth']
# ['Brig-Glis', 'Nakskov', 'Wernau', 'Pegnitz', 'Tauberbischofsheim', 'Barlinek', 'Sendenhorst', 'Plattling', 'Pritzwalk', 'Morąg']
# ['Buchs', 'Velen', 'Affoltern am Albis', 'Rüti', 'Diósd', 'Rödental', 'Dębno', 'Weinsberg', 'Wolfhagen', 'Pfarrkirchen']
# ['Zella-Mehlis', 'Röthenbach an der Pegnitz', 'Herbrechtingen', 'Olfen', 'Haselünne', 'Ulvila', 'Parvomay', 'Östringen', 'Beverungen', 'Balatonfüred']
# ['Radomir', 'Yamato', 'Weilburg', 'Maglód', 'Schleiden', 'Spreitenbach', 'Bonyhád', 'Waltershausen', 'Hadamar', 'Bad Doberan']
# ['Rosbach vor der Höhe', 'Sulingen', 'Hersbruck', 'Treuchtlingen', 'Herzberg am Harz', 'Alcácer do Sal', 'Wächtersbach', 'Halásztelek', 'Gárdony', 'Linnich']
# ['Brzeg Dolny', 'Schongau', 'Hajdúhadház', 'Herk-de-Stad', 'Üllő', 'Beelitz', 'Velten', 'Hungen', 'Brzeziny', 'Avrig']
# ['Möckern', 'Brugg', 'Bassersdorf', 'Hemsbach', 'Lubaczów', 'Chiatura', 'Dorog', 'Gyomaendrőd', 'Steinheim', 'Újfehértó']
# ['Jilava', 'Pecica', 'Suzu', 'Sławno', 'Ashibetsu', 'Novi Pazar', 'Bad Urach', 'Simeria', 'Kłobuck', 'Brunsbüttel']
# ['Palos de la Frontera', 'Hattem', 'Kuçovë', 'Ladenburg', 'Zofingen', 'Sulz am Neckar', 'Winterberg', 'Roding', 'Feuchtwangen', 'Blaubeuren']
# ['Erkner', 'Twistringen', 'Kalajoki', 'Rochefort', 'Tiszavasvári', 'Vălenii de Munte', 'Anklam', 'Cumpăna', 'Neuenburg am Rhein', 'Valu lui Traian']
# ['Pyrzyce', 'Sântana', 'Lindenberg im Allgäu', 'Sabugal', 'Namchi', 'Preußisch Oldendorf', 'Frohburg', 'Koluszki', 'Oberwil', 'Pfäffikon']
# ['Bad Windsheim', 'Ebersberg', 'Vilsbiburg', 'Brzeszcze', 'Jüterbog', 'Plan-les-Ouates', 'Hessisch Lichtenau', 'Sędziszów Małopolski', 'Złocieniec', 'Gladenbach']
# ['Balchik', 'Gaildorf', 'Romanshorn', 'Razlog', 'Nagykáta', 'Veurne', 'Budakalász', 'Pößneck', 'Błonie', 'Bad Fallingbostel']
# ['Sânnicolau Mare', 'Gistel', 'Ludwigslust', 'Maxhütte-Haidhof', 'Bad Freienwalde', 'Titisee-Neustadt', 'Foča', 'Wołów', 'Węgrów', 'Hagenow']
# ['Pargas', 'Laichingen', 'Wells', 'Wasilków', 'Weinfelden', 'Lauffen am Neckar', 'Leingarten', 'Arth', 'Burladingen', 'Strzelin']
# ['Dăbuleni', 'Wolgast', 'Dinkelsbühl', 'Rovinari', 'Neuenrade', 'Appingedam', 'Tiszakécske', 'Kozloduy', 'Zwönitz', 'Pilis']
# ['Pasłęk', 'Kőszeg', 'Socuéllamos', 'Perleberg', 'Stamboliyski', 'Bicske', 'Warka', 'Comarnic', 'Góra Kalwaria', 'Çüngüş']
# ['Çüngüş', 'Büdelsdorf', 'Oestrich-Winkel', 'Alavus', 'Dąbrowa Tarnowska', 'Wildau', 'Darabani', 'Osterhofen', 'Nyírbátor', 'Doesburg']
# ['Sárbogárd', 'Hildburghausen', 'Lichtenstein', 'Sajószentpéter', 'Geisenheim', 'Diez', 'Janów Lubelski', 'Tosashimizu', 'Bad Dürrenberg', 'Drolshagen']
# ['Mülheim-Kärlich', 'Miesbach', 'Nieuwpoort', 'Nowe Miasto Lubawskie', 'Vendas Novas', 'Bopfingen', 'Oberderdingen', 'Monschau', 'Hauzenberg', 'Neuhausen am Rheinfall']
# ['Kankaanpää', 'Liman', 'Liman', 'Lieksa', 'Góra', 'Krujë', 'Aesch', 'Wolmirstedt', 'Isaszeg', 'Orchha']
# ['Gräfenhainichen', 'Matca', 'Walldürn', 'Durbuy', 'Santa Comba Dão', 'Geisenfeld', 'Billerbeck', 'Muzaffarnagar', 'Hinwil', 'Bad Nenndorf']
# ['Schwaigern', 'Radnevo', 'Drawsko Pomorskie', 'Videle', 'Möhlin', 'Schöningen', 'Marktheidenfeld', 'Săcueni', 'Stollberg', 'Risch']
# ['Werther', 'Rutesheim', 'Bad Schwalbach', 'Ciechocinek', 'Mogilno', 'Wittingen', 'Esil', 'Esil', 'Rheinau', 'Cholpon-Ata']
# ['Welzheim', 'Myronivka', 'Târgu Ocna', 'Rothenburg ob der Tauber', 'Balve', 'Beclean', 'Lenzburg', 'Ochsenfurt', 'Kostinbrod', 'Bátonyterenye']
# ['Lajosmizse', 'Herbolzheim', 'Virton', 'Körmend', 'Czarnków', 'Flawil', 'Waidhofen an der Ybbs', 'Suhr', 'Sárospatak', 'Lauingen']
# ['Călan', 'Lang Suan', 'Burrel', 'Miechów', 'Tsqaltubo', 'Krosno Odrzańskie', 'Eisenberg', 'Eisenberg', 'Marcali', 'Nieder-Olm']
# ['Lubawa', 'Engen', 'Lorch', 'Glückstadt', 'Linluo', 'Braunfels', 'Tinchlik', 'Węgorzewo', 'Gengenbach', 'Isselburg']
# ['Regen', 'Szprotawa', 'Hârlău', 'Barmstedt', 'Osterwieck', 'Betzdorf', 'Wisła', 'Flöha', 'Tolna', 'Damme']
# ['Ráckeve', 'Hammelburg', 'Myślibórz', 'Dolhasca', 'Milicz', 'Szydłowiec', 'Burgstädt', 'Olbernhau', 'Donzdorf', 'Rogoźno']
# ['Schleusingen', 'Hakone', 'Gernsheim', 'Waldkirchen', 'Koronowo', 'Rüthen', 'Kiskunmajsa', 'Altensteig', 'Sângeorz-Băi', 'Süßen']
# ['Wronki', 'Haigerloch', 'Bischofswerda', 'Bad Iburg', 'Boizenburg', 'Kowary', 'Kisújszállás', 'Langenzenn', 'Riedlingen', 'Borgloon']
# ['Meßstetten', 'Sagarejo', 'Kenzingen', 'Davos', 'Nivala', 'Le Locle', 'Erlenbach am Main', 'Lollar', 'Reguengos de Monsaraz', 'Kuršėnai']
# ['Braunsbedra', 'Tököl', 'Tiszaföldvár', 'Tiszafüred', 'Demmin', 'Nowa Dęba', 'Bleicherode', 'Felsberg', 'Tangerhütte', 'Aigle']
# ['Lichtenau', 'Tafalla', 'Neuenhaus', 'Burgau', 'Paimio', 'Weilheim an der Teck', 'Querfurt', 'Flămânzi', 'Zdzieszowice', 'Altötting']
# ['Grevesmühlen', 'Spa', 'Parczew', 'Biskupiec', 'Gommern', 'Nossen', 'Borjomi', 'Bad Orb', 'Dnestrovsc', 'Bad Wildbad']
# ['Huittinen', 'Wildberg', 'Etropole', 'Aulendorf', 'Niebüll', 'Bogen', 'Tangermünde', 'Neuenstadt am Kocher', 'Năsăud', 'Werlte']
# ['Simbach am Inn', 'Knezha', 'Lipova', 'Steinau an der Straße', 'Głogów Małopolski', 'Førde', 'Münchberg', 'Nideggen', 'Murowana Goślina', 'Międzychód']
# ['Heubach', 'Meuselwitz', 'Blumberg', 'Syców', 'Göytəpə', 'Göytəpə', 'Rehburg-Loccum', 'Pechea', 'Pińczów', 'Garliava']
# ['Serebryansk', 'Serebryansk', 'Schotten', 'Rüdesheim am Rhein', 'Pavlikeni', 'Beilngries', 'Levski', 'Alajärvi', 'Trebbin', 'Elhovo']
# ['Momchilgrad', 'Tutrakan', 'Khoni', 'Tirupati', 'Marginea']

# %%
# Out:
# 4845
