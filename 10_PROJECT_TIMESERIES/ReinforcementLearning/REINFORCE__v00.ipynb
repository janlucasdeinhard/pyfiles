# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import warnings,os,time,datetime,sys

import torch
import pandas as pd

import gym

# %%
class Net(torch.nn.Module):
    def __init__(self,env):
        super(Net,self).__init__()
        self.l0 = torch.nn.Linear(env.observation_space.shape[0],16)
        self.l1 = torch.nn.Linear(16,env.action_space.n)
    def forward(self,x):
        x = torch.nn.functional.relu(self.l0(x))
        x = torch.nn.functional.softmax(self.l1(x))
        return x

# %%
def discount_rewards(rewards,gamma=0.99):
    r = np.array([gamma**k*rewards[k] for k in range(len(rewards))])
    r = r[::-1].cumsum()[::-1]
    return r-r.mean()

# %%
batch_size = 25

# %%
env = gym.make('CartPole-v0')
action_space = np.arange(env.action_space.n)

net = Net(env)
optimizer = torch.optim.Adam(net.parameters(),lr=0.01)
# Out:
# C:\Users\Jan\Anaconda3\lib\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
total_rewards = []

batch_rewards = []
batch_actions = []
batch_states = []

batch_counter = 1

episodes = 0
while episodes<500:

    s0 = env.reset()

    states = []
    rewards = []
    actions = []

    done = False

    while not done:

        action_probs = net(torch.FloatTensor(s0)).detach().numpy()
        action_c = rnd.choice(action_space,p=action_probs)

        s1,r,done,_ = env.step(action_c)

        states.append(s0)
        rewards.append(r)
        actions.append(action_c)

        s0 = s1

        if done:

            total_rewards.append(sum(rewards))

            batch_states.extend(states)
            batch_rewards.extend(discount_rewards(rewards))
            batch_actions.extend(actions)

            batch_counter += 1

            if batch_counter==batch_size:

                optimizer.zero_grad()

                state_t = torch.FloatTensor(batch_states)
                reward_t = torch.FloatTensor(batch_rewards)
                action_t = torch.LongTensor(batch_actions)

                logprob = torch.log(net(state_t))
                selected_logprobs = reward_t*torch.gather(logprob,1,action_t.reshape(action_t.shape[0],1)).squeeze()
                loss = -selected_logprobs.mean()

                loss.backward()
                optimizer.step()

                batch_states = []
                batch_rewards = []
                batch_actions = []
                batch_counter = 1
                
            print('Avg rewards over previous 100 episodes: {}'.format(np.mean(total_rewards[-100:])))
            episodes += 1
            
env.close()
# Out:
# C:\Users\Jan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Avg rewards over previous 100 episodes: 8.0
# Avg rewards over previous 100 episodes: 14.0
# Avg rewards over previous 100 episodes: 18.0
# Avg rewards over previous 100 episodes: 16.75
# Avg rewards over previous 100 episodes: 17.6
# Avg rewards over previous 100 episodes: 16.5
# Avg rewards over previous 100 episodes: 16.0
# Avg rewards over previous 100 episodes: 15.5
# Avg rewards over previous 100 episodes: 16.555555555555557
# Avg rewards over previous 100 episodes: 17.4
# Avg rewards over previous 100 episodes: 18.0
# Avg rewards over previous 100 episodes: 17.75
# Avg rewards over previous 100 episodes: 17.076923076923077
# Avg rewards over previous 100 episodes: 17.0
# Avg rewards over previous 100 episodes: 17.2
# Avg rewards over previous 100 episodes: 16.875
# Avg rewards over previous 100 episodes: 17.352941176470587
# Avg rewards over previous 100 episodes: 17.055555555555557
# Avg rewards over previous 100 episodes: 16.842105263157894
# Avg rewards over previous 100 episodes: 16.9
# Avg rewards over previous 100 episodes: 18.333333333333332
# Avg rewards over previous 100 episodes: 17.954545454545453
# Avg rewards over previous 100 episodes: 19.08695652173913
# Avg rewards over previous 100 episodes: 20.625
# Avg rewards over previous 100 episodes: 21.08
# Avg rewards over previous 100 episodes: 20.76923076923077
# Avg rewards over previous 100 episodes: 20.40740740740741
# Avg rewards over previous 100 episodes: 20.428571428571427
# Avg rewards over previous 100 episodes: 21.275862068965516
# Avg rewards over previous 100 episodes: 21.166666666666668
# Avg rewards over previous 100 episodes: 21.0
# Avg rewards over previous 100 episodes: 21.21875
# Avg rewards over previous 100 episodes: 21.757575757575758
# Avg rewards over previous 100 episodes: 21.38235294117647
# Avg rewards over previous 100 episodes: 21.257142857142856
# Avg rewards over previous 100 episodes: 21.333333333333332
# Avg rewards over previous 100 episodes: 21.16216216216216
# Avg rewards over previous 100 episodes: 21.57894736842105
# Avg rewards over previous 100 episodes: 21.692307692307693
# Avg rewards over previous 100 episodes: 21.675
# Avg rewards over previous 100 episodes: 21.658536585365855
# Avg rewards over previous 100 episodes: 21.785714285714285
# Avg rewards over previous 100 episodes: 21.767441860465116
# Avg rewards over previous 100 episodes: 22.09090909090909
# Avg rewards over previous 100 episodes: 21.977777777777778
# Avg rewards over previous 100 episodes: 21.91304347826087
# Avg rewards over previous 100 episodes: 21.80851063829787
# Avg rewards over previous 100 episodes: 21.729166666666668
# Avg rewards over previous 100 episodes: 21.551020408163264
# Avg rewards over previous 100 episodes: 21.54
# Avg rewards over previous 100 episodes: 21.607843137254903
# Avg rewards over previous 100 episodes: 21.51923076923077
# Avg rewards over previous 100 episodes: 21.32075471698113
# Avg rewards over previous 100 episodes: 21.203703703703702
# Avg rewards over previous 100 episodes: 21.89090909090909
# Avg rewards over previous 100 episodes: 22.125
# Avg rewards over previous 100 episodes: 22.087719298245613
# Avg rewards over previous 100 episodes: 22.189655172413794
# Avg rewards over previous 100 episodes: 22.440677966101696
# Avg rewards over previous 100 episodes: 22.283333333333335
# Avg rewards over previous 100 episodes: 22.475409836065573
# Avg rewards over previous 100 episodes: 22.403225806451612
# Avg rewards over previous 100 episodes: 22.365079365079364
# Avg rewards over previous 100 episodes: 22.5
# Avg rewards over previous 100 episodes: 22.661538461538463
# Avg rewards over previous 100 episodes: 22.46969696969697
# Avg rewards over previous 100 episodes: 22.35820895522388
# Avg rewards over previous 100 episodes: 22.264705882352942
# Avg rewards over previous 100 episodes: 22.36231884057971
# Avg rewards over previous 100 episodes: 22.34285714285714
# Avg rewards over previous 100 episodes: 22.239436619718308
# Avg rewards over previous 100 episodes: 22.27777777777778
# Avg rewards over previous 100 episodes: 22.82191780821918
# Avg rewards over previous 100 episodes: 22.68918918918919
# Avg rewards over previous 100 episodes: 22.773333333333333
# Avg rewards over previous 100 episodes: 22.960526315789473
# Avg rewards over previous 100 episodes: 22.844155844155843
# Avg rewards over previous 100 episodes: 22.71794871794872
# Avg rewards over previous 100 episodes: 22.848101265822784
# Avg rewards over previous 100 episodes: 23.1
# Avg rewards over previous 100 episodes: 23.160493827160494
# Avg rewards over previous 100 episodes: 23.195121951219512
# Avg rewards over previous 100 episodes: 23.44578313253012
# Avg rewards over previous 100 episodes: 23.392857142857142
# Avg rewards over previous 100 episodes: 23.388235294117646
# Avg rewards over previous 100 episodes: 23.406976744186046
# Avg rewards over previous 100 episodes: 23.482758620689655
# Avg rewards over previous 100 episodes: 24.329545454545453
# Avg rewards over previous 100 episodes: 24.808988764044944
# Avg rewards over previous 100 episodes: 24.77777777777778
# Avg rewards over previous 100 episodes: 24.791208791208792
# Avg rewards over previous 100 episodes: 25.695652173913043
# Avg rewards over previous 100 episodes: 25.655913978494624
# Avg rewards over previous 100 episodes: 25.574468085106382
# Avg rewards over previous 100 episodes: 25.473684210526315
# Avg rewards over previous 100 episodes: 25.3125
# Avg rewards over previous 100 episodes: 25.391752577319586
# Avg rewards over previous 100 episodes: 25.367346938775512
# Avg rewards over previous 100 episodes: 25.242424242424242
# Avg rewards over previous 100 episodes: 25.54
# Avg rewards over previous 100 episodes: 25.93
# Avg rewards over previous 100 episodes: 25.87
# Avg rewards over previous 100 episodes: 25.79
# Avg rewards over previous 100 episodes: 25.84
# Avg rewards over previous 100 episodes: 25.81
# Avg rewards over previous 100 episodes: 25.83
# Avg rewards over previous 100 episodes: 25.86
# Avg rewards over previous 100 episodes: 25.96
# Avg rewards over previous 100 episodes: 25.91
# Avg rewards over previous 100 episodes: 26.29
# Avg rewards over previous 100 episodes: 26.23
# Avg rewards over previous 100 episodes: 26.38
# Avg rewards over previous 100 episodes: 26.5
# Avg rewards over previous 100 episodes: 26.86
# Avg rewards over previous 100 episodes: 27.56
# Avg rewards over previous 100 episodes: 27.86
# Avg rewards over previous 100 episodes: 27.97
# Avg rewards over previous 100 episodes: 28.13
# Avg rewards over previous 100 episodes: 28.19
# Avg rewards over previous 100 episodes: 28.22
# Avg rewards over previous 100 episodes: 27.98
# Avg rewards over previous 100 episodes: 28.03
# Avg rewards over previous 100 episodes: 27.9
# Avg rewards over previous 100 episodes: 27.84
# Avg rewards over previous 100 episodes: 27.67
# Avg rewards over previous 100 episodes: 27.7
# Avg rewards over previous 100 episodes: 28.04
# Avg rewards over previous 100 episodes: 27.98
# Avg rewards over previous 100 episodes: 27.86
# Avg rewards over previous 100 episodes: 27.8
# Avg rewards over previous 100 episodes: 27.86
# Avg rewards over previous 100 episodes: 27.9
# Avg rewards over previous 100 episodes: 27.86
# Avg rewards over previous 100 episodes: 28.16
# Avg rewards over previous 100 episodes: 28.25
# Avg rewards over previous 100 episodes: 28.27
# Avg rewards over previous 100 episodes: 28.3
# Avg rewards over previous 100 episodes: 28.24
# Avg rewards over previous 100 episodes: 28.38
# Avg rewards over previous 100 episodes: 28.68
# Avg rewards over previous 100 episodes: 28.67
# Avg rewards over previous 100 episodes: 28.69
# Avg rewards over previous 100 episodes: 28.71
# Avg rewards over previous 100 episodes: 28.63
# Avg rewards over previous 100 episodes: 28.72
# Avg rewards over previous 100 episodes: 29.08
# Avg rewards over previous 100 episodes: 29.11
# Avg rewards over previous 100 episodes: 29.08
# Avg rewards over previous 100 episodes: 29.33
# Avg rewards over previous 100 episodes: 29.29
# Avg rewards over previous 100 episodes: 29.26
# Avg rewards over previous 100 episodes: 29.5
# Avg rewards over previous 100 episodes: 29.65
# Avg rewards over previous 100 episodes: 29.92
# Avg rewards over previous 100 episodes: 29.52
# Avg rewards over previous 100 episodes: 29.61
# Avg rewards over previous 100 episodes: 29.71
# Avg rewards over previous 100 episodes: 29.75
# Avg rewards over previous 100 episodes: 29.59
# Avg rewards over previous 100 episodes: 29.77
# Avg rewards over previous 100 episodes: 29.75
# Avg rewards over previous 100 episodes: 29.83
# Avg rewards over previous 100 episodes: 29.76
# Avg rewards over previous 100 episodes: 29.58
# Avg rewards over previous 100 episodes: 29.46
# Avg rewards over previous 100 episodes: 30.08
# Avg rewards over previous 100 episodes: 30.3
# Avg rewards over previous 100 episodes: 31.31
# Avg rewards over previous 100 episodes: 31.56
# Avg rewards over previous 100 episodes: 31.65
# Avg rewards over previous 100 episodes: 31.8
# Avg rewards over previous 100 episodes: 31.84
# Avg rewards over previous 100 episodes: 31.41
# Avg rewards over previous 100 episodes: 31.46
# Avg rewards over previous 100 episodes: 31.3
# Avg rewards over previous 100 episodes: 31.05
# Avg rewards over previous 100 episodes: 31.15
# Avg rewards over previous 100 episodes: 31.21
# Avg rewards over previous 100 episodes: 31.13
# Avg rewards over previous 100 episodes: 30.95
# Avg rewards over previous 100 episodes: 30.99
# Avg rewards over previous 100 episodes: 30.98
# Avg rewards over previous 100 episodes: 30.75
# Avg rewards over previous 100 episodes: 30.69
# Avg rewards over previous 100 episodes: 30.59
# Avg rewards over previous 100 episodes: 30.63
# Avg rewards over previous 100 episodes: 30.57
# Avg rewards over previous 100 episodes: 29.78
# Avg rewards over previous 100 episodes: 29.26
# Avg rewards over previous 100 episodes: 29.29
# Avg rewards over previous 100 episodes: 29.22
# Avg rewards over previous 100 episodes: 28.28
# Avg rewards over previous 100 episodes: 28.29
# Avg rewards over previous 100 episodes: 28.28
# Avg rewards over previous 100 episodes: 28.28
# Avg rewards over previous 100 episodes: 28.5
# Avg rewards over previous 100 episodes: 28.28
# Avg rewards over previous 100 episodes: 28.33
# Avg rewards over previous 100 episodes: 28.41
# Avg rewards over previous 100 episodes: 28.06
# Avg rewards over previous 100 episodes: 27.84
# Avg rewards over previous 100 episodes: 27.8
# Avg rewards over previous 100 episodes: 27.84
# Avg rewards over previous 100 episodes: 28.38
# Avg rewards over previous 100 episodes: 28.42
# Avg rewards over previous 100 episodes: 28.95
# Avg rewards over previous 100 episodes: 29.12
# Avg rewards over previous 100 episodes: 29.36
# Avg rewards over previous 100 episodes: 29.38
# Avg rewards over previous 100 episodes: 28.94
# Avg rewards over previous 100 episodes: 29.1
# Avg rewards over previous 100 episodes: 28.91
# Avg rewards over previous 100 episodes: 28.88
# Avg rewards over previous 100 episodes: 28.84
# Avg rewards over previous 100 episodes: 28.25
# Avg rewards over previous 100 episodes: 28.07
# Avg rewards over previous 100 episodes: 28.54
# Avg rewards over previous 100 episodes: 28.63
# Avg rewards over previous 100 episodes: 28.86
# Avg rewards over previous 100 episodes: 29.52
# Avg rewards over previous 100 episodes: 29.86
# Avg rewards over previous 100 episodes: 29.85
# Avg rewards over previous 100 episodes: 29.7
# Avg rewards over previous 100 episodes: 29.58
# Avg rewards over previous 100 episodes: 29.67
# Avg rewards over previous 100 episodes: 29.87
# Avg rewards over previous 100 episodes: 29.74
# Avg rewards over previous 100 episodes: 29.89
# Avg rewards over previous 100 episodes: 30.06
# Avg rewards over previous 100 episodes: 30.22
# Avg rewards over previous 100 episodes: 30.43
# Avg rewards over previous 100 episodes: 30.25
# Avg rewards over previous 100 episodes: 30.13
# Avg rewards over previous 100 episodes: 29.94
# Avg rewards over previous 100 episodes: 29.98
# Avg rewards over previous 100 episodes: 30.0
# Avg rewards over previous 100 episodes: 29.98
# Avg rewards over previous 100 episodes: 30.33
# Avg rewards over previous 100 episodes: 30.35
# Avg rewards over previous 100 episodes: 30.13
# Avg rewards over previous 100 episodes: 30.26
# Avg rewards over previous 100 episodes: 30.09
# Avg rewards over previous 100 episodes: 30.34
# Avg rewards over previous 100 episodes: 30.34
# Avg rewards over previous 100 episodes: 30.52
# Avg rewards over previous 100 episodes: 30.28
# Avg rewards over previous 100 episodes: 30.39
# Avg rewards over previous 100 episodes: 30.58
# Avg rewards over previous 100 episodes: 30.37
# Avg rewards over previous 100 episodes: 30.46
# Avg rewards over previous 100 episodes: 30.55
# Avg rewards over previous 100 episodes: 31.17
# Avg rewards over previous 100 episodes: 31.35
# Avg rewards over previous 100 episodes: 31.12
# Avg rewards over previous 100 episodes: 31.21
# Avg rewards over previous 100 episodes: 31.01
# Avg rewards over previous 100 episodes: 31.0
# Avg rewards over previous 100 episodes: 31.16
# Avg rewards over previous 100 episodes: 31.32
# Avg rewards over previous 100 episodes: 31.3
# Avg rewards over previous 100 episodes: 31.25
# Avg rewards over previous 100 episodes: 31.46
# Avg rewards over previous 100 episodes: 31.7
# Avg rewards over previous 100 episodes: 32.05
# Avg rewards over previous 100 episodes: 32.24
# Avg rewards over previous 100 episodes: 31.81
# Avg rewards over previous 100 episodes: 31.66
# Avg rewards over previous 100 episodes: 30.97
# Avg rewards over previous 100 episodes: 31.29
# Avg rewards over previous 100 episodes: 31.13
# Avg rewards over previous 100 episodes: 31.06
# Avg rewards over previous 100 episodes: 31.8
# Avg rewards over previous 100 episodes: 32.16
# Avg rewards over previous 100 episodes: 32.34
# Avg rewards over previous 100 episodes: 32.42
# Avg rewards over previous 100 episodes: 32.72
# Avg rewards over previous 100 episodes: 32.9
# Avg rewards over previous 100 episodes: 32.96
# Avg rewards over previous 100 episodes: 33.24
# Avg rewards over previous 100 episodes: 33.31
# Avg rewards over previous 100 episodes: 33.88
# Avg rewards over previous 100 episodes: 33.98
# Avg rewards over previous 100 episodes: 34.2
# Avg rewards over previous 100 episodes: 34.21
# Avg rewards over previous 100 episodes: 34.97
# Avg rewards over previous 100 episodes: 35.21
# Avg rewards over previous 100 episodes: 35.22
# Avg rewards over previous 100 episodes: 35.44
# Avg rewards over previous 100 episodes: 35.8
# Avg rewards over previous 100 episodes: 35.79
# Avg rewards over previous 100 episodes: 35.8
# Avg rewards over previous 100 episodes: 36.83
# Avg rewards over previous 100 episodes: 37.04
# Avg rewards over previous 100 episodes: 37.22
# Avg rewards over previous 100 episodes: 37.81
# Avg rewards over previous 100 episodes: 37.88
# Avg rewards over previous 100 episodes: 38.34
# Avg rewards over previous 100 episodes: 38.3
# Avg rewards over previous 100 episodes: 38.84
# Avg rewards over previous 100 episodes: 39.03
# Avg rewards over previous 100 episodes: 39.27
# Avg rewards over previous 100 episodes: 39.81
# Avg rewards over previous 100 episodes: 40.39
# Avg rewards over previous 100 episodes: 39.97
# Avg rewards over previous 100 episodes: 39.98
# Avg rewards over previous 100 episodes: 39.74
# Avg rewards over previous 100 episodes: 39.7
# Avg rewards over previous 100 episodes: 39.42
# Avg rewards over previous 100 episodes: 39.44
# Avg rewards over previous 100 episodes: 39.5
# Avg rewards over previous 100 episodes: 39.37
# Avg rewards over previous 100 episodes: 39.61
# Avg rewards over previous 100 episodes: 39.85
# Avg rewards over previous 100 episodes: 39.49
# Avg rewards over previous 100 episodes: 39.46
# Avg rewards over previous 100 episodes: 39.52
# Avg rewards over previous 100 episodes: 39.02
# Avg rewards over previous 100 episodes: 39.36
# Avg rewards over previous 100 episodes: 39.38
# Avg rewards over previous 100 episodes: 38.81
# Avg rewards over previous 100 episodes: 38.7
# Avg rewards over previous 100 episodes: 38.78
# Avg rewards over previous 100 episodes: 39.04
# Avg rewards over previous 100 episodes: 38.8
# Avg rewards over previous 100 episodes: 39.26
# Avg rewards over previous 100 episodes: 39.38
# Avg rewards over previous 100 episodes: 39.65
# Avg rewards over previous 100 episodes: 39.74
# Avg rewards over previous 100 episodes: 39.67
# Avg rewards over previous 100 episodes: 40.28
# Avg rewards over previous 100 episodes: 40.2
# Avg rewards over previous 100 episodes: 40.59
# Avg rewards over previous 100 episodes: 41.05
# Avg rewards over previous 100 episodes: 41.12
# Avg rewards over previous 100 episodes: 41.18
# Avg rewards over previous 100 episodes: 41.19
# Avg rewards over previous 100 episodes: 41.34
# Avg rewards over previous 100 episodes: 41.53
# Avg rewards over previous 100 episodes: 41.65
# Avg rewards over previous 100 episodes: 41.73
# Avg rewards over previous 100 episodes: 42.01
# Avg rewards over previous 100 episodes: 42.15
# Avg rewards over previous 100 episodes: 41.98
# Avg rewards over previous 100 episodes: 41.89
# Avg rewards over previous 100 episodes: 41.58
# Avg rewards over previous 100 episodes: 41.85
# Avg rewards over previous 100 episodes: 41.75
# Avg rewards over previous 100 episodes: 41.75
# Avg rewards over previous 100 episodes: 42.17
# Avg rewards over previous 100 episodes: 42.52
# Avg rewards over previous 100 episodes: 42.71
# Avg rewards over previous 100 episodes: 42.22
# Avg rewards over previous 100 episodes: 42.05
# Avg rewards over previous 100 episodes: 42.28
# Avg rewards over previous 100 episodes: 42.46
# Avg rewards over previous 100 episodes: 42.72
# Avg rewards over previous 100 episodes: 42.95
# Avg rewards over previous 100 episodes: 42.75
# Avg rewards over previous 100 episodes: 42.69
# Avg rewards over previous 100 episodes: 42.93
# Avg rewards over previous 100 episodes: 43.12
# Avg rewards over previous 100 episodes: 43.11
# Avg rewards over previous 100 episodes: 43.03
# Avg rewards over previous 100 episodes: 43.14
# Avg rewards over previous 100 episodes: 43.33
# Avg rewards over previous 100 episodes: 43.7
# Avg rewards over previous 100 episodes: 43.74
# Avg rewards over previous 100 episodes: 43.49
# Avg rewards over previous 100 episodes: 43.02
# Avg rewards over previous 100 episodes: 43.53
# Avg rewards over previous 100 episodes: 43.56
# Avg rewards over previous 100 episodes: 42.84
# Avg rewards over previous 100 episodes: 42.53
# Avg rewards over previous 100 episodes: 42.48
# Avg rewards over previous 100 episodes: 42.48
# Avg rewards over previous 100 episodes: 42.44
# Avg rewards over previous 100 episodes: 42.31
# Avg rewards over previous 100 episodes: 42.43
# Avg rewards over previous 100 episodes: 42.55
# Avg rewards over previous 100 episodes: 42.47
# Avg rewards over previous 100 episodes: 41.86
# Avg rewards over previous 100 episodes: 41.71
# Avg rewards over previous 100 episodes: 41.46
# Avg rewards over previous 100 episodes: 41.62
# Avg rewards over previous 100 episodes: 41.41
# Avg rewards over previous 100 episodes: 41.21
# Avg rewards over previous 100 episodes: 41.37
# Avg rewards over previous 100 episodes: 41.56
# Avg rewards over previous 100 episodes: 41.53
# Avg rewards over previous 100 episodes: 41.56
# Avg rewards over previous 100 episodes: 41.64
# Avg rewards over previous 100 episodes: 41.14
# Avg rewards over previous 100 episodes: 41.13
# Avg rewards over previous 100 episodes: 41.14
# Avg rewards over previous 100 episodes: 41.11
# Avg rewards over previous 100 episodes: 41.99
# Avg rewards over previous 100 episodes: 41.82
# Avg rewards over previous 100 episodes: 41.85
# Avg rewards over previous 100 episodes: 41.74
# Avg rewards over previous 100 episodes: 41.94
# Avg rewards over previous 100 episodes: 41.76
# Avg rewards over previous 100 episodes: 42.13
# Avg rewards over previous 100 episodes: 41.62
# Avg rewards over previous 100 episodes: 41.66
# Avg rewards over previous 100 episodes: 42.03
# Avg rewards over previous 100 episodes: 41.86
# Avg rewards over previous 100 episodes: 41.85
# Avg rewards over previous 100 episodes: 41.96
# Avg rewards over previous 100 episodes: 41.98
# Avg rewards over previous 100 episodes: 42.14
# Avg rewards over previous 100 episodes: 42.33
# Avg rewards over previous 100 episodes: 42.19
# Avg rewards over previous 100 episodes: 42.35
# Avg rewards over previous 100 episodes: 42.57
# Avg rewards over previous 100 episodes: 42.61
# Avg rewards over previous 100 episodes: 42.73
# Avg rewards over previous 100 episodes: 43.08
# Avg rewards over previous 100 episodes: 42.59
# Avg rewards over previous 100 episodes: 42.53
# Avg rewards over previous 100 episodes: 42.45
# Avg rewards over previous 100 episodes: 42.35
# Avg rewards over previous 100 episodes: 43.14
# Avg rewards over previous 100 episodes: 43.13
# Avg rewards over previous 100 episodes: 43.74
# Avg rewards over previous 100 episodes: 44.27
# Avg rewards over previous 100 episodes: 44.96
# Avg rewards over previous 100 episodes: 44.61
# Avg rewards over previous 100 episodes: 44.79
# Avg rewards over previous 100 episodes: 44.58
# Avg rewards over previous 100 episodes: 43.99
# Avg rewards over previous 100 episodes: 44.27
# Avg rewards over previous 100 episodes: 44.05
# Avg rewards over previous 100 episodes: 43.57
# Avg rewards over previous 100 episodes: 43.62
# Avg rewards over previous 100 episodes: 44.11
# Avg rewards over previous 100 episodes: 44.54
# Avg rewards over previous 100 episodes: 44.76
# Avg rewards over previous 100 episodes: 44.53
# Avg rewards over previous 100 episodes: 44.71
# Avg rewards over previous 100 episodes: 44.89
# Avg rewards over previous 100 episodes: 44.91
# Avg rewards over previous 100 episodes: 46.15
# Avg rewards over previous 100 episodes: 46.74
# Avg rewards over previous 100 episodes: 47.05
# Avg rewards over previous 100 episodes: 47.5
# Avg rewards over previous 100 episodes: 47.83
# Avg rewards over previous 100 episodes: 47.98
# Avg rewards over previous 100 episodes: 47.99
# Avg rewards over previous 100 episodes: 48.12
# Avg rewards over previous 100 episodes: 47.77
# Avg rewards over previous 100 episodes: 47.9
# Avg rewards over previous 100 episodes: 47.98
# Avg rewards over previous 100 episodes: 47.9
# Avg rewards over previous 100 episodes: 47.74
# Avg rewards over previous 100 episodes: 47.76
# Avg rewards over previous 100 episodes: 49.26
# Avg rewards over previous 100 episodes: 49.42
# Avg rewards over previous 100 episodes: 49.61
# Avg rewards over previous 100 episodes: 50.73
# Avg rewards over previous 100 episodes: 50.78
# Avg rewards over previous 100 episodes: 50.69
# Avg rewards over previous 100 episodes: 50.59
# Avg rewards over previous 100 episodes: 51.52
# Avg rewards over previous 100 episodes: 51.31
# Avg rewards over previous 100 episodes: 51.55
# Avg rewards over previous 100 episodes: 51.69
# Avg rewards over previous 100 episodes: 51.85
# Avg rewards over previous 100 episodes: 52.44
# Avg rewards over previous 100 episodes: 52.72
# Avg rewards over previous 100 episodes: 53.18
# Avg rewards over previous 100 episodes: 53.76
# Avg rewards over previous 100 episodes: 53.93
# Avg rewards over previous 100 episodes: 53.84
# Avg rewards over previous 100 episodes: 53.85
# Avg rewards over previous 100 episodes: 54.51
# Avg rewards over previous 100 episodes: 54.86
# Avg rewards over previous 100 episodes: 55.43
# Avg rewards over previous 100 episodes: 56.14
# Avg rewards over previous 100 episodes: 56.63
# Avg rewards over previous 100 episodes: 57.26
# Avg rewards over previous 100 episodes: 57.33
# Avg rewards over previous 100 episodes: 57.65
# Avg rewards over previous 100 episodes: 58.38
# Avg rewards over previous 100 episodes: 58.56
# Avg rewards over previous 100 episodes: 59.03
# Avg rewards over previous 100 episodes: 59.26
# Avg rewards over previous 100 episodes: 59.68
# Avg rewards over previous 100 episodes: 59.42
# Avg rewards over previous 100 episodes: 60.9
# Avg rewards over previous 100 episodes: 60.98
# Avg rewards over previous 100 episodes: 61.41
# Avg rewards over previous 100 episodes: 61.26
# Avg rewards over previous 100 episodes: 61.59
# Avg rewards over previous 100 episodes: 61.54
# Avg rewards over previous 100 episodes: 61.1
# Avg rewards over previous 100 episodes: 60.12
# Avg rewards over previous 100 episodes: 60.07
# Avg rewards over previous 100 episodes: 60.16
# Avg rewards over previous 100 episodes: 59.69
# Avg rewards over previous 100 episodes: 59.53

# %%
env = gym.make('CartPole-v0')

s0 = env.reset()
env.render()

done = False
while not done:
    
    action_probs = net(torch.FloatTensor(s0)).detach().numpy()
    action_c = rnd.choice(action_space,p=action_probs)
    
    s0,r,done,_ = env.step(action_c)
    env.render()

env.close()
# Out:
# C:\Users\Jan\Anaconda3\lib\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# C:\Users\Jan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
