# %%
import pandas as pd
from pandas.plotting import autocorrelation_plot

import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings,os

import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense,Conv2D,Dropout,LSTM

# %%
data = pd.read_csv('Data\\data1\\all_stocks_5yr.csv')
data['date'] = pd.to_datetime(data['date'],infer_datetime_format=True)
data = data.set_index(keys='date',drop=True)

# %%
for colname in data.Name.unique():
    try:
        df[colname]=data[data['Name']==colname]['high']
    except:
        continue

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr().abs())

# %%
corr_mean=df.corr().abs().mean()

# %%
corr_mean[corr_mean>0.7]
# Out:
# AVGO    0.701065
# BDX     0.703854
# CTAS    0.703356
# FISV    0.703166
# FIS     0.701245
# FTV     0.705370
# HPQ     0.703445
# INTU    0.700540
# LMT     0.704632
# NOC     0.703615
# SYK     0.700970
# UNH     0.701708
# V       0.700568
# dtype: float64

# %%
corr_mean[corr_mean<0.13]
# Out:
# VZ    0.123415
# dtype: float64
