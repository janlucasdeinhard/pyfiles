# %%
import numpy as np
import tensorflow as tf
import csv
import datetime 

from urllib.parse import urlencode
from urllib.request import urlretrieve
from IPython.display import Image

from astropy.io import fits
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
from astropy.visualization import astropy_mpl_style

from astropy.coordinates import Galactic

from matplotlib import pyplot as plt
plt.style.use(astropy_mpl_style)
# %matplotlib inline

# %%
namestr = 'Bootes Void'

store_path = 'C:\\Users\\Jan\\Desktop\\Pictures\\astropy\\'+namestr.replace(' ','_')+'_'+str(datetime.datetime.now()).replace(' ','_').replace(':','_').replace('.','_')+'.jpeg'
baseurl = 'http://skyservice.pha.jhu.edu/DR12/ImgCutout/getjpeg.aspx'

img_size = 100*u.arcmin
img_pixels = 500

bv_center = SkyCoord.from_name(namestr)

query = urlencode(dict(ra=bv_center.ra.deg,
                       dec=bv_center.dec.deg,
                       width=img_pixels,height=img_pixels,
                       scale=img_size.to(u.arcsec).value/img_pixels))
fullurl = baseurl + '?' + query

urlretrieve(fullurl,store_path)

Image(store_path)

# %%
from astropy.coordinates import EarthLocation,AltAz
from astropy.time import Time

erlangen = EarthLocation(lat='49.580643deg',lon='11.004509deg',height=285.5*u.m)
obsTime = Time('2018-09-11 23:40')

myframe = AltAz(location=erlangen,obstime=obsTime)

print(bv_center.transform_to(myframe))
# Out:
# <SkyCoord (AltAz: obstime=2018-09-11 23:40:00.000, location=(4067476.6507674986, 790969.5661360602, 4832894.368824517) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     ( 328.826658,  13.39790218)>
