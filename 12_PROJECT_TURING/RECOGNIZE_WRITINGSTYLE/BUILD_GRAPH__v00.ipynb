# %%
import numpy as np
from matplotlib import pyplot as plt
from numpy import random as rnd
import warnings,os,datetime,time

import torch
import pandas as pd

from keras.models import Sequential,Model
from keras.layers import Dense,LSTM,Conv2D,Conv2DTranspose,Input,Activation,BatchNormalization,Dropout,concatenate

import pickle

import networkx as nx
# Out:
# C:\Users\Jan\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Jan\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
results = pickle.load(open('.\\DATA\\blogentries_selected_info_condensed.p','rb'))

# %%
df = pd.DataFrame(results).rename(columns={0:'source',1:'edge',2:'target'})

# %%
df[df['source']=='they']
# Out:
#      source        edge       target
# 42     they        have         what
# 45     they        want         them
# 175    they        have       drones
# 264    they      defied          ban
# 310    they        mess        thing
# 330    they        make       couple
# 335    they    updating     software
# 347    they       doing         this
# 351    they        find         tale
# 492    they      review        books
# 495    they        play        music
# 626    they     digging        patio
# 641    they        told         need
# 662    they        arnt         news
# 677    they        rate         land
# 703    they        come         what
# 707    they         're     position
# 724    they        want    something
# 790    they         get         some
# 794    they         got      reviews
# 840    they        have        manga
# 872    they        need       people
# 924    they      opened         team
# 968    they  recruiting           me
# ...

# %%
G = nx.from_pandas_edgelist(df[df['source']=='they'],source='source',target='target',edge_attr=True,create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
