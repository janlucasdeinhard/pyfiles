# %%
# Imports


import numpy as np
import numpy.random as rnd
from matplotlib import pyplot as plt
import tensorflow as tf
import scipy.signal as sig
from datetime import datetime
import csv

import pandas as pd
from pandas_datareader import data as pd_data

from keras.models import Sequential
from keras.layers import LSTM,Dense,Activation,Dropout
# Out:
# Using TensorFlow backend.

# %%
# Functions definition


# Generate data
def data_generator():
    t = np.arange(0,2,0.0002)
    f = np.sin(2*np.pi*7*t)+1.6*np.sin(2*np.pi*9*t)#+1.2*rnd.randn(t.shape[0])
    f = f/np.max(f)
    return f 


# Randomize data
def randomize_data(data,labels):
    idx = rnd.permutation(data.shape[0])
    data = data[idx,:]
    labels = labels[idx,:]
    return data,labels
    

# Split up data into training data and labels
def make_training_data(input_fn,lookback,prediction_len,permute_data=True):
    assert len(input_fn)>1
    data = []
    labels = []
    for k in range(lookback,len(input_fn)-prediction_len+1):
        xin = input_fn[k-lookback:k]
        yout = input_fn[k+prediction_len-1:k+prediction_len]
        data.append(xin)
        labels.append(yout)
    data = np.array(data)
    labels = np.array(labels)
    if permute_data==True:
        data,labels = randomize_data(data,labels)
    return data,labels

# %%
# Parameter setting


lookback = 60
pred_len = 50
state_size = 20

# %%
# Stocks data preparation


# Read in all available stock IDs from drive
with open('stock_symb.txt','r') as f:
    lines = f.readlines()
content = [line.strip() for line in lines]

# Select an ID
test_ticker = content.pop(0)
tickers = [content[i] for i in list(np.random.permutation(np.arange(len(content)))[0:300])]

# Set the time frame
start_date = datetime(2000,1,1)
end_date = datetime(2018,8,5)

DATA = []

# Read data as pandas frame
ctr = 1
for ticker in tickers:
    
    print('Processing ticker %d/%d...'%(ctr,len(tickers)))
    ctr += 1
    
    try:
        panel_data = pd_data.DataReader(ticker,'robinhood',start_date,end_date,retry_count=0)
    except ValueError:
        print('Value error')
    except KeyError:
        print('Key error')


    # Restructure frame
    if not panel_data.index.name=='IDX':
        panel_data.insert(0,'IDX',range(252))
        panel_data = panel_data.set_index('IDX')
    panel_data['close_price'] = panel_data['close_price'].apply(lambda x: float(x))
    
    
    # Append to file
    DATA.append(panel_data)

    
# Merge all data into one file
T_DATA = np.empty(shape=(0,lookback))
T_LABELS = np.empty(shape=(0,1))
for d in DATA:
    d_np = np.array(d['close_price'])
    cdata,clabels = make_training_data(d_np,lookback,pred_len)
    T_DATA = np.append(T_DATA, cdata, axis=0)
    T_LABELS = np.append(T_LABELS, clabels, axis=0)
    

# Randomize data file
data,labels = randomize_data(T_DATA,T_LABELS)
# Out:
# Processing ticker 1/300...
# Processing ticker 2/300...
# Processing ticker 3/300...
# Key error
# Processing ticker 4/300...
# Processing ticker 5/300...
# Processing ticker 6/300...
# Processing ticker 7/300...
# Key error
# Processing ticker 8/300...
# Key error
# Processing ticker 9/300...
# Processing ticker 10/300...
# Processing ticker 11/300...
# Processing ticker 12/300...
# Processing ticker 13/300...
# Key error
# Processing ticker 14/300...
# Processing ticker 231/300...
# Processing ticker 232/300...
# Processing ticker 233/300...
# Processing ticker 234/300...
# Processing ticker 235/300...
# Processing ticker 236/300...
# Processing ticker 237/300...
# Processing ticker 238/300...
# Processing ticker 239/300...
# Processing ticker 240/300...
# Processing ticker 241/300...
# Processing ticker 242/300...
# Processing ticker 243/300...
# Processing ticker 244/300...
# Processing ticker 245/300...
# Processing ticker 246/300...
# Processing ticker 247/300...
# Processing ticker 248/300...
# Processing ticker 249/300...
# Processing ticker 250/300...
# Processing ticker 251/300...
# Processing ticker 252/300...
# Processing ticker 253/300...
# Processing ticker 254/300...
# Processing ticker 255/300...
# Processing ticker 256/300...
# Processing ticker 257/300...
# Processing ticker 258/300...
# Processing ticker 259/300...
# Processing ticker 260/300...
# Processing ticker 261/300...
# Processing ticker 262/300...
# Processing ticker 263/300...
# Processing ticker 264/300...
# Processing ticker 265/300...
# Processing ticker 266/300...
# Processing ticker 267/300...
# Processing ticker 268/300...
# Processing ticker 269/300...
# Processing ticker 270/300...
# Processing ticker 271/300...
# Processing ticker 272/300...
# Processing ticker 273/300...
# Processing ticker 274/300...
# Processing ticker 275/300...
# Processing ticker 276/300...
# Processing ticker 277/300...
# Key error
# Processing ticker 278/300...
# Processing ticker 279/300...
# Processing ticker 280/300...
# Processing ticker 281/300...
# Processing ticker 282/300...
# Key error
# Processing ticker 283/300...
# Processing ticker 284/300...
# Processing ticker 285/300...
# Processing ticker 286/300...
# Processing ticker 287/300...
# Key error
# Processing ticker 288/300...
# Processing ticker 289/300...
# Processing ticker 290/300...
# Processing ticker 291/300...
# Processing ticker 292/300...
# Processing ticker 293/300...
# Processing ticker 294/300...
# Key error
# Processing ticker 295/300...
# Processing ticker 296/300...
# Processing ticker 297/300...
# Processing ticker 298/300...
# Key error
# Processing ticker 299/300...
# Processing ticker 300/300...
# Key error

# %%
# Build predictor


# Build model
model = Sequential()
model.add(LSTM(units=128,input_shape=(lookback,1),return_sequences=True))
model.add(LSTM(units=128,input_shape=(1,128)))
model.add(Dropout(0.2))
model.add(Dense(units=30))
model.add(Dense(units=1))
model.compile(loss='mse',optimizer='adam')


# Build training set
training_set_lstm = np.reshape(data,[data.shape[0],data.shape[1],1])
label_set_lstm = labels


# Training phase
model.fit(training_set_lstm,label_set_lstm,verbose=1,epochs=15,batch_size=10,validation_split=0.1)


# Test phase
try:
    panel_data = pd_data.DataReader(test_ticker,'robinhood',start_date,end_date,retry_count=0)
except ValueError:
    print('Value error')
except KeyError:
    print('Key error')

if not panel_data.index.name=='IDX':
    panel_data.insert(0,'IDX',range(252))
    panel_data = panel_data.set_index('IDX')
panel_data['close_price'] = panel_data['close_price'].apply(lambda x: float(x))

test_array = np.array(panel_data['close_price'])
# Out:
# Train on 38610 samples, validate on 4290 samples
# Epoch 1/15
# 38610/38610 [==============================] - 691s 18ms/step - loss: 107.6084 - val_loss: 113.1410
# Epoch 2/15
# 38610/38610 [==============================] - 530s 14ms/step - loss: 69.6838 - val_loss: 51.6765
# Epoch 3/15
# 38610/38610 [==============================] - 523s 14ms/step - loss: 61.9852 - val_loss: 40.2006
# Epoch 4/15
# 38610/38610 [==============================] - 523s 14ms/step - loss: 59.9165 - val_loss: 45.1479
# Epoch 5/15
# 38610/38610 [==============================] - 521s 13ms/step - loss: 57.4993 - val_loss: 61.2337
# Epoch 6/15
# 38610/38610 [==============================] - 521s 13ms/step - loss: 57.1402 - val_loss: 51.8233
# Epoch 7/15
# 38610/38610 [==============================] - 522s 14ms/step - loss: 53.7784 - val_loss: 55.6965
# Epoch 8/15
# 38610/38610 [==============================] - 518s 13ms/step - loss: 53.8539 - val_loss: 41.8690
# Epoch 9/15
# 38610/38610 [==============================] - 527s 14ms/step - loss: 52.9801 - val_loss: 40.3056
# Epoch 10/15
# 38610/38610 [==============================] - 520s 13ms/step - loss: 52.3320 - val_loss: 52.3763
# Epoch 11/15
# 38610/38610 [==============================] - 525s 14ms/step - loss: 54.0273 - val_loss: 40.2693
# Epoch 12/15
# 38610/38610 [==============================] - 521s 13ms/step - loss: 53.4321 - val_loss: 42.0389
# Epoch 13/15
# 38610/38610 [==============================] - 522s 14ms/step - loss: 51.0363 - val_loss: 51.2237
# Epoch 14/15
# 38610/38610 [==============================] - 519s 13ms/step - loss: 52.5930 - val_loss: 38.9101
# Epoch 15/15
# 38610/38610 [==============================] - 509s 13ms/step - loss: 56.1440 - val_loss: 39.6646

# %%
# Plot results for evaluation

test_ticker = content[1023]

try:
    panel_data = pd_data.DataReader(test_ticker,'robinhood',start_date,end_date,retry_count=0)
except ValueError:
    print('Value error')
except KeyError:
    print('Key error')

if not panel_data.index.name=='IDX':
    panel_data.insert(0,'IDX',range(252))
    panel_data = panel_data.set_index('IDX')
panel_data['close_price'] = panel_data['close_price'].apply(lambda x: float(x))

test_array = np.array(panel_data['close_price'])


invec = test_array[0:lookback]

pred_seq = []

for k in range(lookback,test_array.shape[0]-pred_len):
    invec = test_array[k-lookback:k]
    invec = np.reshape(invec,[1,lookback,1])
    
    pred = model.predict(invec)
    pred_seq.append(pred)
    
pp = np.array(pred_seq)

pp = np.insert(pp,0,pp[0]*np.ones([lookback,1,1]),axis=0)

plt.plot(pp[:,0,0],'b')
plt.plot(test_array,'r')
plt.show()

plt.show()

# %%
# Make artificial data
f = data_generator()
plt.plot(f)
plt.show()


# Generate training and label sets
data,labels = make_training_data(f,lookback,pred_len)


# Print shape of resultig data
print('Data shape: '+str(data.shape))
print('Lable shape: '+str(labels.shape))
# Out:
# Data shape: (9943, 8)
# Lable shape: (9943, 1)

# %%
# SimpleRNN Solution


# Tensorflow RNN model
tf.reset_default_graph()

time_seq = tf.placeholder(shape=[lookback,1],dtype=tf.float32)
state_prev = tf.placeholder(shape=[state_size,1],dtype=tf.float32)
label = tf.placeholder(shape=[1,1],dtype=tf.float32)

Whx = tf.Variable(tf.random_normal([state_size,lookback]))
Whh = tf.Variable(tf.random_normal([state_size,state_size]))
bh = tf.Variable(tf.random_normal([state_size,1]))

Wyh = tf.Variable(tf.random_normal([1,state_size]))
by = tf.Variable(tf.random_normal([1,1]))

next_state = tf.nn.sigmoid(tf.matmul(Whx,time_seq) + tf.matmul(Whh,state_prev) + bh)
prediction = tf.matmul(Wyh,next_state) + by

loss = tf.reduce_mean(tf.square(tf.subtract(prediction,label)))
opt = tf.train.AdamOptimizer(learning_rate=0.01).minimize(loss)


# Training phase
c_ID = 'STOCKSMODEL\\rnn_simple_'+datetime.now().strftime("%Y-%m-%d_%H_%M_%S")+'.ckpt'

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    state = np.zeros(shape=[state_size,1])
    
    for k in range(data.shape[0]):
        _,c_state,c_loss,mypred = sess.run([opt,next_state,loss,prediction],feed_dict={
            time_seq:np.reshape(data[k,:],[lookback,1]),
            state_prev:state,
            label:np.reshape(labels[k],[1,1])
        })
        if k%1000==0:
            print('Training step %d/%d: %f'%(k,data.shape[0],c_loss))
        state = c_state
    
    saver = tf.train.Saver()
    saver.save(sess,c_ID)


# Test phase
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess,c_ID)
    
    myseq = f[0:lookback]
    for k in range(lookback,data.shape[0]-pred_len,pred_len):
        mypred,c_state = sess.run([prediction,state_prev],feed_dict={
            time_seq:np.reshape(f[k:k+lookback],[lookback,1]),
            state_prev:state
        })
        myseq = np.append(myseq,-mypred)
        state = c_state

        
# Plot results
plt.plot(-sig.resample(np.array(myseq),len(f)),'b')
plt.plot(f,'r--')
plt.show()


# Why is it still the negative?
# Out:
# Training step 0/9943: 10.102992
# Training step 1000/9943: 0.050391
# Training step 2000/9943: 0.005031
# Training step 3000/9943: 0.011743
# Training step 4000/9943: 0.094411
# Training step 5000/9943: 0.002424
# Training step 6000/9943: 0.026209
# Training step 7000/9943: 0.003388
# Training step 8000/9943: 0.000098
# Training step 9000/9943: 0.004641
# INFO:tensorflow:Restoring parameters from STOCKSMODEL\rnn_simple_2018-09-07_13_27_49.ckpt

# %%
# Tensorflow Solution


# Tensorflow LSTM model
tf.reset_default_graph()

invec = tf.placeholder(shape=[None,lookback,1],dtype=tf.float32)
outvec = tf.placeholder(shape=[None,1],dtype=tf.float32)
cell_state = tf.placeholder(shape=[None,state_size],dtype=tf.float32)
hidden_state = tf.placeholder(shape=[None,state_size],dtype=tf.float32)

init_state = tf.nn.rnn_cell.LSTMStateTuple(cell_state,hidden_state)
basic_cell = tf.contrib.rnn.BasicLSTMCell(num_units=state_size,state_is_tuple=True)

rnn_out,next_state = tf.nn.dynamic_rnn(basic_cell,invec,initial_state=init_state,dtype=tf.float32)
rstage_out = tf.reshape(rnn_out, [-1,lookback])

prediction = tf.layers.dense(next_state.h,1)
loss = tf.reduce_mean(tf.square(prediction[0] - outvec))
train = tf.train.AdamOptimizer(learning_rate=0.01).minimize(loss)


# Training phase
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    
    this_cell_state = np.zeros([1,state_size])
    this_hidden_state = np.zeros([1,state_size])
    
    ctr = 0
    for (x,y) in zip(data,labels):
        
        _,myloss,mystate = sess.run([train,loss,next_state],feed_dict={
            invec:np.reshape(x,[1,lookback,1]),
            outvec:np.reshape(y,[1,1]),
            cell_state:this_cell_state,
            hidden_state:this_hidden_state
        })
        myloss = np.array(myloss)
        np_state = np.array(mystate)
        
        this_cell_state = np.reshape(np_state[0,:,:],[1,state_size])
        this_hidden_state = np.reshape(np_state[1,:,:],[1,state_size])
        
        if ctr%1000==0: 
            print('Training step %d/%d: %f'%(ctr,data.shape[0],myloss))
        ctr+=1
        
    newpath = '.\\model_dir\\model'+datetime.now().strftime('%Y-%m-%d--%H-%M-%S')+'.ckpt'
    save_path = saver.save(sess,newpath)


# Test phase
with tf.Session() as sess:
    
    saver = tf.train.Saver()
    saver.restore(sess,newpath)
    
    this_cell_state = np.zeros([1,state_size])
    this_hidden_state = np.zeros([1,state_size])
    
    predicted_signal = []
    for k in range(lookback,len(f)-pred_len,pred_len):
        
        myxin = np.reshape(np.array(f[k-lookback:k]),[1,lookback,1])
        cpred,cstate = sess.run([prediction,next_state],feed_dict={
            invec:myxin,
            cell_state:this_cell_state,
            hidden_state:this_hidden_state
        })
        np_state = np.array(cstate)
        
        this_cell_state = np.reshape(np_state[0,:,:],[1,state_size])
        this_hidden_state = np.reshape(np_state[1,:,:],[1,state_size])
        
        predicted_signal.append(cpred[0])
        
        
# Plot results
plt.plot(sig.resample(predicted_signal,f.shape[0]),'b')
plt.plot(f,'r--')
plt.show()


# Needs to resample to original data length!
# Out:
# Training step 0/9943: 0.104018
# Training step 1000/9943: 0.049106
# Training step 2000/9943: 0.007533
# Training step 3000/9943: 0.021593
# Training step 4000/9943: 0.076387
# Training step 5000/9943: 0.123471
# Training step 6000/9943: 0.076697
# Training step 7000/9943: 0.076504
# Training step 8000/9943: 0.068061
# Training step 9000/9943: 0.175571
# INFO:tensorflow:Restoring parameters from .\model_dir\model2018-09-07--13-29-39.ckpt

# %%
# Keras Solution


# Build model
model = Sequential()
model.add(LSTM(units=128,input_shape=(lookback,1)))
model.add(Dense(units=1))
model.compile(loss='mse',optimizer='adam')


# Build training set
training_set_lstm = np.reshape(data,[data.shape[0],data.shape[1],1])
label_set_lstm = labels


# Training phase
model.fit(training_set_lstm,label_set_lstm,verbose=1,epochs=3,batch_size=5,validation_split=0.1)


# Test phase
myseq = f[0:lookback]
for k in range(lookback,data.shape[0]-pred_len,pred_len):
    mypred = model.predict(np.reshape(f[k:k+lookback],[1,lookback,1]))   
    myseq = np.append(myseq,mypred)

# %%
# Plot results
plt.plot(sig.resample(myseq,f.shape[0]),'b')
plt.plot(f,'r--')
plt.show()
