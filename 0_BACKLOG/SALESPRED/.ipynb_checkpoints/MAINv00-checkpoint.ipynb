# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import datetime,os,warnings,csv

import tensorflow as tf
import pandas as pd
import seaborn as sns

from keras.models import Model,Sequential
from keras.layers import Input,Dense,LSTM,advanced_activations,Dropout,BatchNormalization,concatenate,Embedding

from sklearn.model_selection import train_test_split
from sklearn import preprocessing as pp
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor

sns.set()
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Jan\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv('..\\..\\TF_data\\SALESPRED\\walmart\\train.csv',infer_datetime_format=True)
df['IsHoliday'] = df['IsHoliday'].apply(lambda x: int(x))
df['Date'] = pd.to_datetime(df['Date'],format='%Y-%m-%d')

# %%
lookback = 100 
forecast = 5

additional_information = []

timeseries = []
d_timeseries = []

labels = []
labels_d = []

storeIDrange = max(df['Store'].unique())
for storeID in df['Store'].unique():
    for deptID in df['Dept'].unique():
        t = df[(df['Store']==storeID)&(df['Dept']==deptID)].sort_values(by='Date')['Weekly_Sales'].values
        #dt = df[(df['Store']==storeID)&(df['Dept']==deptID)].sort_values(by='Date')['Weekly_Sales'].diff().values
        info = [storeID,deptID]
        
        print('Processing store %d/%d, department %d'%(storeID,storeIDrange,deptID))
        for k in range(lookback,t.shape[0]-forecast):
            additional_information.append(info)
            timeseries.append(t[k-lookback:k])
            #d_timeseries.append(dt[k-lookback:k])
            labels.append(t[k+forecast]-t[k])
            #labels_d.append(dt[k+forecast]-dt[k])
                    
additional_information = np.stack(additional_information,axis=0)
timeseries = np.expand_dims(np.stack(timeseries,axis=0),axis=2)
#d_timeseries = np.expand_dims(np.stack(d_timeseries,axis=0),axis=2)
labels = np.stack(labels,axis=0)
#labels_d = np.stack(labels_d,axis=0)

Xtrain,Xtest,Ztrain,Ztest,ytrain,ytest = train_test_split(timeseries,additional_information,labels,test_size=0.5,shuffle=True)

ytrain = np.expand_dims(ytrain,axis=1)
ytest = np.expand_dims(ytest,axis=1)

disc = pp.KBinsDiscretizer(n_bins=8)
ytrain_oh = disc.fit_transform(ytrain).todense()
ytest_oh = disc.transform(ytest).todense()
# Out:
# Processing store 1/45, department 1
# Processing store 1/45, department 2
# Processing store 1/45, department 3
# Processing store 1/45, department 4
# Processing store 1/45, department 5
# Processing store 1/45, department 6
# Processing store 1/45, department 7
# Processing store 1/45, department 8
# Processing store 1/45, department 9
# Processing store 1/45, department 10
# Processing store 1/45, department 11
# Processing store 1/45, department 12
# Processing store 1/45, department 13
# Processing store 1/45, department 14
# Processing store 1/45, department 16
# Processing store 1/45, department 17
# Processing store 1/45, department 18
# Processing store 1/45, department 19
# Processing store 1/45, department 20
# Processing store 1/45, department 21
# Processing store 1/45, department 22
# Processing store 1/45, department 23
# Processing store 1/45, department 24
# Processing store 1/45, department 25
# Processing store 1/45, department 26
# Processing store 1/45, department 27
# Processing store 1/45, department 28
# Processing store 1/45, department 29
# Processing store 1/45, department 30
# Processing store 1/45, department 31
# Processing store 1/45, department 32
# Processing store 1/45, department 33
# Processing store 1/45, department 34
# Processing store 1/45, department 35
# Processing store 1/45, department 36
# Processing store 1/45, department 37
# Processing store 1/45, department 38
# Processing store 1/45, department 40
# Processing store 1/45, department 41
# Processing store 1/45, department 42
# Processing store 1/45, department 44
# Processing store 1/45, department 45
# Processing store 1/45, department 46
# Processing store 1/45, department 47
# Processing store 1/45, department 48
# Processing store 1/45, department 49
# Processing store 1/45, department 51
# Processing store 1/45, department 52
# Processing store 1/45, department 54
# Processing store 1/45, department 55
# Processing store 1/45, department 56
# Processing store 1/45, department 58
# Processing store 1/45, department 59
# Processing store 1/45, department 60
# Processing store 1/45, department 67
# Processing store 1/45, department 71
# Processing store 1/45, department 72
# Processing store 1/45, department 74
# Processing store 1/45, department 77
# Processing store 1/45, department 78
# Processing store 1/45, department 79
# Processing store 1/45, department 80
# Processing store 1/45, department 81
# Processing store 1/45, department 82
# Processing store 1/45, department 83
# Processing store 1/45, department 85
# Processing store 1/45, department 87
# Processing store 1/45, department 90
# Processing store 1/45, department 91
# Processing store 1/45, department 92
# Processing store 1/45, department 93
# Processing store 1/45, department 94
# Processing store 1/45, department 95
# Processing store 1/45, department 96
# Processing store 1/45, department 97
# Processing store 1/45, department 98
# Processing store 1/45, department 99
# Processing store 1/45, department 39
# Processing store 1/45, department 50
# Processing store 1/45, department 43
# Processing store 1/45, department 65
# Processing store 2/45, department 1
# Processing store 2/45, department 2
# Processing store 2/45, department 3
# Processing store 2/45, department 4
# Processing store 2/45, department 5
# Processing store 2/45, department 6
# Processing store 2/45, department 7
# Processing store 2/45, department 8
# Processing store 2/45, department 9
# Processing store 2/45, department 10
# Processing store 2/45, department 11
# Processing store 2/45, department 12
# Processing store 2/45, department 13
# Processing store 2/45, department 14
# Processing store 2/45, department 16
# Processing store 2/45, department 17
# Processing store 2/45, department 18
# Processing store 2/45, department 19
# Processing store 2/45, department 20
# Processing store 2/45, department 21
# Processing store 2/45, department 22
# Processing store 2/45, department 23
# Processing store 2/45, department 24
# Processing store 2/45, department 25
# Processing store 2/45, department 26
# Processing store 2/45, department 27
# Processing store 2/45, department 28
# Processing store 2/45, department 29
# Processing store 2/45, department 30
# Processing store 2/45, department 31
# Processing store 2/45, department 32
# Processing store 2/45, department 33
# Processing store 2/45, department 34
# Processing store 2/45, department 35
# Processing store 2/45, department 36
# Processing store 2/45, department 37
# Processing store 2/45, department 38
# Processing store 2/45, department 40
# Processing store 2/45, department 41
# Processing store 2/45, department 42
# Processing store 2/45, department 44
# Processing store 2/45, department 45
# Processing store 2/45, department 46
# Processing store 2/45, department 47
# Processing store 2/45, department 48
# Processing store 2/45, department 49
# Processing store 2/45, department 51
# Processing store 2/45, department 52
# Processing store 2/45, department 54
# Processing store 2/45, department 55
# Processing store 2/45, department 56
# Processing store 2/45, department 58
# Processing store 2/45, department 59
# Processing store 2/45, department 60
# Processing store 2/45, department 67
# Processing store 2/45, department 71
# Processing store 2/45, department 72
# Processing store 2/45, department 74
# Processing store 2/45, department 77
# Processing store 2/45, department 78
# Processing store 2/45, department 79
# Processing store 2/45, department 80
# Processing store 2/45, department 81
# Processing store 2/45, department 82
# Processing store 2/45, department 83
# Processing store 2/45, department 85
# Processing store 2/45, department 87
# Processing store 2/45, department 90
# Processing store 2/45, department 91
# Processing store 2/45, department 92
# Processing store 2/45, department 93
# Processing store 2/45, department 94
# Processing store 2/45, department 95
# Processing store 2/45, department 96
# Processing store 2/45, department 97
# Processing store 2/45, department 98
# Processing store 2/45, department 99
# Processing store 2/45, department 39
# Processing store 2/45, department 50
# Processing store 2/45, department 43
# Processing store 2/45, department 65
# Processing store 3/45, department 1
# Processing store 3/45, department 2
# Processing store 3/45, department 3
# Processing store 3/45, department 4
# Processing store 3/45, department 5
# Processing store 3/45, department 6
# Processing store 3/45, department 7
# Processing store 3/45, department 8
# Processing store 3/45, department 9
# Processing store 3/45, department 10
# Processing store 3/45, department 11
# Processing store 3/45, department 12
# Processing store 3/45, department 13
# Processing store 3/45, department 14
# Processing store 3/45, department 16
# Processing store 3/45, department 17
# Processing store 3/45, department 18
# Processing store 3/45, department 19
# Processing store 3/45, department 20
# Processing store 3/45, department 21
# Processing store 3/45, department 22
# Processing store 3/45, department 23
# Processing store 3/45, department 24
# Processing store 3/45, department 25
# Processing store 3/45, department 26
# Processing store 3/45, department 27
# Processing store 3/45, department 28
# Processing store 3/45, department 29
# Processing store 3/45, department 30
# Processing store 3/45, department 31
# Processing store 3/45, department 32
# Processing store 3/45, department 33
# Processing store 3/45, department 34
# Processing store 3/45, department 35
# Processing store 3/45, department 36
# Processing store 3/45, department 37
# Processing store 3/45, department 38
# Processing store 3/45, department 40
# Processing store 3/45, department 41
# Processing store 3/45, department 42
# Processing store 3/45, department 44
# Processing store 3/45, department 45
# Processing store 3/45, department 46
# Processing store 3/45, department 47
# Processing store 3/45, department 48
# Processing store 3/45, department 49
# Processing store 3/45, department 51
# Processing store 3/45, department 52
# Processing store 3/45, department 54
# Processing store 3/45, department 55
# Processing store 3/45, department 56
# Processing store 3/45, department 58
# Processing store 3/45, department 59
# Processing store 3/45, department 60
# Processing store 3/45, department 67
# Processing store 3/45, department 71
# Processing store 3/45, department 72
# Processing store 3/45, department 74
# Processing store 3/45, department 77
# Processing store 3/45, department 78
# Processing store 3/45, department 79
# Processing store 3/45, department 80
# Processing store 3/45, department 81
# Processing store 3/45, department 82
# Processing store 3/45, department 83
# Processing store 3/45, department 85
# Processing store 3/45, department 87
# Processing store 3/45, department 90
# Processing store 3/45, department 91
# Processing store 3/45, department 92
# Processing store 3/45, department 93
# Processing store 3/45, department 94
# Processing store 3/45, department 95
# Processing store 3/45, department 96
# Processing store 3/45, department 97
# Processing store 3/45, department 98
# Processing store 3/45, department 99
# Processing store 3/45, department 39
# Processing store 3/45, department 50
# Processing store 3/45, department 43
# Processing store 3/45, department 65
# Processing store 4/45, department 1
# Processing store 4/45, department 2
# Processing store 4/45, department 3
# Processing store 4/45, department 4
# Processing store 4/45, department 5
# Processing store 4/45, department 6
# Processing store 4/45, department 7
# Processing store 4/45, department 8
# Processing store 4/45, department 9
# Processing store 4/45, department 10
# Processing store 4/45, department 11
# Processing store 4/45, department 12
# Processing store 4/45, department 13
# Processing store 4/45, department 14
# Processing store 4/45, department 16
# Processing store 4/45, department 17
# Processing store 4/45, department 18
# Processing store 4/45, department 19
# Processing store 4/45, department 20
# Processing store 4/45, department 21
# Processing store 4/45, department 22
# Processing store 4/45, department 23
# Processing store 4/45, department 24
# Processing store 4/45, department 25
# Processing store 4/45, department 26
# Processing store 4/45, department 27
# Processing store 4/45, department 28
# Processing store 4/45, department 29
# Processing store 4/45, department 30
# Processing store 4/45, department 31
# Processing store 4/45, department 32
# Processing store 4/45, department 33
# Processing store 4/45, department 34
# Processing store 4/45, department 35
# Processing store 4/45, department 36
# Processing store 4/45, department 37
# Processing store 4/45, department 38
# Processing store 4/45, department 40
# Processing store 4/45, department 41
# Processing store 4/45, department 42
# Processing store 4/45, department 44
# Processing store 4/45, department 45
# Processing store 4/45, department 46
# Processing store 4/45, department 47
# Processing store 4/45, department 48
# Processing store 4/45, department 49
# Processing store 4/45, department 51
# Processing store 4/45, department 52
# Processing store 4/45, department 54
# Processing store 4/45, department 55
# Processing store 4/45, department 56
# Processing store 4/45, department 58
# Processing store 4/45, department 59
# Processing store 4/45, department 60
# Processing store 4/45, department 67
# Processing store 4/45, department 71
# Processing store 4/45, department 72
# Processing store 4/45, department 74
# Processing store 4/45, department 77
# Processing store 4/45, department 78
# Processing store 4/45, department 79
# Processing store 4/45, department 80
# Processing store 4/45, department 81
# Processing store 4/45, department 82
# Processing store 4/45, department 83
# Processing store 4/45, department 85
# Processing store 4/45, department 87
# Processing store 4/45, department 90
# Processing store 4/45, department 91
# Processing store 4/45, department 92
# Processing store 4/45, department 93
# Processing store 4/45, department 94
# Processing store 4/45, department 95
# Processing store 4/45, department 96
# Processing store 4/45, department 97
# Processing store 4/45, department 98
# Processing store 4/45, department 99
# Processing store 4/45, department 39
# Processing store 4/45, department 50
# Processing store 4/45, department 43
# Processing store 4/45, department 65
# Processing store 5/45, department 1
# Processing store 5/45, department 2
# Processing store 5/45, department 3
# Processing store 5/45, department 4
# Processing store 5/45, department 5
# Processing store 5/45, department 6
# Processing store 5/45, department 7
# Processing store 5/45, department 8
# Processing store 5/45, department 9
# Processing store 5/45, department 10
# Processing store 5/45, department 11
# Processing store 5/45, department 12
# Processing store 5/45, department 13
# Processing store 5/45, department 14
# Processing store 5/45, department 16
# Processing store 5/45, department 17
# Processing store 5/45, department 18
# Processing store 5/45, department 19
# Processing store 5/45, department 20
# Processing store 5/45, department 21
# Processing store 5/45, department 22
# Processing store 5/45, department 23
# Processing store 5/45, department 24
# Processing store 5/45, department 25
# Processing store 5/45, department 26
# Processing store 5/45, department 27
# Processing store 5/45, department 28
# Processing store 5/45, department 29
# Processing store 5/45, department 30
# Processing store 5/45, department 31
# Processing store 5/45, department 32
# Processing store 5/45, department 33
# Processing store 5/45, department 34
# Processing store 5/45, department 35
# Processing store 5/45, department 36
# Processing store 5/45, department 37
# Processing store 5/45, department 38
# Processing store 5/45, department 40
# Processing store 5/45, department 41
# Processing store 5/45, department 42
# Processing store 5/45, department 44
# Processing store 5/45, department 45
# Processing store 5/45, department 46
# Processing store 5/45, department 47
# Processing store 5/45, department 48
# Processing store 5/45, department 49
# Processing store 5/45, department 51
# Processing store 5/45, department 52
# Processing store 5/45, department 54
# Processing store 5/45, department 55
# Processing store 5/45, department 56
# Processing store 5/45, department 58
# Processing store 5/45, department 59
# Processing store 5/45, department 60
# Processing store 5/45, department 67
# Processing store 5/45, department 71
# Processing store 5/45, department 72
# Processing store 5/45, department 74
# Processing store 5/45, department 77
# Processing store 5/45, department 78
# Processing store 5/45, department 79
# Processing store 5/45, department 80
# Processing store 5/45, department 81
# Processing store 5/45, department 82
# Processing store 5/45, department 83
# Processing store 5/45, department 85
# Processing store 5/45, department 87
# Processing store 5/45, department 90
# Processing store 5/45, department 91
# Processing store 5/45, department 92
# Processing store 5/45, department 93
# Processing store 5/45, department 94
# Processing store 5/45, department 95
# Processing store 5/45, department 96
# Processing store 5/45, department 97
# Processing store 5/45, department 98
# Processing store 5/45, department 99
# Processing store 5/45, department 39
# Processing store 5/45, department 50
# Processing store 5/45, department 43
# Processing store 5/45, department 65
# Processing store 6/45, department 1
# Processing store 6/45, department 2
# Processing store 6/45, department 3
# Processing store 6/45, department 4
# Processing store 6/45, department 5
# Processing store 6/45, department 6
# Processing store 6/45, department 7
# Processing store 6/45, department 8
# Processing store 6/45, department 9
# Processing store 6/45, department 10
# Processing store 6/45, department 11
# Processing store 6/45, department 12
# Processing store 6/45, department 13
# Processing store 6/45, department 14
# Processing store 6/45, department 16
# Processing store 6/45, department 17
# Processing store 6/45, department 18
# Processing store 6/45, department 19
# Processing store 6/45, department 20
# Processing store 6/45, department 21
# Processing store 6/45, department 22
# Processing store 6/45, department 23
# Processing store 6/45, department 24
# Processing store 6/45, department 25
# Processing store 6/45, department 26
# Processing store 6/45, department 27
# Processing store 6/45, department 28
# Processing store 6/45, department 29
# Processing store 6/45, department 30
# Processing store 6/45, department 31
# Processing store 6/45, department 32
# Processing store 6/45, department 33
# Processing store 6/45, department 34
# Processing store 6/45, department 35
# Processing store 6/45, department 36
# Processing store 6/45, department 37
# Processing store 6/45, department 38
# Processing store 6/45, department 40
# Processing store 6/45, department 41
# Processing store 6/45, department 42
# Processing store 6/45, department 44
# Processing store 6/45, department 45
# Processing store 6/45, department 46
# Processing store 6/45, department 47
# Processing store 6/45, department 48
# Processing store 6/45, department 49
# Processing store 6/45, department 51
# Processing store 6/45, department 52
# Processing store 6/45, department 54
# Processing store 6/45, department 55
# Processing store 6/45, department 56
# Processing store 6/45, department 58
# Processing store 6/45, department 59
# Processing store 6/45, department 60
# Processing store 6/45, department 67
# Processing store 6/45, department 71
# Processing store 6/45, department 72
# Processing store 6/45, department 74
# Processing store 6/45, department 77
# Processing store 6/45, department 78
# Processing store 6/45, department 79
# Processing store 6/45, department 80
# Processing store 6/45, department 81
# Processing store 6/45, department 82
# Processing store 6/45, department 83
# Processing store 6/45, department 85
# Processing store 6/45, department 87
# Processing store 6/45, department 90
# Processing store 6/45, department 91
# Processing store 6/45, department 92
# Processing store 6/45, department 93
# Processing store 6/45, department 94
# Processing store 6/45, department 95
# Processing store 6/45, department 96
# Processing store 6/45, department 97
# Processing store 6/45, department 98
# Processing store 6/45, department 99
# Processing store 6/45, department 39
# Processing store 6/45, department 50
# Processing store 6/45, department 43
# Processing store 6/45, department 65
# Processing store 7/45, department 1
# Processing store 7/45, department 2
# Processing store 7/45, department 3
# Processing store 7/45, department 4
# Processing store 7/45, department 5
# Processing store 7/45, department 6
# Processing store 7/45, department 7
# Processing store 7/45, department 8
# Processing store 7/45, department 9
# Processing store 7/45, department 10
# Processing store 7/45, department 11
# Processing store 7/45, department 12
# Processing store 7/45, department 13
# Processing store 7/45, department 14
# Processing store 7/45, department 16
# Processing store 7/45, department 17
# Processing store 7/45, department 18
# Processing store 7/45, department 19
# Processing store 7/45, department 20
# Processing store 7/45, department 21
# Processing store 7/45, department 22
# Processing store 7/45, department 23
# Processing store 7/45, department 24
# Processing store 7/45, department 25
# Processing store 7/45, department 26
# Processing store 7/45, department 27
# Processing store 7/45, department 28
# Processing store 7/45, department 29
# Processing store 7/45, department 30
# Processing store 7/45, department 31
# Processing store 7/45, department 32
# Processing store 7/45, department 33
# Processing store 7/45, department 34
# Processing store 7/45, department 35
# Processing store 7/45, department 36
# Processing store 7/45, department 37
# Processing store 7/45, department 38
# Processing store 7/45, department 40
# Processing store 7/45, department 41
# Processing store 7/45, department 42
# Processing store 7/45, department 44
# Processing store 7/45, department 45
# Processing store 7/45, department 46
# Processing store 7/45, department 47
# Processing store 7/45, department 48
# Processing store 7/45, department 49
# Processing store 7/45, department 51
# Processing store 7/45, department 52
# Processing store 7/45, department 54
# Processing store 7/45, department 55
# Processing store 7/45, department 56
# Processing store 7/45, department 58
# Processing store 7/45, department 59
# Processing store 7/45, department 60
# Processing store 7/45, department 67
# Processing store 7/45, department 71
# Processing store 7/45, department 72
# Processing store 7/45, department 74
# Processing store 7/45, department 77
# Processing store 7/45, department 78
# Processing store 7/45, department 79
# Processing store 7/45, department 80
# Processing store 7/45, department 81
# Processing store 7/45, department 82
# Processing store 7/45, department 83
# Processing store 7/45, department 85
# Processing store 7/45, department 87
# Processing store 7/45, department 90
# Processing store 7/45, department 91
# Processing store 7/45, department 92
# Processing store 7/45, department 93
# Processing store 7/45, department 94
# Processing store 7/45, department 95
# Processing store 7/45, department 96
# Processing store 7/45, department 97
# Processing store 7/45, department 98
# Processing store 7/45, department 99
# Processing store 7/45, department 39
# Processing store 7/45, department 50
# Processing store 7/45, department 43
# Processing store 7/45, department 65
# Processing store 8/45, department 1
# Processing store 8/45, department 2
# Processing store 8/45, department 3
# Processing store 8/45, department 4
# Processing store 8/45, department 5
# Processing store 8/45, department 6
# Processing store 8/45, department 7
# Processing store 8/45, department 8
# Processing store 8/45, department 9
# Processing store 8/45, department 10
# Processing store 8/45, department 11
# Processing store 8/45, department 12
# Processing store 8/45, department 13
# Processing store 8/45, department 14
# Processing store 8/45, department 16
# Processing store 8/45, department 17
# Processing store 8/45, department 18
# Processing store 8/45, department 19
# Processing store 8/45, department 20
# Processing store 8/45, department 21
# Processing store 8/45, department 22
# Processing store 8/45, department 23
# Processing store 8/45, department 24
# Processing store 8/45, department 25
# Processing store 8/45, department 26
# Processing store 8/45, department 27
# Processing store 8/45, department 28
# Processing store 8/45, department 29
# Processing store 8/45, department 30
# Processing store 8/45, department 31
# Processing store 8/45, department 32
# Processing store 8/45, department 33
# Processing store 8/45, department 34
# Processing store 8/45, department 35
# Processing store 8/45, department 36
# Processing store 8/45, department 37
# Processing store 8/45, department 38
# Processing store 8/45, department 40
# Processing store 8/45, department 41
# Processing store 8/45, department 42
# Processing store 8/45, department 44
# Processing store 8/45, department 45
# Processing store 8/45, department 46
# Processing store 8/45, department 47
# Processing store 8/45, department 48
# Processing store 8/45, department 49
# Processing store 8/45, department 51
# Processing store 8/45, department 52
# Processing store 8/45, department 54
# Processing store 8/45, department 55
# Processing store 8/45, department 56
# Processing store 8/45, department 58
# Processing store 8/45, department 59
# Processing store 8/45, department 60
# Processing store 8/45, department 67
# Processing store 8/45, department 71
# Processing store 8/45, department 72
# Processing store 8/45, department 74
# Processing store 8/45, department 77
# Processing store 8/45, department 78
# Processing store 8/45, department 79
# Processing store 8/45, department 80
# Processing store 8/45, department 81
# Processing store 8/45, department 82
# Processing store 8/45, department 83
# Processing store 8/45, department 85
# Processing store 8/45, department 87
# Processing store 8/45, department 90
# Processing store 8/45, department 91
# Processing store 8/45, department 92
# Processing store 8/45, department 93
# Processing store 8/45, department 94
# Processing store 8/45, department 95
# Processing store 8/45, department 96
# Processing store 8/45, department 97
# Processing store 8/45, department 98
# Processing store 8/45, department 99
# Processing store 8/45, department 39
# Processing store 8/45, department 50
# Processing store 8/45, department 43
# Processing store 8/45, department 65
# Processing store 9/45, department 1
# Processing store 9/45, department 2
# Processing store 9/45, department 3
# Processing store 9/45, department 4
# Processing store 9/45, department 5
# Processing store 9/45, department 6
# Processing store 9/45, department 7
# Processing store 9/45, department 8
# Processing store 9/45, department 9
# Processing store 9/45, department 10
# Processing store 9/45, department 11
# Processing store 9/45, department 12
# Processing store 9/45, department 13
# Processing store 9/45, department 14
# Processing store 9/45, department 16
# Processing store 9/45, department 17
# Processing store 9/45, department 18
# Processing store 9/45, department 19
# Processing store 9/45, department 20
# Processing store 9/45, department 21
# Processing store 9/45, department 22
# Processing store 9/45, department 23
# Processing store 9/45, department 24
# Processing store 9/45, department 25
# Processing store 9/45, department 26
# Processing store 9/45, department 27
# Processing store 9/45, department 28
# Processing store 9/45, department 29
# Processing store 9/45, department 30
# Processing store 9/45, department 31
# Processing store 9/45, department 32
# Processing store 9/45, department 33
# Processing store 9/45, department 34
# Processing store 9/45, department 35
# Processing store 9/45, department 36
# Processing store 9/45, department 37
# Processing store 9/45, department 38
# Processing store 9/45, department 40
# Processing store 9/45, department 41
# Processing store 9/45, department 42
# Processing store 9/45, department 44
# Processing store 9/45, department 45
# Processing store 9/45, department 46
# Processing store 9/45, department 47
# Processing store 9/45, department 48
# Processing store 9/45, department 49
# Processing store 9/45, department 51
# Processing store 9/45, department 52
# Processing store 9/45, department 54
# Processing store 9/45, department 55
# Processing store 9/45, department 56
# Processing store 9/45, department 58
# Processing store 9/45, department 59
# Processing store 9/45, department 60
# Processing store 9/45, department 67
# Processing store 9/45, department 71
# Processing store 9/45, department 72
# Processing store 9/45, department 74
# Processing store 9/45, department 77
# Processing store 9/45, department 78
# Processing store 9/45, department 79
# Processing store 9/45, department 80
# Processing store 9/45, department 81
# Processing store 9/45, department 82
# Processing store 9/45, department 83
# Processing store 9/45, department 85
# Processing store 9/45, department 87
# Processing store 9/45, department 90
# Processing store 9/45, department 91
# Processing store 9/45, department 92
# Processing store 9/45, department 93
# Processing store 9/45, department 94
# Processing store 9/45, department 95
# Processing store 9/45, department 96
# Processing store 9/45, department 97
# Processing store 9/45, department 98
# Processing store 9/45, department 99
# Processing store 9/45, department 39
# Processing store 9/45, department 50
# Processing store 9/45, department 43
# Processing store 9/45, department 65
# Processing store 10/45, department 1
# Processing store 10/45, department 2
# Processing store 10/45, department 3
# Processing store 10/45, department 4
# Processing store 10/45, department 5
# Processing store 10/45, department 6
# Processing store 10/45, department 7
# Processing store 10/45, department 8
# Processing store 10/45, department 9
# Processing store 10/45, department 10
# Processing store 10/45, department 11
# Processing store 10/45, department 12
# Processing store 10/45, department 13
# Processing store 10/45, department 14
# Processing store 10/45, department 16
# Processing store 10/45, department 17
# Processing store 10/45, department 18
# Processing store 10/45, department 19
# Processing store 10/45, department 20
# Processing store 10/45, department 21
# Processing store 10/45, department 22
# Processing store 10/45, department 23
# Processing store 10/45, department 24
# Processing store 10/45, department 25
# Processing store 10/45, department 26
# Processing store 10/45, department 27
# Processing store 10/45, department 28
# Processing store 10/45, department 29
# Processing store 10/45, department 30
# Processing store 10/45, department 31
# Processing store 10/45, department 32
# Processing store 10/45, department 33
# Processing store 10/45, department 34
# Processing store 10/45, department 35
# Processing store 10/45, department 36
# Processing store 10/45, department 37
# Processing store 10/45, department 38
# Processing store 10/45, department 40
# Processing store 10/45, department 41
# Processing store 10/45, department 42
# Processing store 10/45, department 44
# Processing store 10/45, department 45
# Processing store 10/45, department 46
# Processing store 10/45, department 47
# Processing store 10/45, department 48
# Processing store 10/45, department 49
# Processing store 10/45, department 51
# Processing store 10/45, department 52
# Processing store 10/45, department 54
# Processing store 10/45, department 55
# Processing store 10/45, department 56
# Processing store 10/45, department 58
# Processing store 10/45, department 59
# Processing store 10/45, department 60
# Processing store 10/45, department 67
# Processing store 10/45, department 71
# Processing store 10/45, department 72
# Processing store 10/45, department 74
# Processing store 10/45, department 77
# Processing store 10/45, department 78
# Processing store 10/45, department 79
# Processing store 10/45, department 80
# Processing store 10/45, department 81
# Processing store 10/45, department 82
# Processing store 10/45, department 83
# Processing store 10/45, department 85
# Processing store 10/45, department 87
# Processing store 10/45, department 90
# Processing store 10/45, department 91
# Processing store 10/45, department 92
# Processing store 10/45, department 93
# Processing store 10/45, department 94
# Processing store 10/45, department 95
# Processing store 10/45, department 96
# Processing store 10/45, department 97
# Processing store 10/45, department 98
# Processing store 10/45, department 99
# Processing store 10/45, department 39
# Processing store 10/45, department 50
# Processing store 10/45, department 43
# Processing store 10/45, department 65
# Processing store 11/45, department 1
# Processing store 11/45, department 2
# Processing store 11/45, department 3
# Processing store 11/45, department 4
# Processing store 11/45, department 5
# Processing store 11/45, department 6
# Processing store 11/45, department 7
# Processing store 11/45, department 8
# Processing store 11/45, department 9
# Processing store 11/45, department 10
# Processing store 11/45, department 11
# Processing store 11/45, department 12
# Processing store 11/45, department 13
# Processing store 11/45, department 14
# Processing store 11/45, department 16
# Processing store 11/45, department 17
# Processing store 11/45, department 18
# Processing store 11/45, department 19
# Processing store 11/45, department 20
# Processing store 11/45, department 21
# Processing store 11/45, department 22
# Processing store 11/45, department 23
# Processing store 11/45, department 24
# Processing store 11/45, department 25
# Processing store 11/45, department 26
# Processing store 11/45, department 27
# Processing store 11/45, department 28
# Processing store 11/45, department 29
# Processing store 11/45, department 30
# Processing store 11/45, department 31
# Processing store 11/45, department 32
# Processing store 11/45, department 33
# Processing store 11/45, department 34
# Processing store 11/45, department 35
# Processing store 11/45, department 36
# Processing store 11/45, department 37
# Processing store 11/45, department 38
# Processing store 11/45, department 40
# Processing store 11/45, department 41
# Processing store 11/45, department 42
# Processing store 11/45, department 44
# Processing store 11/45, department 45
# Processing store 11/45, department 46
# Processing store 11/45, department 47
# Processing store 11/45, department 48
# Processing store 11/45, department 49
# Processing store 11/45, department 51
# Processing store 11/45, department 52
# Processing store 11/45, department 54
# Processing store 11/45, department 55
# Processing store 11/45, department 56
# Processing store 11/45, department 58
# Processing store 11/45, department 59
# Processing store 11/45, department 60
# Processing store 11/45, department 67
# Processing store 11/45, department 71
# Processing store 11/45, department 72
# Processing store 11/45, department 74
# Processing store 11/45, department 77
# Processing store 11/45, department 78
# Processing store 11/45, department 79
# Processing store 11/45, department 80
# Processing store 11/45, department 81
# Processing store 11/45, department 82
# Processing store 11/45, department 83
# Processing store 11/45, department 85
# Processing store 11/45, department 87
# Processing store 11/45, department 90
# Processing store 11/45, department 91
# Processing store 11/45, department 92
# Processing store 11/45, department 93
# Processing store 11/45, department 94
# Processing store 11/45, department 95
# Processing store 11/45, department 96
# Processing store 11/45, department 97
# Processing store 11/45, department 98
# Processing store 11/45, department 99
# Processing store 11/45, department 39
# Processing store 11/45, department 50
# Processing store 11/45, department 43
# Processing store 11/45, department 65
# Processing store 12/45, department 1
# Processing store 12/45, department 2
# Processing store 12/45, department 3
# Processing store 12/45, department 4
# Processing store 12/45, department 5
# Processing store 12/45, department 6
# Processing store 12/45, department 7
# Processing store 12/45, department 8
# Processing store 12/45, department 9
# Processing store 12/45, department 10
# Processing store 12/45, department 11
# Processing store 12/45, department 12
# Processing store 12/45, department 13
# Processing store 12/45, department 14
# Processing store 12/45, department 16
# Processing store 12/45, department 17
# Processing store 12/45, department 18
# Processing store 12/45, department 19
# Processing store 12/45, department 20
# Processing store 12/45, department 21
# Processing store 12/45, department 22
# Processing store 12/45, department 23
# Processing store 12/45, department 24
# Processing store 12/45, department 25
# Processing store 12/45, department 26
# Processing store 12/45, department 27
# Processing store 12/45, department 28
# Processing store 12/45, department 29
# Processing store 12/45, department 30
# Processing store 12/45, department 31
# Processing store 12/45, department 32
# Processing store 12/45, department 33
# Processing store 12/45, department 34
# Processing store 12/45, department 35
# Processing store 12/45, department 36
# Processing store 12/45, department 37
# Processing store 12/45, department 38
# Processing store 12/45, department 40
# Processing store 12/45, department 41
# Processing store 12/45, department 42
# Processing store 12/45, department 44
# Processing store 12/45, department 45
# Processing store 12/45, department 46
# Processing store 12/45, department 47
# Processing store 12/45, department 48
# Processing store 12/45, department 49
# Processing store 12/45, department 51
# Processing store 12/45, department 52
# Processing store 12/45, department 54
# Processing store 12/45, department 55
# Processing store 12/45, department 56
# Processing store 12/45, department 58
# Processing store 12/45, department 59
# Processing store 12/45, department 60
# Processing store 12/45, department 67
# Processing store 12/45, department 71
# Processing store 12/45, department 72
# Processing store 12/45, department 74
# Processing store 12/45, department 77
# Processing store 12/45, department 78
# Processing store 12/45, department 79
# Processing store 12/45, department 80
# Processing store 12/45, department 81
# Processing store 12/45, department 82
# Processing store 12/45, department 83
# Processing store 12/45, department 85
# Processing store 12/45, department 87
# Processing store 12/45, department 90
# Processing store 12/45, department 91
# Processing store 12/45, department 92
# Processing store 12/45, department 93
# Processing store 12/45, department 94
# Processing store 12/45, department 95
# Processing store 12/45, department 96
# Processing store 12/45, department 97
# Processing store 12/45, department 98
# Processing store 12/45, department 99
# Processing store 12/45, department 39
# Processing store 12/45, department 50
# Processing store 12/45, department 43
# Processing store 12/45, department 65
# Processing store 13/45, department 1
# Processing store 13/45, department 2
# Processing store 13/45, department 3
# Processing store 13/45, department 4
# Processing store 13/45, department 5
# Processing store 13/45, department 6
# Processing store 13/45, department 7
# Processing store 13/45, department 8
# Processing store 13/45, department 9
# Processing store 13/45, department 10
# Processing store 13/45, department 11
# Processing store 13/45, department 12
# Processing store 13/45, department 13
# Processing store 13/45, department 14
# Processing store 13/45, department 16
# Processing store 13/45, department 17
# Processing store 13/45, department 18
# Processing store 13/45, department 19
# Processing store 13/45, department 20
# Processing store 13/45, department 21
# Processing store 13/45, department 22
# Processing store 13/45, department 23
# Processing store 13/45, department 24
# Processing store 13/45, department 25
# Processing store 13/45, department 26
# Processing store 13/45, department 27
# Processing store 13/45, department 28
# Processing store 13/45, department 29
# Processing store 13/45, department 30
# Processing store 13/45, department 31
# Processing store 13/45, department 32
# Processing store 13/45, department 33
# Processing store 13/45, department 34
# Processing store 13/45, department 35
# Processing store 13/45, department 36
# Processing store 13/45, department 37
# Processing store 13/45, department 38
# Processing store 13/45, department 40
# Processing store 13/45, department 41
# Processing store 13/45, department 42
# Processing store 13/45, department 44
# Processing store 13/45, department 45
# Processing store 13/45, department 46
# Processing store 13/45, department 47
# Processing store 13/45, department 48
# Processing store 13/45, department 49
# Processing store 13/45, department 51
# Processing store 13/45, department 52
# Processing store 13/45, department 54
# Processing store 13/45, department 55
# Processing store 13/45, department 56
# Processing store 13/45, department 58
# Processing store 13/45, department 59
# Processing store 13/45, department 60
# Processing store 13/45, department 67
# Processing store 13/45, department 71
# Processing store 13/45, department 72
# Processing store 13/45, department 74
# Processing store 13/45, department 77
# Processing store 13/45, department 78
# Processing store 13/45, department 79
# Processing store 13/45, department 80
# Processing store 13/45, department 81
# Processing store 13/45, department 82
# Processing store 13/45, department 83
# Processing store 13/45, department 85
# Processing store 13/45, department 87
# Processing store 13/45, department 90
# Processing store 13/45, department 91
# Processing store 13/45, department 92
# Processing store 13/45, department 93
# Processing store 13/45, department 94
# Processing store 13/45, department 95
# Processing store 13/45, department 96
# Processing store 13/45, department 97
# Processing store 13/45, department 98
# Processing store 13/45, department 99
# Processing store 13/45, department 39
# Processing store 13/45, department 50
# Processing store 13/45, department 43
# Processing store 13/45, department 65
# Processing store 14/45, department 1
# Processing store 14/45, department 2
# Processing store 14/45, department 3
# Processing store 14/45, department 4
# Processing store 14/45, department 5
# Processing store 14/45, department 6
# Processing store 14/45, department 7
# Processing store 14/45, department 8
# Processing store 14/45, department 9
# Processing store 14/45, department 10
# Processing store 14/45, department 11
# Processing store 14/45, department 12
# Processing store 14/45, department 13
# Processing store 14/45, department 14
# Processing store 14/45, department 16
# Processing store 14/45, department 17
# Processing store 14/45, department 18
# Processing store 14/45, department 19
# Processing store 14/45, department 20
# Processing store 14/45, department 21
# Processing store 14/45, department 22
# Processing store 14/45, department 23
# Processing store 14/45, department 24
# Processing store 14/45, department 25
# Processing store 14/45, department 26
# Processing store 14/45, department 27
# Processing store 14/45, department 28
# Processing store 14/45, department 29
# Processing store 14/45, department 30
# Processing store 14/45, department 31
# Processing store 14/45, department 32
# Processing store 14/45, department 33
# Processing store 14/45, department 34
# Processing store 14/45, department 35
# Processing store 14/45, department 36
# Processing store 14/45, department 37
# Processing store 14/45, department 38
# Processing store 14/45, department 40
# Processing store 14/45, department 41
# Processing store 14/45, department 42
# Processing store 14/45, department 44
# Processing store 14/45, department 45
# Processing store 14/45, department 46
# Processing store 14/45, department 47
# Processing store 14/45, department 48
# Processing store 14/45, department 49
# Processing store 14/45, department 51
# Processing store 14/45, department 52
# Processing store 14/45, department 54
# Processing store 14/45, department 55
# Processing store 14/45, department 56
# Processing store 14/45, department 58
# Processing store 14/45, department 59
# Processing store 14/45, department 60
# Processing store 14/45, department 67
# Processing store 14/45, department 71
# Processing store 14/45, department 72
# Processing store 14/45, department 74
# Processing store 14/45, department 77
# Processing store 14/45, department 78
# Processing store 14/45, department 79
# Processing store 14/45, department 80
# Processing store 14/45, department 81
# Processing store 14/45, department 82
# Processing store 14/45, department 83
# Processing store 14/45, department 85
# Processing store 14/45, department 87
# Processing store 14/45, department 90
# Processing store 14/45, department 91
# Processing store 14/45, department 92
# Processing store 14/45, department 93
# Processing store 14/45, department 94
# Processing store 14/45, department 95
# Processing store 14/45, department 96
# Processing store 14/45, department 97
# Processing store 14/45, department 98
# Processing store 14/45, department 99
# Processing store 14/45, department 39
# Processing store 14/45, department 50
# Processing store 14/45, department 43
# Processing store 14/45, department 65
# Processing store 15/45, department 1
# Processing store 15/45, department 2
# Processing store 15/45, department 3
# Processing store 15/45, department 4
# Processing store 15/45, department 5
# Processing store 15/45, department 6
# Processing store 15/45, department 7
# Processing store 15/45, department 8
# Processing store 15/45, department 9
# Processing store 15/45, department 10
# Processing store 15/45, department 11
# Processing store 15/45, department 12
# Processing store 15/45, department 13
# Processing store 15/45, department 14
# Processing store 15/45, department 16
# Processing store 15/45, department 17
# Processing store 15/45, department 18
# Processing store 15/45, department 19
# Processing store 15/45, department 20
# Processing store 15/45, department 21
# Processing store 15/45, department 22
# Processing store 15/45, department 23
# Processing store 15/45, department 24
# Processing store 15/45, department 25
# Processing store 15/45, department 26
# Processing store 15/45, department 27
# Processing store 15/45, department 28
# Processing store 15/45, department 29
# Processing store 15/45, department 30
# Processing store 15/45, department 31
# Processing store 15/45, department 32
# Processing store 15/45, department 33
# Processing store 15/45, department 34
# Processing store 15/45, department 35
# Processing store 15/45, department 36
# Processing store 15/45, department 37
# Processing store 15/45, department 38
# Processing store 15/45, department 40
# Processing store 15/45, department 41
# Processing store 15/45, department 42
# Processing store 15/45, department 44
# Processing store 15/45, department 45
# Processing store 15/45, department 46
# Processing store 15/45, department 47
# Processing store 15/45, department 48
# Processing store 15/45, department 49
# Processing store 15/45, department 51
# Processing store 15/45, department 52
# Processing store 15/45, department 54
# Processing store 15/45, department 55
# Processing store 15/45, department 56
# Processing store 15/45, department 58
# Processing store 15/45, department 59
# Processing store 15/45, department 60
# Processing store 15/45, department 67
# Processing store 15/45, department 71
# Processing store 15/45, department 72
# Processing store 15/45, department 74
# Processing store 15/45, department 77
# Processing store 15/45, department 78
# Processing store 15/45, department 79
# Processing store 15/45, department 80
# Processing store 15/45, department 81
# Processing store 15/45, department 82
# Processing store 15/45, department 83
# Processing store 15/45, department 85
# Processing store 15/45, department 87
# Processing store 15/45, department 90
# Processing store 15/45, department 91
# Processing store 15/45, department 92
# Processing store 15/45, department 93
# Processing store 15/45, department 94
# Processing store 15/45, department 95
# Processing store 15/45, department 96
# Processing store 15/45, department 97
# Processing store 15/45, department 98
# Processing store 15/45, department 99
# Processing store 15/45, department 39
# Processing store 15/45, department 50
# Processing store 15/45, department 43
# Processing store 15/45, department 65
# Processing store 16/45, department 1
# Processing store 16/45, department 2
# Processing store 16/45, department 3
# Processing store 16/45, department 4
# Processing store 16/45, department 5
# Processing store 16/45, department 6
# Processing store 16/45, department 7
# Processing store 16/45, department 8
# Processing store 16/45, department 9
# Processing store 16/45, department 10
# Processing store 16/45, department 11
# Processing store 16/45, department 12
# Processing store 16/45, department 13
# Processing store 16/45, department 14
# Processing store 16/45, department 16
# Processing store 16/45, department 17
# Processing store 16/45, department 18
# Processing store 16/45, department 19
# Processing store 16/45, department 20
# Processing store 16/45, department 21
# Processing store 16/45, department 22
# Processing store 16/45, department 23
# Processing store 16/45, department 24
# Processing store 16/45, department 25
# Processing store 16/45, department 26
# Processing store 16/45, department 27
# Processing store 16/45, department 28
# Processing store 16/45, department 29
# Processing store 16/45, department 30
# Processing store 16/45, department 31
# Processing store 16/45, department 32
# Processing store 16/45, department 33
# Processing store 16/45, department 34
# Processing store 16/45, department 35
# Processing store 16/45, department 36
# Processing store 16/45, department 37
# Processing store 16/45, department 38
# Processing store 16/45, department 40
# Processing store 16/45, department 41
# Processing store 16/45, department 42
# Processing store 16/45, department 44
# Processing store 16/45, department 45
# Processing store 16/45, department 46
# Processing store 16/45, department 47
# Processing store 16/45, department 48
# Processing store 16/45, department 49
# Processing store 16/45, department 51
# Processing store 16/45, department 52
# Processing store 16/45, department 54
# Processing store 16/45, department 55
# Processing store 16/45, department 56
# Processing store 16/45, department 58
# Processing store 16/45, department 59
# Processing store 16/45, department 60
# Processing store 16/45, department 67
# Processing store 16/45, department 71
# Processing store 16/45, department 72
# Processing store 16/45, department 74
# Processing store 16/45, department 77
# Processing store 16/45, department 78
# Processing store 16/45, department 79
# Processing store 16/45, department 80
# Processing store 16/45, department 81
# Processing store 16/45, department 82
# Processing store 16/45, department 83
# Processing store 16/45, department 85
# Processing store 16/45, department 87
# Processing store 16/45, department 90
# Processing store 16/45, department 91
# Processing store 16/45, department 92
# Processing store 16/45, department 93
# ...
# Processing store 40/45, department 83
# Processing store 40/45, department 85
# Processing store 40/45, department 87
# Processing store 40/45, department 90
# Processing store 40/45, department 91
# Processing store 40/45, department 92
# Processing store 40/45, department 93
# Processing store 40/45, department 94
# Processing store 40/45, department 95
# Processing store 40/45, department 96
# Processing store 40/45, department 97
# Processing store 40/45, department 98
# Processing store 40/45, department 99
# Processing store 40/45, department 39
# Processing store 40/45, department 50
# Processing store 40/45, department 43
# Processing store 40/45, department 65
# Processing store 41/45, department 1
# Processing store 41/45, department 2
# Processing store 41/45, department 3
# Processing store 41/45, department 4
# Processing store 41/45, department 5
# Processing store 41/45, department 6
# Processing store 41/45, department 7
# Processing store 41/45, department 8
# Processing store 41/45, department 9
# Processing store 41/45, department 10
# Processing store 41/45, department 11
# Processing store 41/45, department 12
# Processing store 41/45, department 13
# Processing store 41/45, department 14
# Processing store 41/45, department 16
# Processing store 41/45, department 17
# Processing store 41/45, department 18
# Processing store 41/45, department 19
# Processing store 41/45, department 20
# Processing store 41/45, department 21
# Processing store 41/45, department 22
# Processing store 41/45, department 23
# Processing store 41/45, department 24
# Processing store 41/45, department 25
# Processing store 41/45, department 26
# Processing store 41/45, department 27
# Processing store 41/45, department 28
# Processing store 41/45, department 29
# Processing store 41/45, department 30
# Processing store 41/45, department 31
# Processing store 41/45, department 32
# Processing store 41/45, department 33
# Processing store 41/45, department 34
# Processing store 41/45, department 35
# Processing store 41/45, department 36
# Processing store 41/45, department 37
# Processing store 41/45, department 38
# Processing store 41/45, department 40
# Processing store 41/45, department 41
# Processing store 41/45, department 42
# Processing store 41/45, department 44
# Processing store 41/45, department 45
# Processing store 41/45, department 46
# Processing store 41/45, department 47
# Processing store 41/45, department 48
# Processing store 41/45, department 49
# Processing store 41/45, department 51
# Processing store 41/45, department 52
# Processing store 41/45, department 54
# Processing store 41/45, department 55
# Processing store 41/45, department 56
# Processing store 41/45, department 58
# Processing store 41/45, department 59
# Processing store 41/45, department 60
# Processing store 41/45, department 67
# Processing store 41/45, department 71
# Processing store 41/45, department 72
# Processing store 41/45, department 74
# Processing store 41/45, department 77
# Processing store 41/45, department 78
# Processing store 41/45, department 79
# Processing store 41/45, department 80
# Processing store 41/45, department 81
# Processing store 41/45, department 82
# Processing store 41/45, department 83
# Processing store 41/45, department 85
# Processing store 41/45, department 87
# Processing store 41/45, department 90
# Processing store 41/45, department 91
# Processing store 41/45, department 92
# Processing store 41/45, department 93
# Processing store 41/45, department 94
# Processing store 41/45, department 95
# Processing store 41/45, department 96
# Processing store 41/45, department 97
# Processing store 41/45, department 98
# Processing store 41/45, department 99
# Processing store 41/45, department 39
# Processing store 41/45, department 50
# Processing store 41/45, department 43
# Processing store 41/45, department 65
# Processing store 42/45, department 1
# Processing store 42/45, department 2
# Processing store 42/45, department 3
# Processing store 42/45, department 4
# Processing store 42/45, department 5
# Processing store 42/45, department 6
# Processing store 42/45, department 7
# Processing store 42/45, department 8
# Processing store 42/45, department 9
# Processing store 42/45, department 10
# Processing store 42/45, department 11
# Processing store 42/45, department 12
# Processing store 42/45, department 13
# Processing store 42/45, department 14
# Processing store 42/45, department 16
# Processing store 42/45, department 17
# Processing store 42/45, department 18
# Processing store 42/45, department 19
# Processing store 42/45, department 20
# Processing store 42/45, department 21
# Processing store 42/45, department 22
# Processing store 42/45, department 23
# Processing store 42/45, department 24
# Processing store 42/45, department 25
# Processing store 42/45, department 26
# Processing store 42/45, department 27
# Processing store 42/45, department 28
# Processing store 42/45, department 29
# Processing store 42/45, department 30
# Processing store 42/45, department 31
# Processing store 42/45, department 32
# Processing store 42/45, department 33
# Processing store 42/45, department 34
# Processing store 42/45, department 35
# Processing store 42/45, department 36
# Processing store 42/45, department 37
# Processing store 42/45, department 38
# Processing store 42/45, department 40
# Processing store 42/45, department 41
# Processing store 42/45, department 42
# Processing store 42/45, department 44
# Processing store 42/45, department 45
# Processing store 42/45, department 46
# Processing store 42/45, department 47
# Processing store 42/45, department 48
# Processing store 42/45, department 49
# Processing store 42/45, department 51
# Processing store 42/45, department 52
# Processing store 42/45, department 54
# Processing store 42/45, department 55
# Processing store 42/45, department 56
# Processing store 42/45, department 58
# Processing store 42/45, department 59
# Processing store 42/45, department 60
# Processing store 42/45, department 67
# Processing store 42/45, department 71
# Processing store 42/45, department 72
# Processing store 42/45, department 74
# Processing store 42/45, department 77
# Processing store 42/45, department 78
# Processing store 42/45, department 79
# Processing store 42/45, department 80
# Processing store 42/45, department 81
# Processing store 42/45, department 82
# Processing store 42/45, department 83
# Processing store 42/45, department 85
# Processing store 42/45, department 87
# Processing store 42/45, department 90
# Processing store 42/45, department 91
# Processing store 42/45, department 92
# Processing store 42/45, department 93
# Processing store 42/45, department 94
# Processing store 42/45, department 95
# Processing store 42/45, department 96
# Processing store 42/45, department 97
# Processing store 42/45, department 98
# Processing store 42/45, department 99
# Processing store 42/45, department 39
# Processing store 42/45, department 50
# Processing store 42/45, department 43
# Processing store 42/45, department 65
# Processing store 43/45, department 1
# Processing store 43/45, department 2
# Processing store 43/45, department 3
# Processing store 43/45, department 4
# Processing store 43/45, department 5
# Processing store 43/45, department 6
# Processing store 43/45, department 7
# Processing store 43/45, department 8
# Processing store 43/45, department 9
# Processing store 43/45, department 10
# Processing store 43/45, department 11
# Processing store 43/45, department 12
# Processing store 43/45, department 13
# Processing store 43/45, department 14
# Processing store 43/45, department 16
# Processing store 43/45, department 17
# Processing store 43/45, department 18
# Processing store 43/45, department 19
# Processing store 43/45, department 20
# Processing store 43/45, department 21
# Processing store 43/45, department 22
# Processing store 43/45, department 23
# Processing store 43/45, department 24
# Processing store 43/45, department 25
# Processing store 43/45, department 26
# Processing store 43/45, department 27
# Processing store 43/45, department 28
# Processing store 43/45, department 29
# Processing store 43/45, department 30
# Processing store 43/45, department 31
# Processing store 43/45, department 32
# Processing store 43/45, department 33
# Processing store 43/45, department 34
# Processing store 43/45, department 35
# Processing store 43/45, department 36
# Processing store 43/45, department 37
# Processing store 43/45, department 38
# Processing store 43/45, department 40
# Processing store 43/45, department 41
# Processing store 43/45, department 42
# Processing store 43/45, department 44
# Processing store 43/45, department 45
# Processing store 43/45, department 46
# Processing store 43/45, department 47
# Processing store 43/45, department 48
# Processing store 43/45, department 49
# Processing store 43/45, department 51
# Processing store 43/45, department 52
# Processing store 43/45, department 54
# Processing store 43/45, department 55
# Processing store 43/45, department 56
# Processing store 43/45, department 58
# Processing store 43/45, department 59
# Processing store 43/45, department 60
# Processing store 43/45, department 67
# Processing store 43/45, department 71
# Processing store 43/45, department 72
# Processing store 43/45, department 74
# Processing store 43/45, department 77
# Processing store 43/45, department 78
# Processing store 43/45, department 79
# Processing store 43/45, department 80
# Processing store 43/45, department 81
# Processing store 43/45, department 82
# Processing store 43/45, department 83
# Processing store 43/45, department 85
# Processing store 43/45, department 87
# Processing store 43/45, department 90
# Processing store 43/45, department 91
# Processing store 43/45, department 92
# Processing store 43/45, department 93
# Processing store 43/45, department 94
# Processing store 43/45, department 95
# Processing store 43/45, department 96
# Processing store 43/45, department 97
# Processing store 43/45, department 98
# Processing store 43/45, department 99
# Processing store 43/45, department 39
# Processing store 43/45, department 50
# Processing store 43/45, department 43
# Processing store 43/45, department 65
# Processing store 44/45, department 1
# Processing store 44/45, department 2
# Processing store 44/45, department 3
# Processing store 44/45, department 4
# Processing store 44/45, department 5
# Processing store 44/45, department 6
# Processing store 44/45, department 7
# Processing store 44/45, department 8
# Processing store 44/45, department 9
# Processing store 44/45, department 10
# Processing store 44/45, department 11
# Processing store 44/45, department 12
# Processing store 44/45, department 13
# Processing store 44/45, department 14
# Processing store 44/45, department 16
# Processing store 44/45, department 17
# Processing store 44/45, department 18
# Processing store 44/45, department 19
# Processing store 44/45, department 20
# Processing store 44/45, department 21
# Processing store 44/45, department 22
# Processing store 44/45, department 23
# Processing store 44/45, department 24
# Processing store 44/45, department 25
# Processing store 44/45, department 26
# Processing store 44/45, department 27
# Processing store 44/45, department 28
# Processing store 44/45, department 29
# Processing store 44/45, department 30
# Processing store 44/45, department 31
# Processing store 44/45, department 32
# Processing store 44/45, department 33
# Processing store 44/45, department 34
# Processing store 44/45, department 35
# Processing store 44/45, department 36
# Processing store 44/45, department 37
# Processing store 44/45, department 38
# Processing store 44/45, department 40
# Processing store 44/45, department 41
# Processing store 44/45, department 42
# Processing store 44/45, department 44
# Processing store 44/45, department 45
# Processing store 44/45, department 46
# Processing store 44/45, department 47
# Processing store 44/45, department 48
# Processing store 44/45, department 49
# Processing store 44/45, department 51
# Processing store 44/45, department 52
# Processing store 44/45, department 54
# Processing store 44/45, department 55
# Processing store 44/45, department 56
# Processing store 44/45, department 58
# Processing store 44/45, department 59
# Processing store 44/45, department 60
# Processing store 44/45, department 67
# Processing store 44/45, department 71
# Processing store 44/45, department 72
# Processing store 44/45, department 74
# Processing store 44/45, department 77
# Processing store 44/45, department 78
# Processing store 44/45, department 79
# Processing store 44/45, department 80
# Processing store 44/45, department 81
# Processing store 44/45, department 82
# Processing store 44/45, department 83
# Processing store 44/45, department 85
# Processing store 44/45, department 87
# Processing store 44/45, department 90
# Processing store 44/45, department 91
# Processing store 44/45, department 92
# Processing store 44/45, department 93
# Processing store 44/45, department 94
# Processing store 44/45, department 95
# Processing store 44/45, department 96
# Processing store 44/45, department 97
# Processing store 44/45, department 98
# Processing store 44/45, department 99
# Processing store 44/45, department 39
# Processing store 44/45, department 50
# Processing store 44/45, department 43
# Processing store 44/45, department 65
# Processing store 45/45, department 1
# Processing store 45/45, department 2
# Processing store 45/45, department 3
# Processing store 45/45, department 4
# Processing store 45/45, department 5
# Processing store 45/45, department 6
# Processing store 45/45, department 7
# Processing store 45/45, department 8
# Processing store 45/45, department 9
# Processing store 45/45, department 10
# Processing store 45/45, department 11
# Processing store 45/45, department 12
# Processing store 45/45, department 13
# Processing store 45/45, department 14
# Processing store 45/45, department 16
# Processing store 45/45, department 17
# Processing store 45/45, department 18
# Processing store 45/45, department 19
# Processing store 45/45, department 20
# Processing store 45/45, department 21
# Processing store 45/45, department 22
# Processing store 45/45, department 23
# Processing store 45/45, department 24
# Processing store 45/45, department 25
# Processing store 45/45, department 26
# Processing store 45/45, department 27
# Processing store 45/45, department 28
# Processing store 45/45, department 29
# Processing store 45/45, department 30
# Processing store 45/45, department 31
# Processing store 45/45, department 32
# Processing store 45/45, department 33
# Processing store 45/45, department 34
# Processing store 45/45, department 35
# Processing store 45/45, department 36
# Processing store 45/45, department 37
# Processing store 45/45, department 38
# Processing store 45/45, department 40
# Processing store 45/45, department 41
# Processing store 45/45, department 42
# Processing store 45/45, department 44
# Processing store 45/45, department 45
# Processing store 45/45, department 46
# Processing store 45/45, department 47
# Processing store 45/45, department 48
# Processing store 45/45, department 49
# Processing store 45/45, department 51
# Processing store 45/45, department 52
# Processing store 45/45, department 54
# Processing store 45/45, department 55
# Processing store 45/45, department 56
# Processing store 45/45, department 58
# Processing store 45/45, department 59
# Processing store 45/45, department 60
# Processing store 45/45, department 67
# Processing store 45/45, department 71
# Processing store 45/45, department 72
# Processing store 45/45, department 74
# Processing store 45/45, department 77
# Processing store 45/45, department 78
# Processing store 45/45, department 79
# Processing store 45/45, department 80
# Processing store 45/45, department 81
# Processing store 45/45, department 82
# Processing store 45/45, department 83
# Processing store 45/45, department 85
# Processing store 45/45, department 87
# Processing store 45/45, department 90
# Processing store 45/45, department 91
# Processing store 45/45, department 92
# Processing store 45/45, department 93
# Processing store 45/45, department 94
# Processing store 45/45, department 95
# Processing store 45/45, department 96
# Processing store 45/45, department 97
# Processing store 45/45, department 98
# Processing store 45/45, department 99
# Processing store 45/45, department 39
# Processing store 45/45, department 50
# Processing store 45/45, department 43
# Processing store 45/45, department 65

# %%
act_fun = 'tanh'

in0 = Input(shape=(lookback,1,))
x = LSTM(units=100,activation=act_fun,return_sequences=False)(in0)
x = Dropout(0.1)(x)
x = Dense(units=50,activation=act_fun)(x)
x = Dropout(0.1)(x)
x = Dense(units=20,activation=act_fun)(x)
x = Dropout(0.1)(x)
x = Dense(units=5,activation=act_fun)(x)
x = Dropout(0.1)(x)
out0 = Dense(units=ytrain_oh.shape[1],activation='softmax')(x)

model = Model(in0,out0)
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %%
model.fit(Xtrain,ytrain_oh,batch_size=3,epochs=2,validation_split=0.1)
# Out:
# Train on 47630 samples, validate on 5293 samples
# Epoch 1/2
# 47630/47630 [==============================] - 1152s 24ms/step - loss: 2.0437 - categorical_accuracy: 0.1603 - val_loss: 1.9697 - val_categorical_accuracy: 0.1853
# Epoch 2/2
# 47630/47630 [==============================] - 1100s 23ms/step - loss: 2.0178 - categorical_accuracy: 0.1608 - val_loss: 1.9835 - val_categorical_accuracy: 0.1823

# %%
t
# Out:
# array([], dtype=float64)
