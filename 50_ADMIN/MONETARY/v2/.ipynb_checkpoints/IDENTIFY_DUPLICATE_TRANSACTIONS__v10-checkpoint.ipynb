# %%
import numpy as np
from tqdm import tqdm

import pandas as pd

from fuzzywuzzy import fuzz
import textdistance

from itertools import product,combinations_with_replacement

# %%
def confirm_duplicate(u,BaseList):
    return (BaseList.count(u[0])==1 and BaseList.count(u[1])==1 and ((u[0].rstrip().lstrip().lower() in u[1].rstrip().lstrip().lower()) or (u[1].rstrip().lstrip().lower() in u[0].rstrip().lstrip().lower())))

# %%
datapath = storepath = '..\\..\\..\\..\\TF_data\\ADMIN\\v2\\04_DATA\\STF.xlsx'

# %%
bf = pd.read_excel(datapath,index_col=0,parse_dates=['Date_booked','Date_ordered'])

# %%
df = bf.drop(columns=['Use'])

for colname in df.columns: 
    if df[colname].dtype=='object':
        df[colname] = df[colname].str.lower()
        
df['DUPLICATE'] = -1

# %%
SIM_THRESHOLD = 0

# %%
daterange = list(pd.date_range(df['Date_booked'].min(),df['Date_booked'].max(),freq='D'))

d_flag = 1
for c_date in tqdm(daterange):

    tf = df[(df['Date_booked']==c_date)].drop(columns=['Date_booked'])

    for colname in tf.columns:
        if len(tf[colname].unique())==1: tf = tf.drop(columns=[colname])
    I = []
    for k in list(product(tf.index.tolist(),tf.index.tolist())):
        if k[0]!=k[1] and (k[1],k[0]) not in I: I.append(list(k))

    for ii in I:
        if df.loc[ii,'DUPLICATE'].sum()!=-2: continue
        sim = []
        for X in tf.loc[ii].transpose().values:
            if pd.isnull(X[0]): sim.append(abs(1 - pd.isnull(X[0])))
            elif pd.isnull(X[1]): sim.append(abs(1 - pd.isnull(X[1])))
            elif type(X[0]) is str: sim.append(abs(fuzz.ratio(X[0],X[1]))/100)
            elif type(X[0]) is type(pd.to_datetime('2020-01-01')): sim.append(abs((X[0]-X[1]).days))
            else: sim.append(abs(X[0]-X[1])/10)
        if sum(sim)<=SIM_THRESHOLD: 
            df.loc[ii,'DUPLICATE'] = d_flag
            d_flag = d_flag + 1
bf['DUPLICATE'] = df['DUPLICATE']
# Out:
# 100%|████████████████████████████████████████| 511/511 [00:26<00:00, 19.05it/s]

# %%
BaseList = [k for k in bf['Use'].tolist()]

keep_indices = []
drop_indices = []
for k in bf[bf['DUPLICATE']>0]['DUPLICATE'].unique().tolist():
    u = bf[bf['DUPLICATE']==k]['Use'].tolist()
    if confirm_duplicate(u,BaseList):
        if len(bf[bf['DUPLICATE']==k].index.tolist())!=2:
            print('Error')
            break
        keep_indices.append(bf[bf['DUPLICATE']==k].index.tolist()[0])
        drop_indices.append(bf[bf['DUPLICATE']==k].index.tolist()[1])

# %%
bf.loc[keep_indices]
# Out:
#                OrderAccount Date_booked Date_ordered      Text_transaction  \
# 10   DE98773501100020557849  2019-09-26   2019-09-26      FOLGELASTSCHRIFT
# 28   DE98773501100020557849  2019-09-04   2019-09-04      FOLGELASTSCHRIFT
# 40   DE98773501100020557849  2019-08-27   2019-08-27      FOLGELASTSCHRIFT
# 48   DE98773501100020557849  2019-08-20   2019-08-20      FOLGELASTSCHRIFT
# 462  DE98773501100020557849  2019-12-13   2019-12-13      FOLGELASTSCHRIFT
# 472  DE98773501100020557849  2019-12-04   2019-12-04      FOLGELASTSCHRIFT
# 499  DE98773501100020557849  2019-11-21   2019-11-21      FOLGELASTSCHRIFT
#
#                                                    Use  \
# 10   D01 3386999 4642225 Prime Video 7EIIAB22V8IHBJFC
# 28    Kieser Training Beitrag ID238912 VOM 03 09 2019
# 40   D01 6278352 4568626 Prime Video 1R29MPD0NUAZ417C
# 48   D01 8161227 1743057 Prime Video 74Q50QIR3FUSSRCL
# 56   D01 4754261 2520624 Prime Video 5N3BYPLUG6LWAFRD
# 66   D01 0301409 3730272 Prime Video 6YUMOXRCXBBLKZA5
# 76   D01 8332720 6610260 Prime Video 1PJUZ9P3PYJZEDKI
# 79   D01 6698135 8149415 Prime Video 37A79GB17VHDGTTK
# 80   D01 6227746 4946224 Prime Video M3RYPLI2AI238NV3
# 81   D01 7214196 8117415 Prime Video 45E1WI28SYRDDZ5J
# 85   D01 9646851 5179845 Prime Video 5PW3VA2DBWO9AY7C
# 87    Kieser Training Beitrag ID238910 VOM 03 07 2019
# 88   D01 6839793 5448645 Prime Video 1IYF3F4MN253ZE3X
# 103  D01 7612084 4725469 Prime Video 1NCHX9E1VRM6XSRH
# 104  D01 4898708 5723861 Prime Video 6L85GJFMCBLOPMNS
# 105  D01 6872360 1925400 Prime Video 6RNI8KF7WTEFUSQB
# 118  D Nr 1010002015 INV B000000060230 vom 06 06 20...
# 119  D01 0767502 7307832 Prime Video 2I3UODAH5Z2C6GA7
# 126  D01 5445295 4040669 Prime Video 5VLB84D81P4SHPTL
# 146        1406 06 584K00 19052305119720144701G584K00
# 161  302 9065472 0492360 AMZN Mktp DE 3ENUA6FNSGPZY...
# 194                 CINESTAR Ihr Einkauf bei CINESTAR
# 197  D01 0389268 1266266 Prime Video 6R20YADL3I0Y25Q3
# 250                   Reise VSNR 783299846 14 03 2019
# 252  D Nr 1010002015 INV B000000042174 vom 07 03 20...
# 352  EREF 209559791MREF 783299846G60018CRED DE74ZZZ...
# 353  EREF 65UNTV6SM1FC185CMREF oc37jPPdyn 18 Jnwk 4...
# 360  EREF Kieser Training Beitrag ID238918 MREF 499...
# 374  EREF 1008096183000 PP 8381 PP PAYPALMREF 4CP22...
# 379  EREF 1008054027618 PP 8381 PP PAYPALMREF 4CP22...
# 389  EREF 1798216 1SVWZ 0005051985 1798216 1 7 2 20...
# 419  EREF 49CRDSXPECNXXXFFMREF oc37jPPdyn 18 Jnwk 4...
# 421  EREF 13003702902020MREF M5015451760001CRED DE3...
# 423  EREF FIJ7WZF555CFP395MREF oc37jPPdyn 18 Jnwk 4...
# 427  EREF 6Z5BWNI40DRD3BDOMREF oc37jPPdyn 18 Jnwk 4...
# 430  EREF Kieser Training Beitrag ID238916 MREF 499...
# 460  EREF 53289PG8875QZKJGMREF oc37jPPdyn 18 Jnwk 4...
# 461  EREF 4GMSKXARK6IF1HNTMREF oc37jPPdyn 18 Jnwk 4...
# 462  EREF 2L65ZNHIIRLJXSBUMREF oc37jPPdyn 18 Jnwk 4...
# 472  EREF Kieser Training Beitrag ID238915 MREF 499...
# 499  EREF 13039767272019MREF M5015451760001CRED DE3...
#
#                                  Contact                  AccNum          BIC  \
# 10     AMAZON INSTANT VIDEO GERMANY GMBH  DE07300308800013011001  TUBDDEDDXXX
#
99      EUR  Umsatz gebucht            AMAZONVIDEOS
# 126              -3.99      EUR  Umsatz gebucht            AMAZONVIDEOS
# 146            1406.06      EUR  Umsatz gebucht                  SALARY
# 161              -8.00      EUR  Umsatz gebucht          AMAZONSHOPPING
# 194             -24.20      EUR  Umsatz gebucht             PAYPAL_MISC
# 197              -3.99      EUR  Umsatz gebucht            AMAZONVIDEOS
# 250              -9.90      EUR  Umsatz gebucht           INSURANCE TKK
# 252             -29.90      EUR  Umsatz gebucht          UTILITIES INET
# 352              -9.90      EUR  Umsatz gebucht           INSURANCE TKK
# 353              -4.98      EUR  Umsatz gebucht            AMAZONVIDEOS
# 360             -69.00      EUR  Umsatz gebucht  MEMBERSHIP_FEES KIESER
# 374             -63.00      EUR  Umsatz gebucht             PAYPAL_MISC
# 379             -31.50      EUR  Umsatz gebucht             PAYPAL_MISC
# 389             525.56      EUR  Umsatz gebucht        LENTBACK_PRIVATE
# 419              -3.99      EUR  Umsatz gebucht            AMAZONVIDEOS
# 421             -29.89      EUR  Umsatz gebucht          UTILITIES INET
# 423              -2.99      EUR  Umsatz gebucht            AMAZONVIDEOS
# 427              -3.99      EUR  Umsatz gebucht            AMAZONVIDEOS
# 430             -69.00      EUR  Umsatz gebucht  MEMBERSHIP_FEES KIESER
# 460             -25.99      EUR  Umsatz gebucht          AMAZONSHOPPING
# 461              -2.71      EUR  Umsatz gebucht          AMAZONSHOPPING
# 462              -7.99      EUR  Umsatz gebucht          AMAZONSHOPPING
# 472             -69.00      EUR  Umsatz gebucht  MEMBERSHIP_FEES KIESER
# 499             -29.89      EUR  Umsatz gebucht          UTILITIES INET
#
#         ExpenseGroup  DUPLICATE
# 10            AMAZON         36
# 28   MEMBERSHIP_FEES         34
# 40            AMAZON         33
# 48            AMAZON         32
# 56            AMAZON         31
# 66            AMAZON         30
# 76            AMAZON         29
# 79            AMAZON         27
# 80            AMAZON         26
# 81            AMAZON         25
# 85            AMAZON         24
# 87   MEMBERSHIP_FEES         22
# 88            AMAZON         21
# 103           AMAZON         19
# 104           AMAZON         20
# 105           AMAZON         18
# 118        UTILITIES         17
# 119           AMAZON         16
# 126           AMAZON         15
# 146           SALARY         11
# 161           AMAZON         39
# 194             MISC         38
# 197           AMAZON         37
# 250        INSURANCE          4
# 252        UTILITIES          2
# 352        INSURANCE         62
# 353           AMAZON         61
# 360  MEMBERSHIP_FEES         60
# 374             MISC         57
# 379             MISC         56
# 389         LENTBACK         53
# 419           AMAZON         51
# 421        UTILITIES         49
# 423           AMAZON         47
# 427           AMAZON         46
# 430  MEMBERSHIP_FEES         45
# 460           AMAZON         42
# 461           AMAZON         43
# 462           AMAZON         44
# 472  MEMBERSHIP_FEES         41
# 499        UTILITIES         40

# %%
drop_indices
# Out:
# [557,
#  575,
#  585,
#  593,
#  601,
#  611,
#  619,
#  622,
#  623,
#  624,
#  628,
#  630,
#  631,
#  644,
#  645,
#  646,
#  659,
#  660,
#  667,
#  686,
#  502,
#  533,
#  536,
#  737,
#  739,
#  771,
#  772,
#  779,
#  792,
#  797,
#  807,
#  835,
#  837,
#  839,
#  843,
#  846,
#  874,
#  875,
#  876,
#  886,
#  911]
