# %%
import pandas as pd

import numpy as np
from matplotlib import pyplot as plt
from numpy import random as rnd
import warnings,os,datetime

import tensorflow as tf

from keras.models import Model,Sequential
from keras.layers import Dense,Conv2D,Dropout,BatchNormalization,LSTM,Input

from sklearn import preprocessing as pp
# Out:
# C:\Users\Jan\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data = pd.read_csv('DATA\\data1\\data.csv')
data['Date'] = pd.to_datetime(data['Date'],infer_datetime_format=True)

catlist = list(data['Variable'].astype('category').cat.categories)
data['Variable'] = data['Variable'].astype('category').cat.codes

data = data.sort_values(by=['Date'])
data = data.drop(data[data['Value'].isnull()].index)
data = data.reset_index(drop=True)

# %%
doc = pd.read_csv('Data\\data1\\documentation.csv')

# %%
doc
# Out:
#      file_name                                        description  \
# 0      a01005a            U.S. Index of Crop Production 1862-1930
# 1     a01005aa  U.S. Index of Crop Producton, Twelve Important...
# 2      a01005b      U.S. Index of Total Crop Production 1866-1950
# 3       a01006   Great Britain Index of Crop Production 1866-1947
# 4      a01007a   U.S. Index of Manufacturing Production 1863-1930
# 5      a01007b   U.S. Index of Manufacturing Production 1920-1939
# 6      a01008a  U.S. Index of Total Physical Production 1863-1921
# 7     a01008aa   Germany Index of Industrial Production 1860-1913
# 8     a01008ab              Germany Index of Production 1913-1931
# 9     a01008ac              Germany Index of Production 1925-1937
# 10    a01008ad   Germany Index of Industrial Production 1919-1931
# 11    a01008ae              Germany Index of Production 1925-1937
# 12     a01008b  U.S. Index of Crop Production, Industrial Prod...
# ...
