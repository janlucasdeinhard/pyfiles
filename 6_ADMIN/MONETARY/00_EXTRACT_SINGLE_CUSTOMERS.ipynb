# %%
# Imports
import numpy as np
import datetime,os
import pandas as pd
from fuzzywuzzy import fuzz
import pyodbc
import re
from itertools import product
from ipywidgets import IntProgress
from IPython.display import display

# Read in STR table
def read_STR(dbpath):
    # Connect to Access DB
    conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ='+dbpath+';')
    # Read Single Transactions table
    STR = pd.read_sql_query(
    '''
    SELECT * FROM STR
    '''
    ,conn).reset_index(drop=True)
    # Close connection
    conn.close()
    # Transform STR
    STR['Date_booked'] = pd.to_datetime(STR['Date_booked'])
    STR['Date_ordered'] = pd.to_datetime(STR['Date_ordered'])
    STR['Value_transaction'] = STR['Value_transaction'].astype('float')
    return STR

# Read in TRI table
def read_TRI(dbpath):
    # Connect to Access DB
    conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ='+dbpath+';')
    # Read Transaction Information table
    TRI = pd.read_sql_query(
    '''
    SELECT * FROM TRINFORMATION
    '''
    ,conn).reset_index(drop=True)
    # Close connection
    conn.close()
    return TRI

# %%
# Load data

dbpath = '..\\..\\..\\..\\banking.accdb'

STR = read_STR(dbpath)
TRI = read_TRI(dbpath)

bf = pd.merge(STR,TRI,on='KEYID',how='left')

# %%
# Identify single transactions by known keywords 

bf.loc[bf[(bf['Text_transaction']=='BARGELDAUSZAHLUNG')].index,'CTYPE']= 'SINGLE'
bf.loc[bf[(bf['Text_transaction']=='BARGELDAUSZAHLUNG')].index,'EPARTYID']= '0'
bf.loc[bf[(bf['Text_transaction']=='BARGELDAUSZAHLUNG')].index,'EPARTYNAME']= 'CASHOUT'

# %%
df0 = bf[bf['Text_transaction']!='BARGELDAUSZAHLUNG'].reset_index(drop=True)
df0['CustomerKEY'] = df0.apply(lambda x: str(x['Contact'])+'|'+str(x['AccNum'])+'|'+str(x['Use']),axis=1)

# %%
L = []
for k in product(df0['CustomerKEY'].unique(),df0['CustomerKEY'].unique()):
    L.append([k[0].lower(),k[1].lower()])

# %%
df1 = pd.DataFrame(L).rename(columns={0:'A0',1:'A1'})

# %%
df1['A0NAME'] = df1.apply(lambda x: x['A0'].split('|')[0],axis=1)
df1['A0NUMBER'] = df1.apply(lambda x: x['A0'].split('|')[1],axis=1)
df1['A0USE'] = df1.apply(lambda x: x['A0'].split('|')[2],axis=1)

df1['A1NAME'] = df1.apply(lambda x: x['A1'].split('|')[0],axis=1)
df1['A1NUMBER'] = df1.apply(lambda x: x['A1'].split('|')[1],axis=1)
df1['A1USE'] = df1.apply(lambda x: x['A1'].split('|')[2],axis=1)

# %%
df1['SIM_name'] = df1.apply(lambda x: float(fuzz.ratio(x['A0NAME'],x['A1NAME']))/100,axis=1)
df1['SIM_num'] = df1.apply(lambda x: float(fuzz.ratio(x['A0NUMBER'],x['A1NUMBER']))/100,axis=1)
df1['SIM_use'] = df1.apply(lambda x: float(fuzz.ratio(x['A0USE'],x['A1USE']))/100,axis=1)

# %%
df2 = df1[['A0','A1','SIM_name','SIM_num','SIM_use']]

# %%
import plotly.express as px

df = px.data.iris()
fig = px.scatter_3d(df2, x='SIM_name', y='SIM_num', z='SIM_use')
fig.show()

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN()
# Out:
#                                                       A0  \
# 0      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 1      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 2      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 3      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 4      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 5      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 6      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 7      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 8      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 9      nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 10     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 11     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 12     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 13     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 14     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 15     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 16     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 17     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 18     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 19     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 20     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 21     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 22     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 23     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 24     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 25     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 26     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 27     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 28     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# 29     nan|0020557849|abrechnung 30 09 2019 siehe anl...
# ...                                                  ...
# 55195  m net telekommunikations gmbh|de74700500000000...
# 55196  m net telekommunikations gmbh|de74700500000000...
# 55197  m net telekommunikations gmbh|de74700500000000...
# 55198  m net telekommunikations gmbh|de74700500000000...
# 55199  m net telekommunikations gmbh|de74700500000000...
# 55200  m net telekommunikations gmbh|de74700500000000...
# 55201  m net telekommunikations gmbh|de74700500000000...
# 55202  m net telekommunikations gmbh|de74700500000000...
# 55203  m net telekommunikations gmbh|de74700500000000...
# 55204  m net telekommunikations gmbh|de74700500000000...
# 55205  m net telekommunikations gmbh|de74700500000000...
# 55206  m net telekommunikations gmbh|de74700500000000...
# 55207  m net telekommunikations gmbh|de74700500000000...
# 55208  m net telekommunikations gmbh|de74700500000000...
# 55209  m net telekommunikations gmbh|de74700500000000...
# 55210  m net telekommunikations gmbh|de74700500000000...
# 55211  m net telekommunikations gmbh|de74700500000000...
# 55212  m net telekommunikations gmbh|de74700500000000...
# 55213  m net telekommunikations gmbh|de74700500000000...
# 55214  m net telekommunikations gmbh|de74700500000000...
# 55215  m net telekommunikations gmbh|de74700500000000...
# 55216  m net telekommunikations gmbh|de74700500000000...
# 55217  m net telekommunikations gmbh|de74700500000000...
# 55218  m net telekommunikations gmbh|de74700500000000...
# 55219  m net telekommunikations gmbh|de74700500000000...
# 55220  m net telekommunikations gmbh|de74700500000000...
# 55221  m net telekommunikations gmbh|de74700500000000...
# 55222  m net telekommunikations gmbh|de74700500000000...
# 55223  m net telekommunikations gmbh|de74700500000000...
# 55224  m net telekommunikations gmbh|de74700500000000...
#
#                                                       A1  SIM_name  SIM_num  \
# 0      nan|0020557849|abrechnung 30 09 2019 siehe anl...      1.00     1.00
# 1         nan|0000000000|entgeltabrechnung siehe anlage       1.00     0.30
# 2      elaine fernandez|de46763500000044116613|miete ...      0.32     0.25
# 3      slf sportland franken gmbh co kg|de88763500000...      0.17     0.25
# 4      siemens aktiengesellschaft|de53700700100203008...      0.21     0.31
# 5      telekom deutschland gmbh landgrabenweg 151|de6...      0.13     0.38
# 6      estw erlangerstadtwerkeag|de067632007200045367...      0.14     0.38
# 7      igm erlangen|de28500500000083044008|beitrag bi...      0.27     0.31
# 8      siemens ag|de90700500000002055382|lohn gehalt ...      0.31     0.44
# 9      amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 10     amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 11     amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 12     paypal europe s a r l et cie s c a |de88500700...      0.05     0.31
# 13     amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 14     kreditkartenabrechnung|9902292060|visa abr 490...      0.24     0.30
# 15     schaefer nohe sagt danke erlangen de|de4637010...      0.15     0.38
# 16     amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 17     paypal europe s a r l et cie s c a |de88500700...      0.05     0.31
# 18     amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 19     m net telekommunikations gmbh|de74700500000000...      0.19     0.25
# 20     amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 21     amazon instant video germany gmbh|de0730030880...      0.17     0.25
# 22     paypal europe s a r l et cie s c a |de88500700...      0.05     0.31
# 23     jens moeller gmbh|de85763500000000001669|kiese...      0.10     0.25
# 24     karstadt lebensm sagt dank nuernberg lorenz de...      0.12     0.31
# 25     xxxs006xxx saturn e nuernberg de|de38300500000...      0.11     0.25
# 26     aldi gmbh co kg erlangen de|de2930050000000113...      0.13     0.25
# 27     estw erlangerstadtwerkeag|de067632007200045367...      0.14     0.38
# 28     siemens aktiengesellschaft|de53700700100203008...      0.21     0.31
# 29     slf sportland franken gmbh co kg|de88763500000...      0.17     0.25
# ...                                                  ...       ...      ...
# 55195  m net telekommunikations gmbh|de74700500000000...      1.00     1.00
# 55196  techniker krankenkasse|de18200100200030936201|...      0.31     0.50
# 55197  1283 klier erlangen de|de13269410530682240708|...      0.31     0.41
# 55198  siemens aktiengesellschaft|de53700700100203008...      0.33     0.64
# 55199  nan|0020557849|abrechnung 28 12 2018 siehe anl...      0.19     0.25
# 55200  igm erlangen|de28500500000083044008|beitrag bi...      0.34     0.68
# 55201  estw erlangerstadtwerkeag|de067632007200045367...      0.33     0.45
# 55202  slf sportland franken gmbh co kg|de88763500000...      0.36     0.68
# 55203  paypal europe s a r l et cie s c a |de88500700...      0.28     0.50
# 55204  siemens ag|de90700500000002055382|lohn gehalt ...      0.31     0.73
# 55205  telekom deutschland gmbh landgrabenweg 151|de6...      0.42     0.50
# 55206  schaefer nohe sagt danke erlangen de|de4637010...      0.31     0.55
# 55207  elaine fernandez|de46763500000044116613|gesche...      0.31     0.55
# 55208  techniker krankenkasse|de18200100200030936201|...      0.31     0.50
# 55209  m net telekommunikations gmbh|de74700500000000...      1.00     1.00
# 55210  dekabank deutsche girozentrale mainzer landstr...      0.33     0.55
# 55211  elaine fernandez|de46763500000044116613|oma ha...      0.31     0.55
# 55212  paypal europe s a r l et cie s c a |de88500700...      0.28     0.50
# 55213  estw erlangerstadtwerkeag|de067632007200045367...      0.33     0.45
# 55214  siemens aktiengesellschaft|de53700700100203008...      0.33     0.64
# 55215  slf sportland franken gmbh co kg|de88763500000...      0.36     0.68
# 55216  siemens ag|de90700500000002055382|lohn gehalt ...      0.31     0.73
# 55217  1283 klier erlangen de|de13269410530682240708|...      0.31     0.41
# 55218  igm erlangen|de28500500000083044008|beitrag bi...      0.34     0.68
# 55219  telekom deutschland gmbh landgrabenweg 151|de6...      0.42     0.50
# 55220  elaine fernandez|de46763500000044116613|geld f...      0.31     0.55
# 55221  angelika deinhard|de60773501100000932426|mit d...      0.39     0.59
# 55222  schaefer nohe sagt danke erlangen de|de4637010...      0.31     0.55
# 55223  techniker krankenkasse|de18200100200030936201|...      0.31     0.50
# 55224  m net telekommunikations gmbh|de74700500000000...      1.00     1.00
#
#        SIM_use
# 0         1.00
# 1         0.73
# 2         0.32
# 3         0.39
# 4         0.32
# 5         0.35
# 6         0.30
# 7         0.26
# 8         0.42
# 9         0.29
# 10        0.29
# 11        0.29
# 12        0.33
# 13        0.29
# 14        0.23
# 15        0.29
# 16        0.33
# 17        0.32
# 18        0.29
# 19        0.36
# 20        0.29
# 21        0.29
# 22        0.26
# 23        0.39
# 24        0.26
# 25        0.26
# 26        0.29
# 27        0.30
# 28        0.34
# 29        0.36
# ...        ...
# 55195     0.84
# 55196     0.38
# 55197     0.33
# 55198     0.31
# 55199     0.35
# 55200     0.31
# 55201     0.30
# 55202     0.34
# 55203     0.31
# 55204     0.26
# 55205     0.34
# 55206     0.29
# 55207     0.16
# 55208     0.35
# 55209     0.89
# 55210     0.31
# 55211     0.14
# 55212     0.25
# 55213     0.30
# 55214     0.30
# 55215     0.36
# 55216     0.26
# 55217     0.31
# 55218     0.31
# 55219     0.36
# 55220     0.19
# 55221     0.36
# 55222     0.31
# 55223     0.37
# 55224     1.00
#
# [55225 rows x 5 columns]
