# %% [markdown]
# # Summary
#
# This section should construct the knowledge graph. To that end, multiple functionalities need to be implemented:
#
#  * Load text file
#  * Identify all relevant nouns in the text
#  * Encode degree of association, based on textual proximity
#  * Strengthen edge weight based on frequency of association
#  * Store as graph
#  * Low-dimensional visualization of graph

# %%
# Imports

import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
import warnings,os,sys,time,datetime,itertools,math

import torch
import torch.nn as nn
import torch.nn.functional as F

import pandas as pd

import networkx as nx

# %% [markdown]
# # Load file

# %%
# Implement load

with open('./../../../TF_Data/Dropbox/TF_data/TXT_Books/illiad.txt','r',encoding='utf8') as txtfile:
    lines = txtfile.readlines()

# %%
lines
# Out:
# ['\ufeffThe Project Gutenberg eBook of The Iliad, by Homer\n',
#  '\n',
#  'This eBook is for the use of anyone anywhere in the United States and\n',
#  'most other parts of the world at no cost and with almost no restrictions\n',
#  'whatsoever. You may copy it, give it away or re-use it under the terms\n',
#  'of the Project Gutenberg License included with this eBook or online at\n',
#  'www.gutenberg.org. If you are not located in the United States, you\n',
#  'will have to check the laws of the country where you are located before\n',
#  'using this eBook.\n',
#  '\n',
#  'Title: The Iliad\n',
#  '\n',
#  'Author: Homer\n',
#  '\n',
#  'Translator: Alexander Pope\n',
#  '\n',
#  'Release Date: November 17, 2002 [eBook #6130]\n',
#  '[Most recently updated: February 5, 2022]\n',
#  '\n',
#  'Language: English\n',
#  '\n',
#  '\n',
#  'Produced by: Anne Soulard, Juliet Sutherland, Charles Franks, and The Online Distributed Proofreading Team\n',
#  '\n',
# ...

# %% [markdown]
# # Preprocess file and extract knowledge graph

# %%
# Extract nouns

# Extract edge connections

# Determine edge weight

# %% [markdown]
# # Convert to graph

# %%
# Convert to networkx format

# %% [markdown]
# # Visualize result

# %%
# Visualize graph in low-dimensional space
