# %%
from __future__ import print_function, division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

num_epochs = 100
total_series_length = 50000
truncated_backprop_length = 15
state_size = 4
num_classes = 2
echo_step = 3
batch_size = 5
num_batches = total_series_length//batch_size//truncated_backprop_length

def generateData():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1))  
    y = y.reshape((batch_size, -1))

    return (x, y)

batchX_placeholder = tf.placeholder(tf.float32, [batch_size, truncated_backprop_length])
batchY_placeholder = tf.placeholder(tf.int32, [batch_size, truncated_backprop_length])

init_state = tf.placeholder(tf.float32, [batch_size, state_size])

W = tf.Variable(np.random.rand(state_size+1, state_size), dtype=tf.float32)
b = tf.Variable(np.zeros((1,state_size)), dtype=tf.float32)

W2 = tf.Variable(np.random.rand(state_size, num_classes),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,num_classes)), dtype=tf.float32)

# Unpack columns
inputs_series = tf.unstack(batchX_placeholder, axis=1)
labels_series = tf.unstack(batchY_placeholder, axis=1)

# Forward pass
current_state = init_state
states_series = []
for current_input in inputs_series:
    current_input = tf.reshape(current_input, [batch_size, 1])
    input_and_state_concatenated = tf.concat([current_input, current_state],1)  # Increasing number of columns

    next_state = tf.tanh(tf.matmul(input_and_state_concatenated, W) + b)  # Broadcasted addition
    states_series.append(next_state)
    current_state = next_state

logits_series = [tf.matmul(state, W2) + b2 for state in states_series] #Broadcasted addition
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels) for logits, labels in zip(logits_series,labels_series)]
total_loss = tf.reduce_mean(losses)

train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)

def plot(loss_list, predictions_series, batchX, batchY):
    plt.subplot(2, 3, 1)
    plt.cla()
    plt.plot(loss_list)

    for batch_series_idx in range(5):
        one_hot_output_series = np.array(predictions_series)[:, batch_series_idx, :]
        single_output_series = np.array([(1 if out[0] < 0.5 else 0) for out in one_hot_output_series])

        plt.subplot(2, 3, batch_series_idx + 2)
        plt.cla()
        plt.axis([0, truncated_backprop_length, 0, 2])
        left_offset = range(truncated_backprop_length)
        plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
        plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
        plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")

    plt.draw()
    plt.pause(0.0001)


with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    plt.ion()
    plt.figure()
    plt.show()
    loss_list = []

    for epoch_idx in range(num_epochs):
        x,y = generateData()
        _current_state = np.zeros((batch_size, state_size))

        print("New data, epoch", epoch_idx)

        for batch_idx in range(num_batches):
            start_idx = batch_idx * truncated_backprop_length
            end_idx = start_idx + truncated_backprop_length

            batchX = x[:,start_idx:end_idx]
            batchY = y[:,start_idx:end_idx]

            _total_loss, _train_step, _current_state, _predictions_series = sess.run(
                [total_loss, train_step, current_state, predictions_series],
                feed_dict={
                    batchX_placeholder:batchX,
                    batchY_placeholder:batchY,
                    init_state:_current_state
                })

            loss_list.append(_total_loss)

            if batch_idx%100 == 0:
                print("Step",batch_idx, "Loss", _total_loss)
                plot(loss_list, _predictions_series, batchX, batchY)

plt.ioff()
plt.show()
# Out:
# WARNING:tensorflow:From c:\users\jan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\util\tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# New data, epoch 0
# Step 0 Loss 0.710251
# Step 100 Loss 0.704808
# Step 200 Loss 0.695629
# Step 300 Loss 0.694527
# Step 400 Loss 0.691322
# Step 500 Loss 0.502575
# Step 600 Loss 0.0857413
# New data, epoch 1
# Step 0 Loss 0.208692
# Step 100 Loss 0.0157477
# Step 200 Loss 0.0414585
# Step 300 Loss 0.00704834
# Step 400 Loss 0.00426842
# Step 500 Loss 0.00373628
# Step 600 Loss 0.00370912
# New data, epoch 2
# Step 0 Loss 0.225374
# Step 100 Loss 0.00299744
# Step 200 Loss 0.00209781
# Step 300 Loss 0.00254153
# Step 400 Loss 0.00211675
# Step 500 Loss 0.00164919
# Step 600 Loss 0.00129451
# New data, epoch 3
# Step 0 Loss 0.187772
# Step 100 Loss 0.00170089
# Step 200 Loss 0.00161829
# Step 300 Loss 0.00130566
# Step 400 Loss 0.00145548
# Step 500 Loss 0.00101379
# Step 600 Loss 0.0010898
# New data, epoch 4
# Step 0 Loss 0.196488
# Step 100 Loss 0.00089545
# Step 200 Loss 0.000975538
# Step 300 Loss 0.00300007
# Step 400 Loss 0.000966896
# Step 500 Loss 0.00110357
# Step 600 Loss 0.00117069
# New data, epoch 5
# Step 0 Loss 0.291039
# Step 100 Loss 0.00100692
# Step 200 Loss 0.000881845
# Step 300 Loss 0.0008267
# Step 400 Loss 0.000727344
# Step 500 Loss 0.000734089
# Step 600 Loss 0.000502244
# New data, epoch 6
# Step 0 Loss 0.462341
# Step 100 Loss 0.00070254
# Step 200 Loss 0.000874254
# Step 300 Loss 0.000745777
# Step 400 Loss 0.000565219
# Step 500 Loss 0.000656804
# Step 600 Loss 0.00062951
# New data, epoch 7
# Step 0 Loss 0.192166
# Step 100 Loss 0.000536209
# Step 200 Loss 0.000687585
# Step 300 Loss 0.000574468
# Step 400 Loss 0.00049925
# Step 500 Loss 0.000542078
# Step 600 Loss 0.000375659
# New data, epoch 8
# Step 0 Loss 0.326948
# Step 100 Loss 0.000768701
# Step 200 Loss 0.000616674
# Step 300 Loss 0.000571803
# Step 400 Loss 0.000542075
# Step 500 Loss 0.000443525
# Step 600 Loss 0.000430426
# New data, epoch 9
# Step 0 Loss 0.145931
# Step 100 Loss 0.000382766
# Step 200 Loss 0.000415572
# Step 300 Loss 0.00039719
# Step 400 Loss 0.000451531
# Step 500 Loss 0.000290873
# Step 600 Loss 0.000549312
# New data, epoch 10
# Step 0 Loss 0.342664
# Step 100 Loss 0.000585983
# Step 200 Loss 0.000398159
# Step 300 Loss 0.000563436
# Step 400 Loss 0.000440372
# Step 500 Loss 0.000384868
# Step 600 Loss 0.000376102
# New data, epoch 11
# Step 0 Loss 0.265129
# Step 100 Loss 0.000279364
# Step 200 Loss 0.000334454
# Step 300 Loss 0.000309663
# Step 400 Loss 0.000324327
# Step 500 Loss 0.000257297
# Step 600 Loss 0.000317247
# New data, epoch 12
# Step 0 Loss 0.235263
# Step 100 Loss 0.000307192
# Step 200 Loss 0.00054117
# Step 300 Loss 0.000349596
# Step 400 Loss 0.000312514
# Step 500 Loss 0.000365666
# Step 600 Loss 0.000373269
# New data, epoch 13
# Step 0 Loss 0.22677
# Step 100 Loss 0.000287438
# Step 200 Loss 0.00030015
# Step 300 Loss 0.000321571
# Step 400 Loss 0.0002844
# Step 500 Loss 0.000249186
# Step 600 Loss 0.000275394
# New data, epoch 14
# Step 0 Loss 0.180975
# Step 100 Loss 0.000340481
# Step 200 Loss 0.000249019
# Step 300 Loss 0.000214654
# Step 400 Loss 0.000266122
# Step 500 Loss 0.000288471
# Step 600 Loss 0.000223509
# New data, epoch 15
# Step 0 Loss 0.26587
# Step 100 Loss 0.00028465
# Step 200 Loss 0.000243073
# Step 300 Loss 0.000208116
# Step 400 Loss 0.000283255
# Step 500 Loss 0.0002183
# Step 600 Loss 0.000251615
# New data, epoch 16
# Step 0 Loss 0.262731
# Step 100 Loss 0.000259423
# Step 200 Loss 0.000307191
# Step 300 Loss 0.000203435
# Step 400 Loss 0.000295509
# Step 500 Loss 0.000214784
# Step 600 Loss 0.000305755
# New data, epoch 17
# Step 0 Loss 0.344767
# Step 100 Loss 0.000210085
# Step 200 Loss 0.000220212
# Step 300 Loss 0.000195124
# Step 400 Loss 0.000220156
# Step 500 Loss 0.000258494
# Step 600 Loss 0.000195262
# New data, epoch 18
# Step 0 Loss 0.341075
# Step 100 Loss 0.000206466
# Step 200 Loss 0.000204062
# Step 300 Loss 0.000251414
# Step 400 Loss 0.000188218
# Step 500 Loss 0.000170078
# Step 600 Loss 0.000231293
# New data, epoch 19
# Step 0 Loss 0.312366
# Step 100 Loss 0.000360773
# Step 200 Loss 0.000252704
# Step 300 Loss 0.000241967
# Step 400 Loss 0.00023347
# Step 500 Loss 0.000216393
# Step 600 Loss 0.000183624
# New data, epoch 20
# Step 0 Loss 0.358582
# Step 100 Loss 0.000219604
# Step 200 Loss 0.000233415
# Step 300 Loss 0.000245236
# Step 400 Loss 0.000159085
# Step 500 Loss 0.000218077
# Step 600 Loss 0.000196543
# New data, epoch 21
# Step 0 Loss 0.253878
# Step 100 Loss 0.00021477
# Step 200 Loss 0.000188003
# Step 300 Loss 0.000179165
# Step 400 Loss 0.000156279
# Step 500 Loss 0.000160001
# Step 600 Loss 0.000139804
# New data, epoch 22
# Step 0 Loss 0.194671
# Step 100 Loss 0.000144429
# Step 200 Loss 0.000153242
# Step 300 Loss 0.000210689
# Step 400 Loss 0.000212335
# Step 500 Loss 0.000170017
# Step 600 Loss 0.000138305
# New data, epoch 23
# Step 0 Loss 0.249545
# Step 100 Loss 0.000150685
# Step 200 Loss 0.000154291
# Step 300 Loss 0.000172414
# Step 400 Loss 0.000169205
# Step 500 Loss 0.000142207
# Step 600 Loss 0.00016104
# New data, epoch 24
# Step 0 Loss 0.225272
# Step 100 Loss 0.00020537
# Step 200 Loss 0.000175714
# Step 300 Loss 0.000210229
# Step 400 Loss 0.00014486
# Step 500 Loss 0.00014763
# Step 600 Loss 0.000149437
# New data, epoch 25
# Step 0 Loss 0.318169
# Step 100 Loss 0.000218482
# Step 200 Loss 0.000199647
# Step 300 Loss 0.000171088
# Step 400 Loss 0.00021606
# Step 500 Loss 0.000200276
# Step 600 Loss 0.000217397
# New data, epoch 26
# Step 0 Loss 0.309517
# Step 100 Loss 0.000141453
# Step 200 Loss 0.00018415
# Step 300 Loss 0.000149849
# Step 400 Loss 0.000133844
# Step 500 Loss 0.000152784
# Step 600 Loss 0.000164706
# New data, epoch 27
# Step 0 Loss 0.320492
# Step 100 Loss 0.000132955
# Step 200 Loss 0.000140286
# Step 300 Loss 0.000153206
# Step 400 Loss 0.000152412
# Step 500 Loss 0.00014004
# Step 600 Loss 0.000151174
# New data, epoch 28
# Step 0 Loss 0.123769
# Step 100 Loss 0.000157029
# Step 200 Loss 0.000146829
# Step 300 Loss 0.000125771
# Step 400 Loss 0.000123864
# Step 500 Loss 0.000164592
# Step 600 Loss 0.000147494
# New data, epoch 29
# Step 0 Loss 0.316066
# Step 100 Loss 0.00017965
# Step 200 Loss 0.000209196
# Step 300 Loss 0.000105723
# Step 400 Loss 0.000111558
# Step 500 Loss 0.000110135
# Step 600 Loss 9.01249e-05
# New data, epoch 30
# Step 0 Loss 0.106556
# Step 100 Loss 0.000100299
# Step 200 Loss 0.00014979
# Step 300 Loss 0.000127445
# Step 400 Loss 0.000143025
# Step 500 Loss 9.21749e-05
# Step 600 Loss 9.7196e-05
# New data, epoch 31
# Step 0 Loss 0.135676
# Step 100 Loss 0.000127768
# Step 200 Loss 0.000136874
# Step 300 Loss 0.000143027
# Step 400 Loss 0.000126341
# Step 500 Loss 0.00012091
# Step 600 Loss 0.000123425
# New data, epoch 32
# Step 0 Loss 0.263981
# Step 100 Loss 0.000144316
# Step 200 Loss 0.000176305
# Step 300 Loss 0.000135413
# Step 400 Loss 0.000144811
# Step 500 Loss 0.000166979
# Step 600 Loss 0.000137999
# New data, epoch 33
# Step 0 Loss 0.379646
# Step 100 Loss 0.000134761
# Step 200 Loss 0.000125846
# Step 300 Loss 9.40496e-05
# Step 400 Loss 0.000104952
# Step 500 Loss 0.00012054
# Step 600 Loss 0.00011038
# New data, epoch 34
# Step 0 Loss 0.345143
# Step 100 Loss 0.000105437
# Step 200 Loss 0.000115078
# Step 300 Loss 9.40764e-05
# Step 400 Loss 0.000130913
# Step 500 Loss 0.000119443
# Step 600 Loss 0.000140748
# New data, epoch 35
# Step 0 Loss 0.197311
# Step 100 Loss 0.000293218
# Step 200 Loss 0.000211662
# Step 300 Loss 0.00014163
# Step 400 Loss 0.00013937
# Step 500 Loss 0.000127884
# Step 600 Loss 0.00017689
# New data, epoch 36
# Step 0 Loss 0.159877
# Step 100 Loss 0.000140408
# Step 200 Loss 0.000147955
# Step 300 Loss 0.000139637
# Step 400 Loss 0.000141217
# Step 500 Loss 9.84623e-05
# Step 600 Loss 0.000128643
# New data, epoch 37
# Step 0 Loss 0.297114
# Step 100 Loss 0.000102112
# Step 200 Loss 0.000129207
# Step 300 Loss 0.000105154
# Step 400 Loss 0.000130131
# Step 500 Loss 0.000129844
# Step 600 Loss 9.00223e-05
# New data, epoch 38
# Step 0 Loss 0.155552
# Step 100 Loss 9.43537e-05
# Step 200 Loss 0.000105984
# Step 300 Loss 0.000146467
# Step 400 Loss 0.000100772
# Step 500 Loss 0.000108154
# Step 600 Loss 8.87484e-05
# New data, epoch 39
# Step 0 Loss 0.16985
# Step 100 Loss 0.000103688
# Step 200 Loss 8.78226e-05
# Step 300 Loss 8.53229e-05
# Step 400 Loss 0.000117783
# Step 500 Loss 0.000103564
# Step 600 Loss 0.000141289
# New data, epoch 40
# Step 0 Loss 0.30983
# Step 100 Loss 0.000116114
# Step 200 Loss 0.000105744
# Step 300 Loss 9.18479e-05
# Step 400 Loss 8.17273e-05
# Step 500 Loss 0.000107039
# Step 600 Loss 9.50265e-05
# New data, epoch 41
# Step 0 Loss 0.314483
# Step 100 Loss 7.33766e-05
# Step 200 Loss 0.000116075
# Step 300 Loss 0.000103273
# Step 400 Loss 0.000107404
# Step 500 Loss 9.30667e-05
# Step 600 Loss 7.63882e-05
# New data, epoch 42
# Step 0 Loss 0.29524
# Step 100 Loss 0.000114439
# Step 200 Loss 8.73922e-05
# Step 300 Loss 8.27371e-05
# Step 400 Loss 6.98498e-05
# Step 500 Loss 0.000135144
# Step 600 Loss 7.61056e-05
# New data, epoch 43
# Step 0 Loss 0.277445
# Step 100 Loss 9.29355e-05
# Step 200 Loss 8.88546e-05
# Step 300 Loss 9.14383e-05
# Step 400 Loss 0.000103485
# Step 500 Loss 7.13092e-05
# Step 600 Loss 7.77212e-05
# New data, epoch 44
# Step 0 Loss 0.343808
# Step 100 Loss 7.55546e-05
# Step 200 Loss 0.000123602
# Step 300 Loss 8.99594e-05
# Step 400 Loss 0.000100689
# Step 500 Loss 7.33083e-05
# Step 600 Loss 8.41318e-05
# New data, epoch 45
# Step 0 Loss 0.293065
# Step 100 Loss 0.000155479
# Step 200 Loss 0.000139428
# Step 300 Loss 0.000116907
# Step 400 Loss 0.000117299
# Step 500 Loss 0.000128284
# Step 600 Loss 0.000112349
# New data, epoch 46
# Step 0 Loss 0.229069
# Step 100 Loss 0.000144691
# Step 200 Loss 0.000145038
# Step 300 Loss 0.000157077
# Step 400 Loss 9.71064e-05
# Step 500 Loss 0.000132467
# Step 600 Loss 0.000120946
# New data, epoch 47
# Step 0 Loss 0.297689
# Step 100 Loss 9.33578e-05
# Step 200 Loss 7.47603e-05
# Step 300 Loss 0.000105308
# Step 400 Loss 0.000112864
# Step 500 Loss 9.45637e-05
# Step 600 Loss 0.000112678
# New data, epoch 48
# Step 0 Loss 0.173506
# Step 100 Loss 0.000100915
# Step 200 Loss 9.59974e-05
# Step 300 Loss 7.631e-05
# Step 400 Loss 0.000114229
# Step 500 Loss 8.41688e-05
# Step 600 Loss 7.12243e-05
# New data, epoch 49
# Step 0 Loss 0.293387
# Step 100 Loss 0.000107039
# Step 200 Loss 8.77439e-05
# Step 300 Loss 0.000102331
# Step 400 Loss 8.75869e-05
# Step 500 Loss 8.03056e-05
# Step 600 Loss 8.86271e-05
# New data, epoch 50
# Step 0 Loss 0.125159
# Step 100 Loss 8.1964e-05
# Step 200 Loss 8.53598e-05
# Step 300 Loss 0.000120627
# Step 400 Loss 9.14682e-05
# Step 500 Loss 0.00010508
# Step 600 Loss 9.08669e-05
# New data, epoch 51
# Step 0 Loss 0.244547
# Step 100 Loss 8.28321e-05
# Step 200 Loss 9.54671e-05
# Step 300 Loss 6.35371e-05
# Step 400 Loss 7.47918e-05
# Step 500 Loss 8.84596e-05
# Step 600 Loss 9.62254e-05
# New data, epoch 52
# Step 0 Loss 0.17471
# Step 100 Loss 0.000142577
# Step 200 Loss 8.574e-05
# Step 300 Loss 7.28212e-05
# Step 400 Loss 6.84346e-05
# Step 500 Loss 7.30978e-05
# Step 600 Loss 5.44942e-05
# New data, epoch 53
# Step 0 Loss 0.122334
# Step 100 Loss 7.02874e-05
# Step 200 Loss 8.85984e-05
# Step 300 Loss 9.10631e-05
# Step 400 Loss 9.53923e-05
# Step 500 Loss 7.19904e-05
# Step 600 Loss 7.45637e-05
# New data, epoch 54
# Step 0 Loss 0.166781
# Step 100 Loss 8.17029e-05
# Step 200 Loss 7.01005e-05
# Step 300 Loss 9.38808e-05
# Step 400 Loss 6.8245e-05
# Step 500 Loss 9.94848e-05
# Step 600 Loss 8.83249e-05
# New data, epoch 55
# Step 0 Loss 0.399834
# Step 100 Loss 7.91861e-05
# Step 200 Loss 7.52533e-05
# Step 300 Loss 7.94139e-05
# Step 400 Loss 8.22632e-05
# Step 500 Loss 5.61549e-05
# Step 600 Loss 9.41357e-05
# New data, epoch 56
# Step 0 Loss 0.15258
# Step 100 Loss 8.71187e-05
# Step 200 Loss 7.351e-05
# Step 300 Loss 7.99736e-05
# Step 400 Loss 6.93038e-05
# Step 500 Loss 7.03865e-05
# Step 600 Loss 7.89055e-05
# New data, epoch 57
# Step 0 Loss 0.43381
# Step 100 Loss 8.86401e-05
# Step 200 Loss 0.00010056
# Step 300 Loss 9.38853e-05
# Step 400 Loss 9.3931e-05
# Step 500 Loss 6.64394e-05
# Step 600 Loss 7.73418e-05
# New data, epoch 58
# Step 0 Loss 0.245359
# Step 100 Loss 7.44648e-05
# Step 200 Loss 0.000101868
# Step 300 Loss 8.87919e-05
# Step 400 Loss 8.77082e-05
# Step 500 Loss 9.32317e-05
# Step 600 Loss 8.88883e-05
# New data, epoch 59
# Step 0 Loss 0.196974
# Step 100 Loss 0.000104166
# Step 200 Loss 9.18857e-05
# Step 300 Loss 6.75198e-05
# Step 400 Loss 0.000118336
# Step 500 Loss 7.73472e-05
# Step 600 Loss 6.02063e-05
# New data, epoch 60
# Step 0 Loss 0.446641
# Step 100 Loss 9.92826e-05
# Step 200 Loss 0.000107406
# Step 300 Loss 9.28863e-05
# Step 400 Loss 0.000100284
# Step 500 Loss 9.0698e-05
# Step 600 Loss 7.35801e-05
# New data, epoch 61
# Step 0 Loss 0.183064
# Step 100 Loss 8.87836e-05
# Step 200 Loss 8.22596e-05
# Step 300 Loss 0.000138132
# Step 400 Loss 7.29235e-05
# Step 500 Loss 7.83452e-05
# Step 600 Loss 6.76471e-05
# New data, epoch 62
# Step 0 Loss 0.209568
# Step 100 Loss 9.47293e-05
# Step 200 Loss 7.09398e-05
# Step 300 Loss 7.30932e-05
# Step 400 Loss 7.99429e-05
# Step 500 Loss 9.30822e-05
# Step 600 Loss 9.51181e-05
# New data, epoch 63
# Step 0 Loss 0.142545
# Step 100 Loss 7.15075e-05
# Step 200 Loss 7.17585e-05
# Step 300 Loss 9.30026e-05
# Step 400 Loss 8.0165e-05
# Step 500 Loss 5.90214e-05
# Step 600 Loss 6.25678e-05
# New data, epoch 64
# Step 0 Loss 0.148389
# Step 100 Loss 6.41971e-05
# Step 200 Loss 6.4243e-05
# Step 300 Loss 5.81435e-05
# Step 400 Loss 6.0668e-05
# Step 500 Loss 9.08243e-05
# Step 600 Loss 4.4434e-05
# New data, epoch 65
# Step 0 Loss 0.131388
# Step 100 Loss 7.13179e-05
# Step 200 Loss 5.74179e-05
# Step 300 Loss 5.88693e-05
# Step 400 Loss 6.75405e-05
# Step 500 Loss 9.27974e-05
# Step 600 Loss 9.07906e-05
# New data, epoch 66
# Step 0 Loss 0.160008
# Step 100 Loss 0.000105169
# Step 200 Loss 8.72181e-05
# Step 300 Loss 7.96071e-05
# Step 400 Loss 8.81306e-05
# Step 500 Loss 7.26294e-05
# Step 600 Loss 7.61828e-05
# New data, epoch 67
# Step 0 Loss 0.274732
# Step 100 Loss 8.12436e-05
# Step 200 Loss 7.41239e-05
# Step 300 Loss 8.40032e-05
# Step 400 Loss 9.77025e-05
# Step 500 Loss 6.26531e-05
# Step 600 Loss 8.08158e-05
# New data, epoch 68
# Step 0 Loss 0.288104
# Step 100 Loss 7.38344e-05
# Step 200 Loss 0.000109462
# Step 300 Loss 6.57729e-05
# Step 400 Loss 8.38358e-05
# Step 500 Loss 7.58071e-05
# Step 600 Loss 6.97604e-05
# New data, epoch 69
# Step 0 Loss 0.288337
# Step 100 Loss 6.26133e-05
# Step 200 Loss 7.12045e-05
# Step 300 Loss 9.64025e-05
# Step 400 Loss 5.32596e-05
# Step 500 Loss 5.63827e-05
# Step 600 Loss 6.16897e-05
# New data, epoch 70
# Step 0 Loss 0.290546
# Step 100 Loss 8.27743e-05
# Step 200 Loss 5.48227e-05
# Step 300 Loss 7.79057e-05
# Step 400 Loss 6.67121e-05
# Step 500 Loss 6.66092e-05
# Step 600 Loss 7.72784e-05
# New data, epoch 71
# Step 0 Loss 0.432408
# Step 100 Loss 7.80836e-05
# Step 200 Loss 6.91146e-05
# Step 300 Loss 5.48026e-05
# Step 400 Loss 7.09345e-05
# Step 500 Loss 7.15331e-05
# Step 600 Loss 6.68598e-05
# New data, epoch 72
# Step 0 Loss 0.155342
# Step 100 Loss 6.5079e-05
# Step 200 Loss 6.83671e-05
# Step 300 Loss 6.68511e-05
# Step 400 Loss 6.72797e-05
# Step 500 Loss 7.00006e-05
# Step 600 Loss 8.12374e-05
# New data, epoch 73
# Step 0 Loss 0.387249
# Step 100 Loss 7.43943e-05
# Step 200 Loss 6.50171e-05
# Step 300 Loss 6.15948e-05
# Step 400 Loss 6.79845e-05
# Step 500 Loss 6.99541e-05
# Step 600 Loss 7.27502e-05
# New data, epoch 74
# Step 0 Loss 0.249361
# Step 100 Loss 6.43555e-05
# Step 200 Loss 8.62266e-05
# Step 300 Loss 8.03205e-05
# Step 400 Loss 5.59064e-05
# Step 500 Loss 5.98556e-05
# Step 600 Loss 6.12915e-05
# New data, epoch 75
# Step 0 Loss 0.136224
# Step 100 Loss 5.15228e-05
# Step 200 Loss 6.24885e-05
# Step 300 Loss 6.34041e-05
# Step 400 Loss 6.01884e-05
# Step 500 Loss 5.34562e-05
# Step 600 Loss 6.71703e-05
# New data, epoch 76
# Step 0 Loss 0.151412
# Step 100 Loss 6.61635e-05
# Step 200 Loss 7.34574e-05
# Step 300 Loss 5.94479e-05
# Step 400 Loss 4.5367e-05
# Step 500 Loss 6.21972e-05
# Step 600 Loss 4.8573e-05
# New data, epoch 77
# Step 0 Loss 0.0952889
# Step 100 Loss 5.62684e-05
# Step 200 Loss 5.98502e-05
# Step 300 Loss 4.57152e-05
# Step 400 Loss 5.68068e-05
# Step 500 Loss 6.5422e-05
# Step 600 Loss 4.898e-05
# New data, epoch 78
# Step 0 Loss 0.200502
# Step 100 Loss 5.73123e-05
# Step 200 Loss 5.15288e-05
# Step 300 Loss 0.000165774
# Step 400 Loss 7.66719e-05
# Step 500 Loss 5.59179e-05
# Step 600 Loss 5.18797e-05
# New data, epoch 79
# Step 0 Loss 0.11485
# Step 100 Loss 6.75578e-05
# Step 200 Loss 4.89286e-05
# Step 300 Loss 5.77359e-05
# Step 400 Loss 5.70289e-05
# Step 500 Loss 7.91533e-05
# Step 600 Loss 6.80511e-05
# New data, epoch 80
# Step 0 Loss 0.168635
# Step 100 Loss 5.13447e-05
# Step 200 Loss 6.83718e-05
# Step 300 Loss 7.64781e-05
# Step 400 Loss 4.15386e-05
# Step 500 Loss 6.15187e-05
# Step 600 Loss 6.42221e-05
# New data, epoch 81
# Step 0 Loss 0.196763
# Step 100 Loss 5.16078e-05
# Step 200 Loss 7.16654e-05
# Step 300 Loss 0.000113106
# Step 400 Loss 7.76965e-05
# Step 500 Loss 8.9438e-05
# Step 600 Loss 6.45176e-05
# New data, epoch 82
# Step 0 Loss 0.255057
# Step 100 Loss 6.21793e-05
# Step 200 Loss 7.97863e-05
# Step 300 Loss 6.31694e-05
# Step 400 Loss 6.50116e-05
# Step 500 Loss 6.19068e-05
# Step 600 Loss 5.10599e-05
# New data, epoch 83
# Step 0 Loss 0.37411
# Step 100 Loss 4.51554e-05
# Step 200 Loss 5.53415e-05
# Step 300 Loss 6.19163e-05
# Step 400 Loss 5.60008e-05
# Step 500 Loss 4.70693e-05
# Step 600 Loss 5.74991e-05
# New data, epoch 84
# Step 0 Loss 0.144143
# Step 100 Loss 4.93231e-05
# Step 200 Loss 6.0954e-05
# Step 300 Loss 4.24333e-05
# Step 400 Loss 5.12711e-05
# Step 500 Loss 5.00495e-05
# Step 600 Loss 8.02527e-05
# New data, epoch 85
# Step 0 Loss 0.190613
# Step 100 Loss 5.6002e-05
# Step 200 Loss 7.92371e-05
# Step 300 Loss 8.47421e-05
# Step 400 Loss 6.02309e-05
# Step 500 Loss 6.38687e-05
# Step 600 Loss 4.27447e-05
# New data, epoch 86
# Step 0 Loss 0.454235
# Step 100 Loss 8.49203e-05
# Step 200 Loss 6.27888e-05
# Step 300 Loss 6.66744e-05
# Step 400 Loss 7.74815e-05
# Step 500 Loss 6.121e-05
# Step 600 Loss 6.65923e-05
# New data, epoch 87
# Step 0 Loss 0.19067
# Step 100 Loss 5.59917e-05
# Step 200 Loss 6.14952e-05
# Step 300 Loss 5.85194e-05
# Step 400 Loss 7.10454e-05
# Step 500 Loss 6.59102e-05
# Step 600 Loss 7.03498e-05
# New data, epoch 88
# Step 0 Loss 0.128535
# Step 100 Loss 7.1153e-05
# Step 200 Loss 6.34734e-05
# Step 300 Loss 6.04718e-05
# Step 400 Loss 5.50855e-05
# Step 500 Loss 5.53733e-05
# Step 600 Loss 5.38586e-05
# New data, epoch 89
# Step 0 Loss 0.238254
# Step 100 Loss 6.59162e-05
# Step 200 Loss 8.15278e-05
# Step 300 Loss 5.38123e-05
# Step 400 Loss 5.98436e-05
# Step 500 Loss 7.48152e-05
# Step 600 Loss 4.63619e-05
# New data, epoch 90
# Step 0 Loss 0.149128
# Step 100 Loss 7.24311e-05
# Step 200 Loss 6.18636e-05
# Step 300 Loss 3.51334e-05
# Step 400 Loss 5.25615e-05
# Step 500 Loss 7.37788e-05
# Step 600 Loss 5.2365e-05
# New data, epoch 91
# Step 0 Loss 0.266552
# Step 100 Loss 7.98345e-05
# Step 200 Loss 4.85942e-05
# Step 300 Loss 5.68279e-05
# Step 400 Loss 5.61247e-05
# Step 500 Loss 6.25996e-05
# Step 600 Loss 4.89415e-05
# New data, epoch 92
# Step 0 Loss 0.190355
# Step 100 Loss 5.42668e-05
# Step 200 Loss 5.04384e-05
# Step 300 Loss 4.35839e-05
# Step 400 Loss 5.43299e-05
# Step 500 Loss 4.90942e-05
# Step 600 Loss 7.38516e-05
# New data, epoch 93
# Step 0 Loss 0.216525
# Step 100 Loss 5.71156e-05
# Step 200 Loss 6.17179e-05
# Step 300 Loss 4.06859e-05
# Step 400 Loss 5.92616e-05
# Step 500 Loss 6.00425e-05
# Step 600 Loss 5.13873e-05
# New data, epoch 94
# Step 0 Loss 0.24604
# Step 100 Loss 5.71441e-05
# Step 200 Loss 4.89111e-05
# Step 300 Loss 5.71241e-05
# Step 400 Loss 5.7746e-05
# Step 500 Loss 4.22514e-05
# Step 600 Loss 5.84264e-05
# New data, epoch 95
# Step 0 Loss 0.0865155
# Step 100 Loss 6.32229e-05
# Step 200 Loss 5.50144e-05
# Step 300 Loss 5.80107e-05
# Step 400 Loss 4.01112e-05
# Step 500 Loss 6.71625e-05
# Step 600 Loss 4.34496e-05
# New data, epoch 96
# Step 0 Loss 0.130983
# Step 100 Loss 5.63558e-05
# Step 200 Loss 5.06707e-05
# Step 300 Loss 5.43893e-05
# Step 400 Loss 5.78636e-05
# Step 500 Loss 5.15519e-05
# Step 600 Loss 5.17018e-05
# New data, epoch 97
# Step 0 Loss 0.237376
# Step 100 Loss 5.58924e-05
# Step 200 Loss 5.64647e-05
# Step 300 Loss 5.54081e-05
# Step 400 Loss 4.45532e-05
# Step 500 Loss 3.33344e-05
# Step 600 Loss 4.16481e-05
# New data, epoch 98
# Step 0 Loss 0.122091
# Step 100 Loss 7.17431e-05
# Step 200 Loss 3.80959e-05
# Step 300 Loss 3.95119e-05
# Step 400 Loss 5.47307e-05
# Step 500 Loss 4.92118e-05
# Step 600 Loss 4.56433e-05
# New data, epoch 99
# Step 0 Loss 0.156303
# Step 100 Loss 6.1284e-05
# Step 200 Loss 3.87493e-05
# Step 300 Loss 4.22234e-05
# Step 400 Loss 5.09759e-05
# Step 500 Loss 4.61664e-05
# Step 600 Loss 5.58845e-05
