# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt
from matplotlib import animation
import os,sys,time,datetime,warnings,itertools,math

# %%
def init():
    line.set_data([],[])
    return line

# %%
def animate(i):
    x = np.linspace(0,2,1000)
    y = np.sin(2*np.pi*(x - 0.01*i))
    line.set_data(x,y)
    return line,

# %%
fig = plt.figure()
ax = plt.axes(
    xlim=(0,2),
    ylim=(-2,2)
)
line, = ax.plot([],[],lw=2)

# %%
anim = animation.FuncAnimation(
    fig,
    animate,
    init_func=init,
    frames=200,
    interval=20,
    blit=True
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-33404c8eb1aa> in <module>
# ----> 1 anim = animation.FuncAnimation(
#       2     fig,
#       3     animate,
#       4     init_func=init,
#       5     frames=200,
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1654         self._save_seq = []
#    1655
# -> 1656         TimedAnimation.__init__(self, fig, **kwargs)
#    1657
#    1658         # Need to reset the saved seq, since right now it will contain data
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1413         if event_source is None:
#    1414             event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1415         Animation.__init__(self, fig, event_source=event_source,
#    1416                            *args, **kwargs)
#    1417
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     943                                                       self._stop)
#     944         if self._blit:
# --> 945             self._setup_blit()
#     946
#     947     def _start(self, *args):
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _setup_blit(self)
#    1247         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1248                                                        self._on_resize)
# -> 1249         self._post_draw(None, self._blit)
#    1250
#    1251     def _on_resize(self, event):
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1200             self._blit_draw(self._drawn_artists)
#    1201         else:
# -> 1202             self._fig.canvas.draw_idle()
#    1203
#    1204     # The rest of the code in this class is to facilitate easy blitting
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1868             self.stale = False
#    1869
# -> 1870         self.canvas.draw_event(renderer)
#    1871
#    1872     def draw_artist(self, a):
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1757         s = 'draw_event'
#    1758         event = DrawEvent(s, self, renderer)
# -> 1759         self.callbacks.process(s, event)
#    1760
#    1761     def resize_event(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     227                 except Exception as exc:
#     228                     if self.exception_handler is not None:
# --> 229                         self.exception_handler(exc)
#     230                     else:
#     231                         raise
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      79 def _exception_printer(exc):
#      80     if _get_running_interactive_framework() in ["headless", None]:
# ---> 81         raise exc
#      82     else:
#      83         traceback.print_exc()
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     222             if func is not None:
#     223                 try:
# --> 224                     func(*args, **kwargs)
#     225                 # this does not capture KeyboardInterrupt, SystemExit,
#     226                 # and GeneratorExit
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _start(self, *args)
#     957
#     958         # Now do any initial draw
# --> 959         self._init_draw()
#     960
#     961         # Add our callback for stepping the animation and
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _init_draw(self)
#    1709                     raise RuntimeError('The init_func must return a '
#    1710                                        'sequence of Artist objects.')
# -> 1711                 for a in self._drawn_artists:
#    1712                     a.set_animated(self._blit)
#    1713         self._save_seq = []
#
# TypeError: 'Line2D' object is not iterable

# %%
TWOPI = 2*np.pi

fig, ax = plt.subplots()

t = np.arange(0.0, TWOPI, 0.001)
s = np.sin(t)
l = plt.plot(t, s)

ax = plt.axis([0,TWOPI,-1,1])

redDot, = plt.plot([0], [np.sin(0)], 'ro')

def animate(i):
    redDot.set_data(i, np.sin(i))
    return redDot,

# create animation using the animate() function
myAnimation = animation.FuncAnimation(fig, animate, frames=np.arange(0.0, TWOPI, 0.1), \
                                      interval=10, blit=True, repeat=True)

plt.show()
